# %%
# %reset -f

# %%
from pathlib import Path
import tarfile
import pandas as pd

# %%
MERGED_TAR = Path.cwd().parent / "data/merged/merged-kg.tar.gz"

# %%
tar = tarfile.open(MERGED_TAR, "r:gz")
# Extract the TSV file
for member in tar.getmembers():
    f = tar.extractfile(member)
    if '_nodes.tsv' in member.name:
        # Read the TSV file into a pandas DataFrame
        df_nodes = pd.read_csv(f, sep='\t', low_memory=False)
    elif '_edges.tsv' in member.name:
        # Read the TSV file into a pandas DataFrame
        df_edges = pd.read_csv(f, sep='\t', low_memory=False)

# Close the tar.gz file
tar.close()

# %%
df_nodes.head()
# Out:
#                  id                                        category  \
# 0       IAO:0000115                           biolink:OntologyClass
# 1       NCBITaxon:1                        biolink:OrganismalEntity
# 2      NCBITaxon:10                        biolink:OrganismalEntity
# 3     NCBITaxon:100  biolink:OrganismTaxon|biolink:OrganismalEntity
# 4  NCBITaxon:100000                        biolink:OrganismalEntity
#
#                       name description                                  xref  \
# 0               definition         NaN                                   NaN
# 1                     root         NaN   GC_ID:1|PMID:30365038|PMID:32761142
# 2               Cellvibrio         NaN  GC_ID:11|PMID:12710603|PMID:24105943
# 3   Ancylobacter aquaticus         NaN                              GC_ID:11
# 4  Herbaspirillum sp. BA12         NaN                              GC_ID:11
#
#   provided_by                  synonym  \
# 0       Graph                      NaN
# 1       Graph                      all
# 2       Graph                      NaN
# 3       Graph    Microcyclus aquaticus
# 4       Graph  Herbispirillum sp. BA12
#
#                                                  iri  object  predicate  \
# 0  http://purl.obolibrary.org/obo/IAO_0000115|htt...     NaN        NaN
# 1         http://purl.obolibrary.org/obo/NCBITaxon_1     NaN        NaN
# 2        http://purl.obolibrary.org/obo/NCBITaxon_10     NaN        NaN
# 3       http://purl.obolibrary.org/obo/NCBITaxon_100     NaN        NaN
# 4    http://purl.obolibrary.org/obo/NCBITaxon_100000     NaN        NaN
#
#    relation  same_as  subject subsets
# 0       NaN      NaN      NaN     NaN
# 1       NaN      NaN      NaN     NaN
# 2       NaN      NaN      NaN     NaN
# 3       NaN      NaN      NaN     NaN
# 4       NaN      NaN      NaN     NaN

# %%
df_edges.head()
# Out:
#                                               id        subject  \
# 0  urn:uuid:c672b249-cb5c-4ed6-b6f6-944bbf690d10   NCBITaxon:10
# 1  urn:uuid:a9b6d704-f957-483d-a02f-5b0dda8b2aca  NCBITaxon:100
# 2  urn:uuid:0f757f39-b6d6-4dae-a76d-96be13967e3f  NCBITaxon:100
# 3  urn:uuid:d0adb6aa-777a-4bf7-a608-3a75ea59173a  NCBITaxon:100
# 4  urn:uuid:3389a8ad-1c31-4f61-a1b2-0b0266e4d212  NCBITaxon:100
#
#              predicate                                      object  \
# 0  biolink:subclass_of                           NCBITaxon:1706371
# 1  biolink:subclass_of                                NCBITaxon:99
# 2    biolink:occurs_in                          medium:7
# 3   biolink:capable_of     pathways:hydrogen_oxidation_dark
# 4   biolink:capable_of  pathways:aerobic_chemo_heterotrophy
#
#           relation  provided_by knowledge_source
# 0  rdfs:subClassOf          NaN            Graph
# 1  rdfs:subClassOf          NaN            Graph
# 2      BAO:0002924          NaN            Graph
# 3       RO:0002215          NaN            Graph
# 4       RO:0002215          NaN            Graph

# %%
all_ingredients_obj = df_edges.loc[df_edges['object'].str.contains("ingredient")]

# %%
all_ingredients_obj['subject'].str.split(":").str[0].unique()
# Out:
# array(['medium', 'mediadive.solution'], dtype=object)

# %%
df_edges['subject'].str.split(":").str[0].unique()
# Out:
# array(['NCBITaxon', 'OBO', 'CHEBI', 'medium',
#        'mediadive.solution'], dtype=object)

# %%
df_edges['object'].str.split(":").str[0].unique()
# Out:
# array(['NCBITaxon', 'medium', 'pathways', 'ENVO',
#        'ECOCORE', 'cell_shape', 'UBERON',
#        'isolation_source', 'CHEBI', 'GO', ' ENVO',
#        'carbon_substrates', 'PO', 'FOODON', 'OBO',
#        'mediadive.solution', 'ingredient', 'CAS-RN', 'PubChem',
#        'KEGG'], dtype=object)

# %%
df_edges.loc[df_edges['subject']=="medium:1a"]
# Out:
#                                                     id              subject  \
# 1239035  urn:uuid:585e79a6-e793-4e1a-a58f-1f20e47fe106  medium:1a
# 1239036  urn:uuid:b5cb5889-7d7c-41bb-aabf-02a9de65bbdb  medium:1a
#
#                 predicate                  object     relation  provided_by  \
# 1239035  biolink:has_part    mediadive.solution:3  BFO:0000051          NaN
# 1239036  biolink:has_part  ingredient:2  BFO:0000051          NaN
#
#         knowledge_source
# 1239035            Graph
# 1239036            Graph

# %%
df_edges.loc[df_edges['subject']=="mediadive.solution:3"]
# Out:
#                                                     id               subject  \
# 1249641  urn:uuid:c91d45a3-e9c3-49ab-8b40-f47b0e73e9e4  mediadive.solution:3
# 1249642  urn:uuid:33df28a0-5f04-41e7-aee0-d4ea5575f104  mediadive.solution:3
# 1249643  urn:uuid:ce34dc43-15f6-4a4a-ae3f-dc9f91147499  mediadive.solution:3
# 1249644  urn:uuid:60bb08e5-2f2e-414f-b977-e4f6ad8f6124  mediadive.solution:3
#
#                 predicate                  object     relation  provided_by  \
# 1249641  biolink:has_part       CAS-RN:73049-73-7  BFO:0000051          NaN
# 1249642  biolink:has_part  ingredient:2  BFO:0000051          NaN
# 1249643  biolink:has_part              CHEBI:2509  BFO:0000051          NaN
# 1249644  biolink:has_part             CHEBI:15377  BFO:0000051          NaN
#
#         knowledge_source
# 1249641            Graph
# 1249642            Graph
# 1249643            Graph
# 1249644            Graph

# %%
subj_pattern = ['medium:', 'mediadive.solution:']
obj_pattern = ['mediadive.solution:', 'ingredient:']

condition_1 = df_edges['subject'].str.contains('|'.join(subj_pattern))
condition_2 = df_edges['object'].str.contains('|'.join(obj_pattern))

df_mediadive = df_edges[condition_1 & condition_2]

# mapping = df_edges.set_index('object')['subject'].to_dict()

# mapping
df_mediadive
# Out:
#                                                     id  \
# 1238696  urn:uuid:c42c2fe3-9311-427f-9065-a6a51d559fbd
# 1238697  urn:uuid:7c80c163-becc-4caf-888f-b43b2bd12eed
# 1238698  urn:uuid:cf686fd5-c286-4112-bac7-fc9ec67f2be4
# 1238699  urn:uuid:3d68198c-eac5-41dd-b35c-95cbd862af9a
# 1238700  urn:uuid:d6162fa5-f52a-44d0-81b6-e6491a5c52c4
# ...                                                ...
# 1340837  urn:uuid:60b08e4e-410d-4bc9-ad97-883486d586b3
# 1340838  urn:uuid:eac11dab-9a49-43d1-9360-3ea8a3907cf6
# 1340839  urn:uuid:14c685ac-f3ad-43e8-8490-80eec5eeb036
# 1340848  urn:uuid:7d168e7c-65ba-4b2b-842c-b7fb162259ab
# 1340863  urn:uuid:2c5c1136-f78e-4911-86c2-e7a35f3878ee
#
#                          subject         predicate                    object  \
# 1238696    medium:1669  biolink:has_part   mediadive.solution:3464
# 1238697    medium:1669  biolink:has_part  ingredient:156
# 1238698      medium:92  biolink:has_part    mediadive.solution:161
# 1238699      medium:92  biolink:has_part   ingredient:99
# 1238700    medium:1609  biolink:has_part   mediadive.solution:3351
# ...                          ...               ...                       ...
# 1340837    medium:C109  biolink:has_part   mediadive.solution:6100
# 1340838    medium:C110  biolink:has_part   mediadive.solution:6101
# 1340839    medium:C110  biolink:has_part   mediadive.solution:6248
# 1340848  mediadive.solution:6101  biolink:has_part   mediadive.solution:6248
# 1340863  mediadive.solution:6248  biolink:has_part   mediadive.solution:6248
#
#             relation  provided_by knowledge_source
# 1238696  BFO:0000051          NaN            Graph
# 1238697  BFO:0000051          NaN            Graph
# 1238698  BFO:0000051          NaN            Graph
# 1238699  BFO:0000051          NaN            Graph
# 1238700  BFO:0000051          NaN            Graph
# ...              ...          ...              ...
# 1340837  BFO:0000051          NaN            Graph
# 1340838  BFO:0000051          NaN            Graph
# 1340839  BFO:0000051          NaN            Graph
# 1340848  BFO:0000051          NaN            Graph
# 1340863  BFO:0000051          NaN            Graph
#
# [44505 rows x 7 columns]

# %%
medium_subject_condition = df_mediadive["subject"].str.startswith("medium:")
solution_object_condition = df_mediadive["object"].str.startswith("mediadive.solution:")

medium_solution_df = df_mediadive[medium_subject_condition & solution_object_condition]
medium_solution_df
# Out:
#                                                     id                subject  \
# 1238696  urn:uuid:c42c2fe3-9311-427f-9065-a6a51d559fbd  medium:1669
# 1238698  urn:uuid:cf686fd5-c286-4112-bac7-fc9ec67f2be4    medium:92
# 1238700  urn:uuid:d6162fa5-f52a-44d0-81b6-e6491a5c52c4  medium:1609
# 1238703  urn:uuid:1702102b-37d7-4c03-a53a-cc36f1f604bf   medium:830
# 1238707  urn:uuid:85b3b579-b9d5-4f65-9470-670f6d572c2d    medium:65
# ...                                                ...                    ...
# 1340795  urn:uuid:bd4f0b42-29a3-4460-affd-dd1d46ae20b7  medium:C108
# 1340796  urn:uuid:2b53712c-9e53-4231-911b-b2dbddc8343a  medium:C108
# 1340837  urn:uuid:60b08e4e-410d-4bc9-ad97-883486d586b3  medium:C109
# 1340838  urn:uuid:eac11dab-9a49-43d1-9360-3ea8a3907cf6  medium:C110
# 1340839  urn:uuid:14c685ac-f3ad-43e8-8490-80eec5eeb036  medium:C110
#
#                 predicate                   object     relation  provided_by  \
# 1238696  biolink:has_part  mediadive.solution:3464  BFO:0000051          NaN
# 1238698  biolink:has_part   mediadive.solution:161  BFO:0000051          NaN
# 1238700  biolink:has_part  mediadive.solution:3351  BFO:0000051          NaN
# 1238703  biolink:has_part  mediadive.solution:1685  BFO:0000051          NaN
# 1238707  biolink:has_part   mediadive.solution:106  BFO:0000051          NaN
# ...                   ...                      ...          ...          ...
# 1340795  biolink:has_part  mediadive.solution:6160  BFO:0000051          NaN
# 1340796  biolink:has_part  mediadive.solution:6246  BFO:0000051          NaN
# 1340837  biolink:has_part  mediadive.solution:6100  BFO:0000051          NaN
# 1340838  biolink:has_part  mediadive.solution:6101  BFO:0000051          NaN
# 1340839  biolink:has_part  mediadive.solution:6248  BFO:0000051          NaN
#
#         knowledge_source
# 1238696            Graph
# 1238698            Graph
# 1238700            Graph
# 1238703            Graph
# 1238707            Graph
# ...                  ...
# 1340795            Graph
# 1340796            Graph
# 1340837            Graph
# 1340838            Graph
# 1340839            Graph
#
# [8525 rows x 7 columns]

# %%
solution_subject_condition = df_mediadive["subject"].str.startswith("mediadive.solution:")
ingredient_object_condition = df_mediadive["object"].str.startswith("ingredient:")

solution_ingredient_df = df_mediadive[solution_subject_condition & ingredient_object_condition]
solution_ingredient_df
# Out:
#                                                     id  \
# 1249568  urn:uuid:653df055-46ac-4a5a-b881-b8e8c4804d9b
# 1249573  urn:uuid:1d669c12-6bcc-49fd-989c-8436ca92721d
# 1249574  urn:uuid:66116aa2-411a-4ca3-be36-6b30014ed72a
# 1249575  urn:uuid:20396f7b-2db6-4061-9e0c-e97b236f7513
# 1249577  urn:uuid:ad93aa8e-920c-474e-a114-39110088c83e
# ...                                                ...
# 1340686  urn:uuid:013ef9c3-c5d7-4301-bb2c-cdc4374a3b73
# 1340700  urn:uuid:486fe651-41c2-4fb4-bcae-6b8bf36befb3
# 1340803  urn:uuid:868448b2-db0e-48c7-988b-1ba8557bf0b2
# 1340809  urn:uuid:b61b5cd7-1312-43fc-8c7a-f9bec69d1904
# 1340818  urn:uuid:855bd741-7061-43f4-9ab7-fcdb899b34f8
#
#                          subject         predicate                     object  \
# 1249568     mediadive.solution:1  biolink:has_part     ingredient:2
# 1249573     mediadive.solution:1  biolink:has_part  ingredient:2111
# 1249574     mediadive.solution:1  biolink:has_part   ingredient:724
# 1249575     mediadive.solution:1  biolink:has_part  ingredient:2110
# 1249577     mediadive.solution:1  biolink:has_part  ingredient:2112
# ...                          ...               ...                        ...
# 1340686  mediadive.solution:6241  biolink:has_part   ingredient:286
# 1340700  mediadive.solution:6242  biolink:has_part   ingredient:286
# 1340803  mediadive.solution:6247  biolink:has_part   ingredient:286
# 1340809  mediadive.solution:6099  biolink:has_part   ingredient:286
# 1340818  mediadive.solution:6246  biolink:has_part   ingredient:286
#
#             relation  provided_by knowledge_source
# 1249568  BFO:0000051          NaN            Graph
# 1249573  BFO:0000051          NaN            Graph
# 1249574  BFO:0000051          NaN            Graph
# 1249575  BFO:0000051          NaN            Graph
# 1249577  BFO:0000051          NaN            Graph
# ...              ...          ...              ...
# 1340686  BFO:0000051          NaN            Graph
# 1340700  BFO:0000051          NaN            Graph
# 1340803  BFO:0000051          NaN            Graph
# 1340809  BFO:0000051          NaN            Graph
# 1340818  BFO:0000051          NaN            Graph
#
# [1962 rows x 7 columns]
