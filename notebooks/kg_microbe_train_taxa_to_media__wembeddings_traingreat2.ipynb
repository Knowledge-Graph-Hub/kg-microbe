# %%
import sys
print(sys.path)
sys.path.append("../KE/")
print(sys.path)
# Out:
# ['/Users/marcin/Documents/VIMSS/ontology/KG-Hub/KG-Microbe/kg-microbe/notebooks', '/Users/marcin/.pyenv/versions/3.10.11/lib/python310.zip', '/Users/marcin/.pyenv/versions/3.10.11/lib/python3.10', '/Users/marcin/.pyenv/versions/3.10.11/lib/python3.10/lib-dynload', '', '/Users/marcin/Documents/VIMSS/ontology/KG-Hub/KG-Microbe/kg-microbe/notebooks/venv/lib/python3.10/site-packages']
# ['/Users/marcin/Documents/VIMSS/ontology/KG-Hub/KG-Microbe/kg-microbe/notebooks', '/Users/marcin/.pyenv/versions/3.10.11/lib/python310.zip', '/Users/marcin/.pyenv/versions/3.10.11/lib/python3.10', '/Users/marcin/.pyenv/versions/3.10.11/lib/python3.10/lib-dynload', '', '/Users/marcin/Documents/VIMSS/ontology/KG-Hub/KG-Microbe/kg-microbe/notebooks/venv/lib/python3.10/site-packages', '../KE/']

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, Pool, cv

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

from KE.classifier.prepare import split_dataset
from KE.dataclean import tables

# %%
import random
import numpy as np
import os

# %%
RANDOM_SEED = 12
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

random_seed = random.seed
print(random.seed)
print(np.random.get_state())
# Out:
# <bound method Random.seed of <random.Random object at 0x16006a410>>
# ('MT19937', array([        12,  274362557, 2871959443,   96505144, 3440553756,
#        3320819264, 1671863157, 2853726411, 3576948821, 2267721719,
#        1471449267,  205467717,  329644101, 2017124422,  120683281,
#        3671631556, 3425389459, 2306138081, 2854342561, 2833917538,
#        2139784180, 1777806526, 3803176561, 3129722129, 3441486743,
#        1830495613, 3911788038,  683126036, 2275605760, 2143413223,
#        1841233884, 3193124688, 3131946362,  854446201,  464715999,
#        3543117598, 3696335765,  563062867, 3171341285, 2053716298,
#        3493445055, 2373285717, 2744558717, 1005575494, 2549531338,
#        3054493973,  794434881,  553407444, 3342173908, 2703770116,
#        1986085520, 3203783784, 2832904198,  647337417,  715893123,
#        2584083430,  191194412,  374961813, 3419702787, 3499023931,
#        1892787284,  234508998, 1165532764, 2246131696,  884260026,
#         627310499,   95884945,  105283704, 1473832860, 1305568822,
#        3268526841, 3941578473, 2984010906, 4260431937, 1062310996,
#         568097135, 2130792471, 1207590651, 1936802544, 2837013092,
#          91646094, 1233993303, 2540674624, 2793980509, 1217562319,
#        2744479131,  214572723, 2433804278, 2407077788, 3048988591,
#        1468912795,  972114717, 1194338253,   31449049,  923628027,
#        3962194790, 2060176441, 3090778745,  657225193, 3305322064,
#        4070300195, 2518167301, 1709591849, 1866389807, 3729214862,
#        1971129866, 1294429633, 2324303147,  832643737, 1313179594,
#        1906783877, 2160141955, 2740337237, 3802043332, 1142344949,
#        2606330039, 2559399133,  944165744,  589847462,   25296629,
#        2121118753,   59584793, 3651780695, 1781650847,  273470930,
#        4252745303, 3740863394, 2095169540, 1895198585,  522793689,
#        1197879583, 3681316697, 2631211270, 1234305817, 1609240830,
#        2932812834, 2335803688,  809539611,  664761905, 3749763808,
#        3811497755, 3024008453, 2463050577, 4247814990, 3984786161,
#        4259425291,   55650234, 1264400117,  249250520,  657389517,
#        3669981559,  129367899, 3488772735,  995067781, 3330909459,
#        1091809259, 3176047086, 3256954553,  405731840, 2220008095,
#         468397457, 1243780054, 2141414261, 1943753063, 1440789474,
#        3508565044, 1098926425, 2688878687, 2738950745,  536605072,
#        3449577082, 1854867304, 2839813657, 1924748372, 2610086711,
#        2647744920, 4094487666, 1454948934, 1523426741, 1488696503,
#         784183938, 2934767615, 2490000519, 1499977264, 1592703757,
#        1671247989, 3949550206, 2003343628, 3246872541, 3615324499,
#        1000123726,   45162117, 3403233337, 1214265763, 4164710316,
#         694532046, 3005268746, 3917757165, 3912670892, 1749107410,
#        3863431431, 2941186909,  637328453, 1887884548, 2085927109,
#         564775457, 2551146707, 1189295172,  411012361, 2483779166,
#        2539712286, 4076360415, 3562302880, 3077602596,  107263700,
#        3680474747, 1904514608, 2231794478, 3786220854,  313265092,
#        1921550640, 2912967218,  131548622,  485214501, 3014535545,
#         507916648, 3153733354, 4175135339,  406592492,  236736769,
#        1535934283,   26399513, 2207558341,  410837100,  810702726,
#         234700489, 2399295289, 4080533044,  329497505, 1818833012,
#        3215047705, 2973149848, 3457399220,  606876966, 1777094386,
#        3978310100, 3644897737, 2793170857, 1010592367, 3587466692,
#        3283396477, 2690286513, 3524641179, 4065835509, 1826293004,
#        3346527264, 1424952783, 3109400903, 4019183163,  892773659,
#         614963115, 1878415996,  940153175,  607784794, 3231005066,
#         896075030, 2982267064, 3405102189,  600585842, 4258430471,
#        3952598178,  744699284, 2178701428, 1518341535, 1126231656,
#        3966976384,  102560963, 3720211716, 2398634969, 2202007934,
#         656722692, 1598373293, 3825623542, 1789117380,  751020757,
#        3882968102, 1465340087,  748568301, 4271286689,  229023755,
#        2461010041,  861547690, 1965070902,  333793240, 2748313950,
#        1387820659, 2940714530, 1055728585, 2184491127, 3228253268,
#        2818203263, 2479041918, 1304186650, 4284328406, 1621753657,
#        3073288777, 2325238729,  561886026, 2593150822, 3446865833,
#        1322703176, 3523922948,  765673211, 4210634048, 3730618281,
#         377778509, 1476258205, 3430262729, 1874611696, 2828515924,
#         384731950, 3940190311, 2247185590, 1064747079, 3434142791,
#         495143961, 2301978659, 2075311948,  755019689,  954580982,
#        1847157592, 1235080296, 2630877113,  268957972, 3606903346,
#        3070881700,  498426830, 1838915479,  736574848, 3232023763,
#        1342502756, 2585635118, 3715124146,  866555692,  970207668,
#        2872897885, 3654292181,  352712137,    6392489, 1884235530,
#        1617710005,   19477347, 2910208623, 2251262818, 2985844290,
#        3039654051, 3432684009, 1656943799, 3302617908,  665216282,
#        1819725482,  707136992, 3750779594, 3154666424, 3737379790,
#        1858901582, 2739967385,  169343638, 4071236766,  117667938,
#        1115222556, 3457420260, 3482866327,  492161497, 2362230035,
#        2981550636, 1462285214,  679999028, 1808922622, 1132941334,
#        4074760591,  421990841, 1559560315, 1161853857, 3053021088,
#        1900648043, 3899462484, 1304637910,  881834583, 1942885592,
#         392518691, 3259045462, 4042542609, 2292740259,  253860367,
#        2115817590,  338620287,  891844008, 3078968534, 2211179827,
#        1236979429, 3886523781,  727909744, 2181699267, 3211740345,
#        3620418140, 1438169105, 1959866343, 1618214230, 3250029548,
#         311096805,   61706740, 1145187040, 1865700706, 4211911853,
#        4113252421,  694145854, 2307688215,  105810411, 1849175642,
#         896925323, 3599946108, 2290261953, 1700619414, 1825472571,
#        1772987019, 1195572252,  388234780,  653541048, 1794455621,
#        2813827202, 2542513199,  981075057,  698039110, 2749422160,
#        2362050061,  660303007, 2156655472, 1553797040, 2972969868,
#         191688382, 2096095407,  916636768, 2280577947,   32540185,
#        2992065178, 1032046518,  148386445,  238315617, 1831868678,
#        1955569797, 3979147735, 3913090664, 4268739836, 1707694433,
#        3672417447, 1758247548, 3187505690,  301991234,  429942485,
#        2669908181, 2070689184, 4257960787, 4160598111, 1023136284,
#        1636754141, 4174069406, 3741104836, 1226518871,  108756675,
#        1625579461, 3216354859, 3959466245, 2648762167, 1407817411,
#         337923685,  554302645, 2787152454, 2835094194, 2425272655,
#        4136915521, 3226978283,  871696490, 2484276661,  836524567,
#        3267812344,  738926317,  678103656, 1671742704, 2348658174,
#         253067862, 1318482905, 3494006308, 1024243280, 2680471422,
#        3749505499, 2320817192, 3128121475,  560330199,  715853510,
#        1338952722, 3226579060, 2666221545, 4094184622, 3439974201,
#        2208691675,  100278679, 3603566990, 3623379869, 2208357715,
#        1042197491,  600040414, 3561797270, 2852964298, 3295468522,
#         268531184, 2453731764,  356445395, 2354404421, 2248173834,
#        1435941424,  829599838, 1563682080, 3137278224, 1447190566,
#        2729824368, 1231438088, 1097104284,  806800385,  741476214,
#         838146464,  331988531, 2093373235, 3645385423, 2482245778,
#         806853351, 1267121723, 2475432187, 3933347159, 3456337983,
#         888200648,  976194053, 1203839767, 3901988813,  157633638,
#         161725535, 2818648733,  647883230, 3414627514,  863055906,
#        2270704016, 2337321665, 1305863191, 2970404055, 3979519795,
#        2193926171, 4198151433, 1330759967,  934766852, 2980811971,
#        1754528597, 3274579541, 3418882080,  854575874, 3511495678,
#        3488072198, 2003254063, 1621621085, 2822479748,  747546647,
#         954049101, 4150738844, 2921411319,  940653030, 4094816252,
#         142354650, 3771648578, 1335465702,  766192229, 1660602652,
#        4267499445, 4099320595,  892145558, 3443027573, 4154113238,
#        2230157138, 3322219738, 3117233384, 1236081822, 2448843784,
#        1711592512,  256215284, 3949305492, 1259823844, 1953076139,
#         793984613, 2298391853, 3882974432,  969982693, 2011984816,
#        2953469997, 1994005476, 4231893171, 2877835211, 1571677609,
#         756712869, 1082067319, 2020140013, 1859074684, 4084857522,
#        3709838135, 2453551591,  818636477, 2774904822, 1811153322,
#        1540763102,  790983267, 2293374584, 2381009548,  384275057,
#        2748465665,  962373788, 2752381946, 4117711687], dtype=uint32), 624, 0, 0.0)

# %%
data = pd.read_csv("../data/merged/merged-kg_edges.tsv", header=0, sep="\t")
# Out:
# /var/folders/7w/ksxs106s7_sg14v6cb2y70vr0000gn/T/ipykernel_5939/2785372968.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/merged/merged-kg_edges.tsv", header=0, sep="\t")

# %%
data_pairs = data[['subject','object']].drop_duplicates()
data_pairs
# Out:
#                    subject                           object
# 0              NCBITaxon:1                      BFO:0000040
# 1             NCBITaxon:10                NCBITaxon:1706371
# 2            NCBITaxon:100                     NCBITaxon:99
# 3            NCBITaxon:100               mediadive.medium:7
# 4            NCBITaxon:100            mediadive.medium:J346
# ...                    ...                              ...
# 1538345   NCBITaxon:147448    traits.cell_shape_enum:coccus
# 1538346   NCBITaxon:147448                 ECOCORE:00000177
# 1538347  NCBITaxon:1240726  traits.cell_shape_enum:bacillus
# 1538348  NCBITaxon:1240783  traits.cell_shape_enum:bacillus
# 1538349  NCBITaxon:1248412    traits.cell_shape_enum:coccus
#
# [1537254 rows x 2 columns]

# %%
# Subset the DataFrame based on the substring in subject
data_pairs_clean = data_pairs[data_pairs['subject'].str.contains('NCBITaxon:')]
# Subset the DataFrame based on the substring in object
data_pairs_clean = data_pairs_clean[data_pairs_clean['object'].str.contains('mediadive.medium:')]
data_pairs_clean.to_csv("NCBITaxon_to_medium.tsv", sep="\t", header=True, index=False)
data_pairs_clean.shape
# Out:
# (32513, 2)

# %%
#TODO add closure

data_pairs_chem = data_pairs[data_pairs['subject'].str.contains('NCBITaxon:')]
data_pairs_chem = data_pairs_chem[data_pairs_chem['object'].str.contains('CHEBI:')]
data_pairs_chem.shape
# Out:
# (37667, 2)

# %%
#TODO add closure

data_pairs_go = data_pairs[data_pairs['subject'].str.contains('NCBITaxon:')]
data_pairs_go = data_pairs_go[data_pairs_go['object'].str.contains('GO:')]
data_pairs_go.shape
# Out:
# (2446, 2)

# %%
data_pairs_rest_all = data_pairs[data_pairs['subject'].str.contains('NCBITaxon:')]
data_pairs_rest = data_pairs_rest_all[data_pairs_rest_all['object'].str.contains('carbon_substrate:')]
data_pairs_rest2 = data_pairs_rest_all[data_pairs_rest_all['object'].str.contains('pathways:')]
data_pairs_rest = pd.concat([data_pairs_rest, data_pairs_rest2], ignore_index=True)
data_pairs_rest2 = data_pairs_rest_all[data_pairs_rest_all['object'].str.contains('cell_shape_enum:')]
data_pairs_rest = pd.concat([data_pairs_rest, data_pairs_rest2], ignore_index=True)
data_pairs_rest2 = data_pairs_rest_all[data_pairs_rest_all['object'].str.contains('data_source:')]
data_pairs_rest = pd.concat([data_pairs_rest, data_pairs_rest2], ignore_index=True)
data_pairs_rest2 = data_pairs_rest_all[data_pairs_rest_all['object'].str.contains('ENVO:')]
data_pairs_rest = pd.concat([data_pairs_rest, data_pairs_rest2], ignore_index=True)
data_pairs_rest2 = data_pairs_rest_all[data_pairs_rest_all['object'].str.contains('UBERON:')]
data_pairs_rest = pd.concat([data_pairs_rest, data_pairs_rest2], ignore_index=True)
data_pairs_rest.shape
# Out:
# (47187, 2)

# %%
data_df_pairs = pd.concat([data_pairs_chem, data_pairs_go], ignore_index=True)
data_df_pairs = pd.concat([data_df_pairs, data_pairs_rest], ignore_index=True)

data_df_pairs['Value'] = 1

# Step 2: Pivot the old DataFrame to form the new DataFrame structure
data_df = data_df_pairs.pivot(index='subject', columns='object', values='Value')

# Step 3: Fill NaN values with 0 to indicate no relationship
data_df = data_df.fillna(0)

# Optionally, convert the filled NaN values to integers if they were floats after pivot
data_df = data_df.astype(int)
data_df
# Out:
# object             CHEBI:132943  CHEBI:133748  CHEBI:14321  CHEBI:15361  \
# subject
# NCBITaxon:100                 0             0            0            0
# NCBITaxon:1000560             0             0            0            0
# NCBITaxon:1000561             0             0            0            0
# NCBITaxon:1000565             0             0            0            0
# NCBITaxon:1000567             0             0            0            0
# ...                         ...           ...          ...          ...
# NCBITaxon:999702              0             0            0            0
# NCBITaxon:999891              0             0            0            0
# NCBITaxon:999892              0             0            0            0
# NCBITaxon:999894              0             0            0            0
# NCBITaxon:999931              0             0            0            0
#
# object             CHEBI:15428  CHEBI:15792  CHEBI:15963  CHEBI:16015  \
# subject
# NCBITaxon:100                0            0            0            0
# NCBITaxon:1000560            0            0            0            0
# NCBITaxon:1000561            0            0            0            0
# NCBITaxon:1000565            0            0            0            0
# NCBITaxon:1000567            0            0            0            0
# ...                        ...          ...          ...          ...
# NCBITaxon:999702             0            0            0            0
# NCBITaxon:999891             0            0            0            0
# NCBITaxon:999892             0            0            0            0
# NCBITaxon:999894             0            0            0            0
# NCBITaxon:999931             0            0            0            0
#
# object             CHEBI:16133  CHEBI:16193  ...  \
# subject                                      ...
# NCBITaxon:100                0            0  ...
# NCBITaxon:1000560            0            0  ...
# NCBITaxon:1000561            0            0  ...
# NCBITaxon:1000565            0            0  ...
# NCBITaxon:1000567            0            0  ...
# ...                        ...          ...  ...
# NCBITaxon:999702             0            0  ...
# NCBITaxon:999891             0            0  ...
# NCBITaxon:999892             0            0  ...
# NCBITaxon:999894             0            0  ...
# NCBITaxon:999931             0            0  ...
#
# object             traits.pathways:thiocyanate_oxidation  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000560                                      0
# NCBITaxon:1000561                                      0
# NCBITaxon:1000565                                      0
# NCBITaxon:1000567                                      0
# ...                                                  ...
# NCBITaxon:999702                                       0
# NCBITaxon:999891                                       0
# NCBITaxon:999892                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:thiocyanate_reduction  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000560                                      0
# NCBITaxon:1000561                                      0
# NCBITaxon:1000565                                      0
# NCBITaxon:1000567                                      0
# ...                                                  ...
# NCBITaxon:999702                                       0
# NCBITaxon:999891                                       0
# NCBITaxon:999892                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:thiosulfate_disproportionation  \
# subject
# NCBITaxon:100                                                   0
# NCBITaxon:1000560                                               0
# NCBITaxon:1000561                                               0
# NCBITaxon:1000565                                               0
# NCBITaxon:1000567                                               0
# ...                                                           ...
# NCBITaxon:999702                                                0
# NCBITaxon:999891                                                0
# NCBITaxon:999892                                                0
# NCBITaxon:999894                                                0
# NCBITaxon:999931                                                0
#
# object             traits.pathways:thiosulfate_oxidation  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000560                                      0
# NCBITaxon:1000561                                      0
# NCBITaxon:1000565                                      0
# NCBITaxon:1000567                                      0
# ...                                                  ...
# NCBITaxon:999702                                       0
# NCBITaxon:999891                                       0
# NCBITaxon:999892                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:thiosulfate_oxidation_dark  \
# subject
# NCBITaxon:100                                               1
# NCBITaxon:1000560                                           0
# NCBITaxon:1000561                                           0
# NCBITaxon:1000565                                           0
# NCBITaxon:1000567                                           0
# ...                                                       ...
# NCBITaxon:999702                                            0
# NCBITaxon:999891                                            0
# NCBITaxon:999892                                            0
# NCBITaxon:999894                                            0
# NCBITaxon:999931                                            0
#
# object             traits.pathways:thiosulfate_reduction  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000560                                      0
# NCBITaxon:1000561                                      0
# NCBITaxon:1000565                                      0
# NCBITaxon:1000567                                      0
# ...                                                  ...
# NCBITaxon:999702                                       0
# NCBITaxon:999891                                       0
# NCBITaxon:999892                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:trithionate_oxidation  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000560                                      0
# NCBITaxon:1000561                                      0
# NCBITaxon:1000565                                      0
# NCBITaxon:1000567                                      0
# ...                                                  ...
# NCBITaxon:999702                                       0
# NCBITaxon:999891                                       0
# NCBITaxon:999892                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:uraninite_oxidation  \
# subject
# NCBITaxon:100                                        0
# NCBITaxon:1000560                                    0
# NCBITaxon:1000561                                    0
# NCBITaxon:1000565                                    0
# NCBITaxon:1000567                                    0
# ...                                                ...
# NCBITaxon:999702                                     0
# NCBITaxon:999891                                     0
# NCBITaxon:999892                                     0
# NCBITaxon:999894                                     0
# NCBITaxon:999931                                     0
#
# object             traits.pathways:uranium_oxidation  \
# subject
# NCBITaxon:100                                      0
# NCBITaxon:1000560                                  0
# NCBITaxon:1000561                                  0
# NCBITaxon:1000565                                  0
# NCBITaxon:1000567                                  0
# ...                                              ...
# NCBITaxon:999702                                   0
# NCBITaxon:999891                                   0
# NCBITaxon:999892                                   0
# NCBITaxon:999894                                   0
# NCBITaxon:999931                                   0
#
# object             traits.pathways:uranyl_reduction
# subject
# NCBITaxon:100                                     0
# NCBITaxon:1000560                                 0
# NCBITaxon:1000561                                 0
# NCBITaxon:1000565                                 0
# NCBITaxon:1000567                                 0
# ...                                             ...
# NCBITaxon:999702                                  0
# NCBITaxon:999891                                  0
# NCBITaxon:999892                                  0
# NCBITaxon:999894                                  0
# NCBITaxon:999931                                  0
#
# [29522 rows x 267 columns]

# %%
subject_object_mapping = data_pairs_clean.set_index('subject')['object'].to_dict()

# Use the map function to create a new column in 'new_dataframe' from the 'subject' indices
data_df['medium'] = data_df.index.map(subject_object_mapping)

# %%
data_df['medium'].isna().sum()
# Out:
# 20368

# %%
data_df_orig = data_df.copy()
data_df = data_df[data_df['medium'].notna()]
data_df
# Out:
# object             CHEBI:132943  CHEBI:133748  CHEBI:14321  CHEBI:15361  \
# subject
# NCBITaxon:100                 0             0            0            0
# NCBITaxon:1000568             0             0            0            0
# NCBITaxon:1001                0             0            0            0
# NCBITaxon:1001240             0             1            0            0
# NCBITaxon:100133              0             0            0            0
# ...                         ...           ...          ...          ...
# NCBITaxon:999550              0             0            0            0
# NCBITaxon:999552              0             0            0            0
# NCBITaxon:999611              0             0            0            0
# NCBITaxon:999894              0             0            0            0
# NCBITaxon:999931              0             0            0            0
#
# object             CHEBI:15428  CHEBI:15792  CHEBI:15963  CHEBI:16015  \
# subject
# NCBITaxon:100                0            0            0            0
# NCBITaxon:1000568            0            0            0            0
# NCBITaxon:1001               0            0            0            0
# NCBITaxon:1001240            0            1            0            0
# NCBITaxon:100133             0            0            0            0
# ...                        ...          ...          ...          ...
# NCBITaxon:999550             0            0            0            0
# NCBITaxon:999552             0            0            0            0
# NCBITaxon:999611             0            0            0            0
# NCBITaxon:999894             0            0            0            0
# NCBITaxon:999931             0            0            0            0
#
# object             CHEBI:16133  CHEBI:16193  ...  \
# subject                                      ...
# NCBITaxon:100                0            0  ...
# NCBITaxon:1000568            0            0  ...
# NCBITaxon:1001               0            0  ...
# NCBITaxon:1001240            0            0  ...
# NCBITaxon:100133             0            0  ...
# ...                        ...          ...  ...
# NCBITaxon:999550             0            0  ...
# NCBITaxon:999552             0            0  ...
# NCBITaxon:999611             0            0  ...
# NCBITaxon:999894             0            0  ...
# NCBITaxon:999931             0            0  ...
#
# object             traits.pathways:thiocyanate_reduction  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001                                         0
# NCBITaxon:1001240                                      0
# NCBITaxon:100133                                       0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:thiosulfate_disproportionation  \
# subject
# NCBITaxon:100                                                   0
# NCBITaxon:1000568                                               0
# NCBITaxon:1001                                                  0
# NCBITaxon:1001240                                               0
# NCBITaxon:100133                                                0
# ...                                                           ...
# NCBITaxon:999550                                                0
# NCBITaxon:999552                                                0
# NCBITaxon:999611                                                0
# NCBITaxon:999894                                                0
# NCBITaxon:999931                                                0
#
# object             traits.pathways:thiosulfate_oxidation  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001                                         0
# NCBITaxon:1001240                                      0
# NCBITaxon:100133                                       0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:thiosulfate_oxidation_dark  \
# subject
# NCBITaxon:100                                               1
# NCBITaxon:1000568                                           0
# NCBITaxon:1001                                              0
# NCBITaxon:1001240                                           0
# NCBITaxon:100133                                            0
# ...                                                       ...
# NCBITaxon:999550                                            0
# NCBITaxon:999552                                            0
# NCBITaxon:999611                                            0
# NCBITaxon:999894                                            0
# NCBITaxon:999931                                            0
#
# object             traits.pathways:thiosulfate_reduction  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001                                         0
# NCBITaxon:1001240                                      0
# NCBITaxon:100133                                       0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:trithionate_oxidation  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001                                         0
# NCBITaxon:1001240                                      0
# NCBITaxon:100133                                       0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:uraninite_oxidation  \
# subject
# NCBITaxon:100                                        0
# NCBITaxon:1000568                                    0
# NCBITaxon:1001                                       0
# NCBITaxon:1001240                                    0
# NCBITaxon:100133                                     0
# ...                                                ...
# NCBITaxon:999550                                     0
# NCBITaxon:999552                                     0
# NCBITaxon:999611                                     0
# NCBITaxon:999894                                     0
# NCBITaxon:999931                                     0
#
# object             traits.pathways:uranium_oxidation  \
# subject
# NCBITaxon:100                                      0
# NCBITaxon:1000568                                  0
# NCBITaxon:1001                                     0
# NCBITaxon:1001240                                  0
# NCBITaxon:100133                                   0
# ...                                              ...
# NCBITaxon:999550                                   0
# NCBITaxon:999552                                   0
# NCBITaxon:999611                                   0
# NCBITaxon:999894                                   0
# NCBITaxon:999931                                   0
#
# object             traits.pathways:uranyl_reduction                  medium
# subject
# NCBITaxon:100                                     0     mediadive.medium:81
# NCBITaxon:1000568                                 0    mediadive.medium:110
# NCBITaxon:1001                                    0    mediadive.medium:668
# NCBITaxon:1001240                                 0     mediadive.medium:92
# NCBITaxon:100133                                  0    mediadive.medium:860
# ...                                             ...                     ...
# NCBITaxon:999550                                  0   mediadive.medium:J118
# NCBITaxon:999552                                  0    mediadive.medium:514
# NCBITaxon:999611                                  0    mediadive.medium:514
# NCBITaxon:999894                                  0  mediadive.medium:1210a
# NCBITaxon:999931                                  0    mediadive.medium:J26
#
# [9154 rows x 268 columns]

# %%
data_df_clean = data_df.groupby('medium').filter(lambda x : len(x)>2)
data_df_clean
# Out:
# object             CHEBI:132943  CHEBI:133748  CHEBI:14321  CHEBI:15361  \
# subject
# NCBITaxon:100                 0             0            0            0
# NCBITaxon:1000568             0             0            0            0
# NCBITaxon:1001240             0             1            0            0
# NCBITaxon:1002367             0             0            0            0
# NCBITaxon:1002368             0             0            0            0
# ...                         ...           ...          ...          ...
# NCBITaxon:999550              0             0            0            0
# NCBITaxon:999552              0             0            0            0
# NCBITaxon:999611              0             0            0            0
# NCBITaxon:999894              0             0            0            0
# NCBITaxon:999931              0             0            0            0
#
# object             CHEBI:15428  CHEBI:15792  CHEBI:15963  CHEBI:16015  \
# subject
# NCBITaxon:100                0            0            0            0
# NCBITaxon:1000568            0            0            0            0
# NCBITaxon:1001240            0            1            0            0
# NCBITaxon:1002367            0            0            0            0
# NCBITaxon:1002368            0            0            0            0
# ...                        ...          ...          ...          ...
# NCBITaxon:999550             0            0            0            0
# NCBITaxon:999552             0            0            0            0
# NCBITaxon:999611             0            0            0            0
# NCBITaxon:999894             0            0            0            0
# NCBITaxon:999931             0            0            0            0
#
# object             CHEBI:16133  CHEBI:16193  ...  \
# subject                                      ...
# NCBITaxon:100                0            0  ...
# NCBITaxon:1000568            0            0  ...
# NCBITaxon:1001240            0            0  ...
# NCBITaxon:1002367            0            0  ...
# NCBITaxon:1002368            0            0  ...
# ...                        ...          ...  ...
# NCBITaxon:999550             0            0  ...
# NCBITaxon:999552             0            0  ...
# NCBITaxon:999611             0            0  ...
# NCBITaxon:999894             0            0  ...
# NCBITaxon:999931             0            0  ...
#
# object             traits.pathways:thiocyanate_reduction  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001240                                      0
# NCBITaxon:1002367                                      0
# NCBITaxon:1002368                                      0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:thiosulfate_disproportionation  \
# subject
# NCBITaxon:100                                                   0
# NCBITaxon:1000568                                               0
# NCBITaxon:1001240                                               0
# NCBITaxon:1002367                                               0
# NCBITaxon:1002368                                               0
# ...                                                           ...
# NCBITaxon:999550                                                0
# NCBITaxon:999552                                                0
# NCBITaxon:999611                                                0
# NCBITaxon:999894                                                0
# NCBITaxon:999931                                                0
#
# object             traits.pathways:thiosulfate_oxidation  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001240                                      0
# NCBITaxon:1002367                                      0
# NCBITaxon:1002368                                      0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:thiosulfate_oxidation_dark  \
# subject
# NCBITaxon:100                                               1
# NCBITaxon:1000568                                           0
# NCBITaxon:1001240                                           0
# NCBITaxon:1002367                                           0
# NCBITaxon:1002368                                           0
# ...                                                       ...
# NCBITaxon:999550                                            0
# NCBITaxon:999552                                            0
# NCBITaxon:999611                                            0
# NCBITaxon:999894                                            0
# NCBITaxon:999931                                            0
#
# object             traits.pathways:thiosulfate_reduction  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001240                                      0
# NCBITaxon:1002367                                      0
# NCBITaxon:1002368                                      0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:trithionate_oxidation  \
# subject
# NCBITaxon:100                                          0
# NCBITaxon:1000568                                      0
# NCBITaxon:1001240                                      0
# NCBITaxon:1002367                                      0
# NCBITaxon:1002368                                      0
# ...                                                  ...
# NCBITaxon:999550                                       0
# NCBITaxon:999552                                       0
# NCBITaxon:999611                                       0
# NCBITaxon:999894                                       0
# NCBITaxon:999931                                       0
#
# object             traits.pathways:uraninite_oxidation  \
# subject
# NCBITaxon:100                                        0
# NCBITaxon:1000568                                    0
# NCBITaxon:1001240                                    0
# NCBITaxon:1002367                                    0
# NCBITaxon:1002368                                    0
# ...                                                ...
# NCBITaxon:999550                                     0
# NCBITaxon:999552                                     0
# NCBITaxon:999611                                     0
# NCBITaxon:999894                                     0
# NCBITaxon:999931                                     0
#
# object             traits.pathways:uranium_oxidation  \
# subject
# NCBITaxon:100                                      0
# NCBITaxon:1000568                                  0
# NCBITaxon:1001240                                  0
# NCBITaxon:1002367                                  0
# NCBITaxon:1002368                                  0
# ...                                              ...
# NCBITaxon:999550                                   0
# NCBITaxon:999552                                   0
# NCBITaxon:999611                                   0
# NCBITaxon:999894                                   0
# NCBITaxon:999931                                   0
#
# object             traits.pathways:uranyl_reduction                  medium
# subject
# NCBITaxon:100                                     0     mediadive.medium:81
# NCBITaxon:1000568                                 0    mediadive.medium:110
# NCBITaxon:1001240                                 0     mediadive.medium:92
# NCBITaxon:1002367                                 0    mediadive.medium:J14
# NCBITaxon:1002368                                 0    mediadive.medium:J12
# ...                                             ...                     ...
# NCBITaxon:999550                                  0   mediadive.medium:J118
# NCBITaxon:999552                                  0    mediadive.medium:514
# NCBITaxon:999611                                  0    mediadive.medium:514
# NCBITaxon:999894                                  0  mediadive.medium:1210a
# NCBITaxon:999931                                  0    mediadive.medium:J26
#
# [7839 rows x 268 columns]

# %%
import pickle

#DeepWalkSkipGramEnsmallen_degreenorm_embedding_2023-11-29_10_24_15.pkl
#DeepWalkSkipGramEnsmallen_degreenorm_embedding_2024-01-08_00_23_18.pkl
pickle_filename = 'DeepWalkSkipGramEnsmallen_degreenorm_embedding_2024-01-08_00_23_18.pkl'

with open(pickle_filename, 'rb') as file:
    # Use the 'rb' mode to read in binary mode
    DeepWalkSkipGramEnsmallen_degreenorm_embedding = pickle.load(file)

# %%
type(DeepWalkSkipGramEnsmallen_degreenorm_embedding)
# Out:
# embiggen.utils.abstract_models.embedding_result.EmbeddingResult

# %%
node_embed = DeepWalkSkipGramEnsmallen_degreenorm_embedding.get_all_node_embedding()[0]

# %%
node_embed2 = DeepWalkSkipGramEnsmallen_degreenorm_embedding.get_all_node_embedding()[1]

# %%
type(node_embed)
# Out:
# pandas.core.frame.DataFrame

# %%
node_embed
# Out:
#                                    0         1         2         3         4   \
# NCBITaxon:1000003           -1.031455  1.349113  1.899774 -0.946336 -0.109856
# NCBITaxon:1000010           -1.157560  1.225671  0.580858  1.201925 -0.718344
# NCBITaxon:1000018           -2.505306 -1.925052  0.932496 -0.718516  1.207053
# NCBITaxon:1000025           -1.082069 -0.767280  1.703067 -0.904418 -0.203546
# NCBITaxon:1000032            2.325878  1.584836  2.900095 -1.365675 -0.001004
# ...                               ...       ...       ...       ...       ...
# NCBITaxon:1659714            0.775793 -0.679273  0.092945 -0.048980  0.397659
# NCBITaxon:1870946            1.050766 -0.580509  0.258101  0.504690  1.080931
# NCBITaxon:1870956            0.670182 -0.607658 -0.074437  0.480364  0.486737
# NCBITaxon:1967661            0.904905 -0.498616 -0.421741  0.243026  0.412067
# traits.cell_shape_enum:ring  0.172603 -0.506463  1.473414  4.455378 -3.381436
#
#                                    5         6         7         8         9   \
# NCBITaxon:1000003           -1.593317 -1.848653 -0.062838  2.012377  1.241247
# NCBITaxon:1000010           -1.292087 -1.950941 -2.336847  1.339372 -1.365434
# NCBITaxon:1000018           -1.530640 -1.440780  0.547364 -1.201462  1.486149
# NCBITaxon:1000025           -0.306053 -3.343982 -0.781077  1.511115 -0.674152
# NCBITaxon:1000032           -2.111284 -2.778858  0.237287 -1.709499 -0.305866
# ...                               ...       ...       ...       ...       ...
# NCBITaxon:1659714            0.614983 -0.502394 -0.500043  1.399469  0.221401
# NCBITaxon:1870946            0.220780 -1.228080 -0.117243  1.517538  0.180042
# NCBITaxon:1870956            0.750590 -1.025770 -0.774118  1.334956  0.296615
# NCBITaxon:1967661            0.728597 -0.875614 -0.539034  1.267377  0.087819
# traits.cell_shape_enum:ring -1.683776 -2.428026  1.376238  1.325544 -2.302459
#
#                              ...        90        91        92        93  \
# NCBITaxon:1000003            ... -0.479338  0.196126  2.574927  0.329952
# NCBITaxon:1000010            ... -1.155502  1.589112  0.693132 -0.746466
# NCBITaxon:1000018            ...  0.110403  0.416665  1.319849  2.196532
# NCBITaxon:1000025            ... -0.333874 -2.003359  1.099833  2.473160
# NCBITaxon:1000032            ... -1.601846  0.405566  1.550465  0.972813
# ...                          ...       ...       ...       ...       ...
# NCBITaxon:1659714            ... -0.084529 -0.068886  0.804680 -0.149316
# NCBITaxon:1870946            ...  0.575155 -0.005054  1.095349  0.270433
# NCBITaxon:1870956            ... -0.003220 -0.028009  0.600880  0.036342
# NCBITaxon:1967661            ... -0.344265 -0.407782  1.151033  0.171674
# traits.cell_shape_enum:ring  ...  1.402529  1.382439  2.231616  3.728646
#
#                                    94        95        96        97        98  \
# NCBITaxon:1000003            0.043694  0.019184 -0.231998 -1.139623 -0.812228
# NCBITaxon:1000010           -1.932839  0.734429 -0.395581 -1.539705 -2.177659
# NCBITaxon:1000018            0.006788 -0.624915  1.991254 -1.983693  2.009059
# NCBITaxon:1000025           -2.325198  1.050515  0.582174 -1.295575 -0.671583
# NCBITaxon:1000032           -0.591192  0.754095 -0.079234 -3.035640 -0.218694
# ...                               ...       ...       ...       ...       ...
# NCBITaxon:1659714            0.027359  0.376390  0.335816 -1.904072 -0.194623
# NCBITaxon:1870946           -0.270216  0.596595  0.201780 -2.196196 -0.409648
# NCBITaxon:1870956            0.093275  0.545338  0.203868 -2.020937  0.245998
# NCBITaxon:1967661           -0.133862  0.878476  0.008379 -1.762125  0.271346
# traits.cell_shape_enum:ring -0.355664  0.898559  0.226421 -0.970270  0.871703
#
#                                    99
# NCBITaxon:1000003            1.687592
# NCBITaxon:1000010            0.478125
# NCBITaxon:1000018            0.663362
# NCBITaxon:1000025           -0.050192
# NCBITaxon:1000032            0.483170
# ...                               ...
# NCBITaxon:1659714            0.076194
# NCBITaxon:1870946            0.082531
# NCBITaxon:1870956           -0.318171
# NCBITaxon:1967661           -0.086053
# traits.cell_shape_enum:ring -1.690973
#
# [1080337 rows x 100 columns]

# %%
node_embed2
# Out:
#                                    0         1         2         3         4   \
# NCBITaxon:1000003           -0.851284  0.988857  0.371988 -1.214423  0.268440
# NCBITaxon:1000010           -0.829608  1.244923 -1.224069  0.476604 -0.947860
# NCBITaxon:1000018           -2.184090 -2.246455 -0.275248 -1.365230  0.978455
# NCBITaxon:1000025           -0.732894 -1.169684  0.234325 -0.850819  0.017477
# NCBITaxon:1000032            3.059520  1.342080  1.604109 -1.334065  0.015293
# ...                               ...       ...       ...       ...       ...
# NCBITaxon:1659714            1.243117 -0.947247 -1.173451 -0.129000  0.579661
# NCBITaxon:1870946            1.721317 -1.331585 -0.380885  0.199079  1.057520
# NCBITaxon:1870956            1.853584 -1.377037 -0.807550  0.109291  1.025742
# NCBITaxon:1967661            1.434538 -1.525860 -1.160817 -0.149080  0.347281
# traits.cell_shape_enum:ring  0.001546 -0.071930  0.445395  4.051243 -2.317745
#
#                                    5         6         7         8         9   \
# NCBITaxon:1000003            0.415412  1.156210  3.355280  0.595030  2.313853
# NCBITaxon:1000010            0.627461  0.869151  0.402238  0.197349 -0.401606
# NCBITaxon:1000018            0.640932  1.945370  4.054640 -2.357964  2.762495
# NCBITaxon:1000025            1.641452  0.107905  2.603926  0.010028  0.617788
# NCBITaxon:1000032           -0.523136  0.756624  3.455146 -3.216451  0.835972
# ...                               ...       ...       ...       ...       ...
# NCBITaxon:1659714            1.990377  1.568887  1.804997  0.836340  0.826854
# NCBITaxon:1870946            1.352228  0.816803  2.050873  0.692222  0.598289
# NCBITaxon:1870956            2.130585  0.881312  1.619169  0.796440  0.537708
# NCBITaxon:1967661            1.425932  0.928340  1.587843  1.054680  0.743261
# traits.cell_shape_enum:ring  2.201210  1.448390  4.274484 -0.021114  0.153821
#
#                              ...        90        91        92        93  \
# NCBITaxon:1000003            ...  1.857498 -1.404233 -0.263133 -1.065219
# NCBITaxon:1000010            ...  0.419021  0.421658 -1.251403 -1.795962
# NCBITaxon:1000018            ...  2.169084 -1.206666 -1.090588  0.582834
# NCBITaxon:1000025            ...  2.087486 -3.625146 -1.904850  0.770218
# NCBITaxon:1000032            ...  0.265562 -1.056380 -1.488469 -0.743376
# ...                          ...       ...       ...       ...       ...
# NCBITaxon:1659714            ...  1.538858 -1.052069 -1.159192 -1.298251
# NCBITaxon:1870946            ...  1.916509 -0.962924 -1.572387 -1.105794
# NCBITaxon:1870956            ...  1.660294 -1.096766 -1.666212 -1.308544
# NCBITaxon:1967661            ...  1.539290 -1.178815 -1.249957 -0.754260
# traits.cell_shape_enum:ring  ...  2.698028 -0.044157 -0.012263  1.526609
#
#                                    94        95        96        97        98  \
# NCBITaxon:1000003            0.319012 -0.311994  0.958230  3.430695  0.509267
# NCBITaxon:1000010           -1.580469  0.866128  0.632690  2.538226 -0.402535
# NCBITaxon:1000018            0.581564 -1.147194  2.670822  2.548922  3.287714
# NCBITaxon:1000025           -1.823285  0.713638  1.886540  3.502179  1.058140
# NCBITaxon:1000032            0.029394  0.374867  1.028236  1.747947  1.130074
# ...                               ...       ...       ...       ...       ...
# NCBITaxon:1659714           -0.026122  0.498160  1.337344  1.443885  1.448357
# NCBITaxon:1870946           -0.263860  0.346044  1.662415  1.505355  1.524117
# NCBITaxon:1870956            0.241269  0.294879  1.871052  1.288712  1.587830
# NCBITaxon:1967661           -0.100542  0.849967  1.272003  1.876271  1.900160
# traits.cell_shape_enum:ring  0.149024 -0.144607  0.750112  3.148416  2.202387
#
#                                    99
# NCBITaxon:1000003            1.592615
# NCBITaxon:1000010            0.114112
# NCBITaxon:1000018            0.368422
# NCBITaxon:1000025            0.029119
# NCBITaxon:1000032            0.605635
# ...                               ...
# NCBITaxon:1659714            0.287928
# NCBITaxon:1870946            0.331351
# NCBITaxon:1870956           -0.404584
# NCBITaxon:1967661            0.189842
# traits.cell_shape_enum:ring -2.019594
#
# [1080337 rows x 100 columns]

# %%
data_df_join_embed = data_df_clean.join(node_embed, how='left')
data_df_join_embed
# Out:
#                    CHEBI:132943  CHEBI:133748  CHEBI:14321  CHEBI:15361  \
# subject
# NCBITaxon:100                 0             0            0            0
# NCBITaxon:1000568             0             0            0            0
# NCBITaxon:1001240             0             1            0            0
# NCBITaxon:1002367             0             0            0            0
# NCBITaxon:1002368             0             0            0            0
# ...                         ...           ...          ...          ...
# NCBITaxon:999550              0             0            0            0
# NCBITaxon:999552              0             0            0            0
# NCBITaxon:999611              0             0            0            0
# NCBITaxon:999894              0             0            0            0
# NCBITaxon:999931              0             0            0            0
#
#                    CHEBI:15428  CHEBI:15792  CHEBI:15963  CHEBI:16015  \
# subject
# NCBITaxon:100                0            0            0            0
# NCBITaxon:1000568            0            0            0            0
# NCBITaxon:1001240            0            1            0            0
# NCBITaxon:1002367            0            0            0            0
# NCBITaxon:1002368            0            0            0            0
# ...                        ...          ...          ...          ...
# NCBITaxon:999550             0            0            0            0
# NCBITaxon:999552             0            0            0            0
# NCBITaxon:999611             0            0            0            0
# NCBITaxon:999894             0            0            0            0
# NCBITaxon:999931             0            0            0            0
#
#                    CHEBI:16133  CHEBI:16193  ...        90        91  \
# subject                                      ...
# NCBITaxon:100                0            0  ...  1.730656  1.075262
# NCBITaxon:1000568            0            0  ... -1.273403 -0.285484
# NCBITaxon:1001240            0            0  ... -1.679868  2.347212
# NCBITaxon:1002367            0            0  ... -0.967366  0.464502
# NCBITaxon:1002368            0            0  ...  0.258961 -1.683862
# ...                        ...          ...  ...       ...       ...
# NCBITaxon:999550             0            0  ... -0.989938  0.802619
# NCBITaxon:999552             0            0  ... -2.326306  2.900110
# NCBITaxon:999611             0            0  ... -0.890035 -0.195962
# NCBITaxon:999894             0            0  ...  0.400278 -0.335466
# NCBITaxon:999931             0            0  ... -0.384625  1.290313
#
#                          92        93        94        95        96        97  \
# subject
# NCBITaxon:100      0.128118  1.590053 -0.593713 -0.872599 -2.279143 -1.198460
# NCBITaxon:1000568  2.894019 -0.588553  0.304278 -1.362631  1.137794 -1.717054
# NCBITaxon:1001240  1.442551  1.449241 -0.497471 -2.567467  0.990777 -3.253783
# NCBITaxon:1002367  2.348836 -0.078550 -0.552918 -0.208043  1.133552 -1.544743
# NCBITaxon:1002368  0.433024  0.270735 -2.204029 -2.115252  1.392747 -1.801429
# ...                     ...       ...       ...       ...       ...       ...
# NCBITaxon:999550   1.274777  0.600908 -0.676428 -1.974637 -2.023367  0.059113
# NCBITaxon:999552  -0.493073  1.381404 -1.819567 -1.161649 -0.548093 -0.653385
# NCBITaxon:999611   0.829923  0.631836 -0.631055 -2.101332 -1.256189 -1.757710
# NCBITaxon:999894   1.557171  2.635607  1.380304 -1.782371 -0.636449 -2.175351
# NCBITaxon:999931   0.545197 -0.234671 -0.757928 -3.666499 -0.565963  0.049104
#
#                          98        99
# subject
# NCBITaxon:100     -0.404164  2.227181
# NCBITaxon:1000568 -1.512253  0.825833
# NCBITaxon:1001240 -0.956055 -2.034431
# NCBITaxon:1002367 -1.716866  1.727506
# NCBITaxon:1002368 -1.007289 -0.213884
# ...                     ...       ...
# NCBITaxon:999550  -0.978106  0.161313
# NCBITaxon:999552  -0.070399  0.790302
# NCBITaxon:999611  -2.034944 -0.066591
# NCBITaxon:999894  -1.565963  0.463269
# NCBITaxon:999931  -1.156607  1.643568
#
# [7839 rows x 368 columns]

# %%
data_df_join_embed2 = data_df_join_embed.join(node_embed2, how='left', lsuffix='_left', rsuffix='_right')
data_df_join_embed2
# Out:
#                    CHEBI:132943  CHEBI:133748  CHEBI:14321  CHEBI:15361  \
# subject
# NCBITaxon:100                 0             0            0            0
# NCBITaxon:1000568             0             0            0            0
# NCBITaxon:1001240             0             1            0            0
# NCBITaxon:1002367             0             0            0            0
# NCBITaxon:1002368             0             0            0            0
# ...                         ...           ...          ...          ...
# NCBITaxon:999550              0             0            0            0
# NCBITaxon:999552              0             0            0            0
# NCBITaxon:999611              0             0            0            0
# NCBITaxon:999894              0             0            0            0
# NCBITaxon:999931              0             0            0            0
#
#                    CHEBI:15428  CHEBI:15792  CHEBI:15963  CHEBI:16015  \
# subject
# NCBITaxon:100                0            0            0            0
# NCBITaxon:1000568            0            0            0            0
# NCBITaxon:1001240            0            1            0            0
# NCBITaxon:1002367            0            0            0            0
# NCBITaxon:1002368            0            0            0            0
# ...                        ...          ...          ...          ...
# NCBITaxon:999550             0            0            0            0
# NCBITaxon:999552             0            0            0            0
# NCBITaxon:999611             0            0            0            0
# NCBITaxon:999894             0            0            0            0
# NCBITaxon:999931             0            0            0            0
#
#                    CHEBI:16133  CHEBI:16193  ...  90_right  91_right  \
# subject                                      ...
# NCBITaxon:100                0            0  ...  3.893311 -1.145257
# NCBITaxon:1000568            0            0  ...  0.162629 -2.273246
# NCBITaxon:1001240            0            0  ...  1.029343  0.536299
# NCBITaxon:1002367            0            0  ...  0.960424 -0.780511
# NCBITaxon:1002368            0            0  ...  1.928981 -2.795320
# ...                        ...          ...  ...       ...       ...
# NCBITaxon:999550             0            0  ... -0.049724 -0.516063
# NCBITaxon:999552             0            0  ...  0.070490  1.371192
# NCBITaxon:999611             0            0  ...  1.084973 -2.020291
# NCBITaxon:999894             0            0  ...  2.085337 -1.646832
# NCBITaxon:999931             0            0  ...  2.522063 -1.444947
#
#                    92_right  93_right  94_right  95_right  96_right  97_right  \
# subject
# NCBITaxon:100     -3.463747 -0.252844  0.133187 -1.350825  0.083498  3.950952
# NCBITaxon:1000568 -0.231700 -1.809598  0.860964 -1.626807  2.129407  2.420233
# NCBITaxon:1001240 -1.034751  0.200735  0.113141 -2.872515  2.464246  1.199523
# NCBITaxon:1002367 -0.646330 -1.586410  0.755049 -0.351068  2.620379  2.629001
# NCBITaxon:1002368 -1.476254 -1.480178 -1.754710 -1.293914  2.666051  2.554238
# ...                     ...       ...       ...       ...       ...       ...
# NCBITaxon:999550  -1.122472 -0.143546 -0.048471 -2.532022 -0.995582  4.884026
# NCBITaxon:999552  -4.092691 -0.763367 -1.182081 -1.621842  1.111404  4.208204
# NCBITaxon:999611  -3.073536 -0.745622  0.092240 -2.240415  0.518260  2.996253
# NCBITaxon:999894  -1.290929  1.334986  2.118105 -1.841994  1.291684  1.864662
# NCBITaxon:999931  -2.763537 -1.992221  0.053032 -3.819162  1.247208  5.129158
#
#                    98_right  99_right
# subject
# NCBITaxon:100      1.296036  2.421812
# NCBITaxon:1000568 -0.656849  1.032531
# NCBITaxon:1001240  0.352270 -1.801784
# NCBITaxon:1002367 -0.215337  3.405646
# NCBITaxon:1002368  0.308699 -0.621719
# ...                     ...       ...
# NCBITaxon:999550   0.669134  0.102672
# NCBITaxon:999552   1.606825  0.705671
# NCBITaxon:999611  -0.029722  0.635136
# NCBITaxon:999894  -0.330740  0.479305
# NCBITaxon:999931   1.141941  2.124608
#
# [7839 rows x 468 columns]

# %%
# Splitting the data into features and target labels
X = data_df_join_embed2.drop('medium', axis=1)#data_pairs_clean[['subject']]
y = data_df_join_embed2['medium']

# Convert the input labels column to a categorical type if it isn't
#X['subject'] = X['subject'].astype('category')

# Convert categorical columns to integers
#X['subject'] = X['subject'].cat.codes

# %%
len(set(data_df_join_embed2['medium']))
# Out:
# 317

# %%
len(set(data_df['medium']))
# Out:
# 1419

# %%
X.shape
# Out:
# (7839, 467)

# %%
len(y)
# Out:
# 7839

# %%
#X.reset_index(drop=True, inplace=True)
#y.reset_index(drop=True, inplace=True)

# %%
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size=0.7, stratify=y)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5488, 467)
# (2351, 467)

# %%
# Check if there are any common indices between X_train and X_test
common_indices = np.intersect1d(X_train.index, X_test.index)
print(f"Number of common indices: {len(common_indices)}")

# %%
train_data = Pool(data=X_train, label=y_train, cat_features=[0])
test_data = Pool(data=X_test, label=y_test, cat_features=[0])

# %%
###
### WARNINIG - this code has a bug that inflates the test samples
###

import numpy as np
from sklearn.model_selection import train_test_split

def custom_stratified_split(X, y, test_size=0.2, RANDOM_SEED=None):
    unique_classes, class_counts = np.unique(y, return_counts=True)
    print("class_counts"+str(class_counts))
    train_indices = []
    test_indices = []
    total_test_allocated = 0  # Keep track of the total number of test instances allocated

    total_count = len(y)
    total_test_size = int(np.round(total_count * test_size))

    for cls, count in zip(unique_classes, class_counts):
        cls_indices = np.where(y == cls)[0]

        if count < 10:
            if count > 1:
                n_test = min(2, count - 1)
            else:
                n_test = 1  # Only one instance, test it
        else:
            n_test = int(np.round(count * test_size))

        print("count/test "+str(count)+"\t"+str(n_test))
        n_train = count - n_test

        # Debug print
        print(f"Class {cls}, Count: {count}, Train: {n_train}, Test: {n_test}")

        total_test_allocated += n_test
        print(f"Running Total Test Allocated: {total_test_allocated}")  # Running total

        cls_train_indices, cls_test_indices = train_test_split(cls_indices, train_size=n_train, test_size=n_test, random_state=RANDOM_SEED)
        train_indices.extend(cls_train_indices)
        test_indices.extend(cls_test_indices)

    # Shuffle the indices to mix different classes
    np.random.seed(RANDOM_SEED)
    np.random.shuffle(train_indices)
    np.random.seed(RANDOM_SEED)
    np.random.shuffle(test_indices)

    # Split the data
    X_train = X.iloc[train_indices]
    y_train = y.iloc[train_indices]
    X_test = X.iloc[test_indices]
    y_test = y.iloc[test_indices]

    # Final Debug Prints
    print(f"Total instances: {total_count}")
    print(f"Expected test instances: {total_test_size}")
    print(f"Allocated test instances: {total_test_allocated}")

    return X_train, X_test, y_train, y_test

# %%
#Y_train, X_test, y_train, y_test = custom_stratified_split(X, y, 0.2, RANDOM_SEED)
#print(X_train.shape)
#print(X_test.shape)
# Out:
# class_counts[358   5   4   6  95   4  30  14   6   6  46 151  48   9   5   8   9  14
#    4   8   6  14  15   4   8   4   5  18   9   5   4  11   5   4  17   6
#    4   5   4  10  12   4   6  13  56   7  60   7   7 248  10   7   4   6
#    5   6  37   6  31  18   5   4  10   8   8  17  11  17   5  21  24  12
#    6   8  10  10  13  44   5   4   5  18   6  13   7   4  13   5   5   4
#  661  16  16  28   9   9   7  28 298  22  24   4  58  69  25  13  40   5
#    9   4   4  10  36   5   7  12  50 268  20   6 378   5   5   4   5   4
#    7  37   8  11   9   4   6  13 431  45 107   5   8   6 298   5   4   6
#    6  11   4   5  24  20   9  13   4  13 423   5  55  79 149   4   4  11
#   17  52   4  11   5   8 162   7   5  21  20 177  47   6  81   6  10   7
#  149  11  48   6  17  99 124   8   4  42  13   4   7   6   6  46   4   8
#   27  25  15   4   7  24  12  27   6   5  19   5  36   4   4   8   5  11
#    8  32   6  74   4   5   5   7  50   7   5   4]
# count/test 358	72
# Class mediadive.medium:1, Count: 358, Train: 286, Test: 72
# Running Total Test Allocated: 72
# count/test 5	2
# Class mediadive.medium:1009, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 74
# count/test 4	2
# Class mediadive.medium:1027, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 76
# count/test 6	2
# Class mediadive.medium:1031a, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 78
# count/test 95	19
# Class mediadive.medium:104, Count: 95, Train: 76, Test: 19
# Running Total Test Allocated: 97
# count/test 4	2
# Class mediadive.medium:1040, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 99
# count/test 30	6
# Class mediadive.medium:104b, Count: 30, Train: 24, Test: 6
# Running Total Test Allocated: 105
# count/test 14	3
# Class mediadive.medium:104c, Count: 14, Train: 11, Test: 3
# Running Total Test Allocated: 108
# count/test 6	2
# Class mediadive.medium:105, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 110
# count/test 6	2
# Class mediadive.medium:1069, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 112
# count/test 46	9
# Class mediadive.medium:1076b, Count: 46, Train: 37, Test: 9
# Running Total Test Allocated: 121
# count/test 151	30
# Class mediadive.medium:11, Count: 151, Train: 121, Test: 30
# Running Total Test Allocated: 151
# count/test 48	10
# Class mediadive.medium:110, Count: 48, Train: 38, Test: 10
# Running Total Test Allocated: 161
# count/test 9	2
# Class mediadive.medium:1113, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 163
# count/test 5	2
# Class mediadive.medium:1122, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 165
# count/test 8	2
# Class mediadive.medium:1159, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 167
# count/test 9	2
# Class mediadive.medium:1166, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 169
# count/test 14	3
# Class mediadive.medium:119, Count: 14, Train: 11, Test: 3
# Running Total Test Allocated: 172
# count/test 4	2
# Class mediadive.medium:1190, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 174
# count/test 8	2
# Class mediadive.medium:1193, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 176
# count/test 6	2
# Class mediadive.medium:11b, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 178
# count/test 14	3
# Class mediadive.medium:1203, Count: 14, Train: 11, Test: 3
# Running Total Test Allocated: 181
# count/test 15	3
# Class mediadive.medium:1203a, Count: 15, Train: 12, Test: 3
# Running Total Test Allocated: 184
# count/test 4	2
# Class mediadive.medium:120a, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 186
# count/test 8	2
# Class mediadive.medium:123, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 188
# count/test 4	2
# Class mediadive.medium:124, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 190
# count/test 5	2
# Class mediadive.medium:1240, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 192
# count/test 18	4
# Class mediadive.medium:141, Count: 18, Train: 14, Test: 4
# Running Total Test Allocated: 196
# count/test 9	2
# Class mediadive.medium:141c, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 198
# count/test 5	2
# Class mediadive.medium:142, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 200
# count/test 4	2
# Class mediadive.medium:1426, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 202
# count/test 11	2
# Class mediadive.medium:144, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 204
# count/test 5	2
# Class mediadive.medium:1484, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 206
# count/test 4	2
# Class mediadive.medium:1494, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 208
# count/test 17	3
# Class mediadive.medium:1523, Count: 17, Train: 14, Test: 3
# Running Total Test Allocated: 211
# count/test 6	2
# Class mediadive.medium:1536, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 213
# count/test 4	2
# Class mediadive.medium:1583, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 215
# count/test 5	2
# Class mediadive.medium:1593, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 217
# count/test 4	2
# Class mediadive.medium:172, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 219
# count/test 10	2
# Class mediadive.medium:193, Count: 10, Train: 8, Test: 2
# Running Total Test Allocated: 221
# count/test 12	2
# Class mediadive.medium:194, Count: 12, Train: 10, Test: 2
# Running Total Test Allocated: 223
# count/test 4	2
# Class mediadive.medium:195, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 225
# count/test 6	2
# Class mediadive.medium:195a, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 227
# count/test 13	3
# Class mediadive.medium:195c, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 230
# count/test 56	11
# Class mediadive.medium:1a, Count: 56, Train: 45, Test: 11
# Running Total Test Allocated: 241
# count/test 7	2
# Class mediadive.medium:214, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 243
# count/test 60	12
# Class mediadive.medium:215, Count: 60, Train: 48, Test: 12
# Running Total Test Allocated: 255
# count/test 7	2
# Class mediadive.medium:217, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 257
# count/test 7	2
# Class mediadive.medium:219, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 259
# count/test 248	50
# Class mediadive.medium:220, Count: 248, Train: 198, Test: 50
# Running Total Test Allocated: 309
# count/test 10	2
# Class mediadive.medium:220a, Count: 10, Train: 8, Test: 2
# Running Total Test Allocated: 311
# count/test 7	2
# Class mediadive.medium:231, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 313
# count/test 4	2
# Class mediadive.medium:232, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 315
# count/test 6	2
# Class mediadive.medium:246, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 317
# count/test 5	2
# Class mediadive.medium:248, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 319
# count/test 6	2
# Class mediadive.medium:250, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 321
# count/test 37	7
# Class mediadive.medium:252, Count: 37, Train: 30, Test: 7
# Running Total Test Allocated: 328
# count/test 6	2
# Class mediadive.medium:255, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 330
# count/test 31	6
# Class mediadive.medium:27, Count: 31, Train: 25, Test: 6
# Running Total Test Allocated: 336
# count/test 18	4
# Class mediadive.medium:28, Count: 18, Train: 14, Test: 4
# Running Total Test Allocated: 340
# count/test 5	2
# Class mediadive.medium:29, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 342
# count/test 4	2
# Class mediadive.medium:293, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 344
# count/test 10	2
# Class mediadive.medium:31, Count: 10, Train: 8, Test: 2
# Running Total Test Allocated: 346
# count/test 8	2
# Class mediadive.medium:311c, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 348
# count/test 8	2
# Class mediadive.medium:330, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 350
# count/test 17	3
# Class mediadive.medium:339, Count: 17, Train: 14, Test: 3
# Running Total Test Allocated: 353
# count/test 11	2
# Class mediadive.medium:339a, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 355
# count/test 17	3
# Class mediadive.medium:354, Count: 17, Train: 14, Test: 3
# Running Total Test Allocated: 358
# count/test 5	2
# Class mediadive.medium:37, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 360
# count/test 21	4
# Class mediadive.medium:372, Count: 21, Train: 17, Test: 4
# Running Total Test Allocated: 364
# count/test 24	5
# Class mediadive.medium:381, Count: 24, Train: 19, Test: 5
# Running Total Test Allocated: 369
# count/test 12	2
# Class mediadive.medium:383, Count: 12, Train: 10, Test: 2
# Running Total Test Allocated: 371
# count/test 6	2
# Class mediadive.medium:40, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 373
# count/test 8	2
# Class mediadive.medium:402, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 375
# count/test 10	2
# Class mediadive.medium:403, Count: 10, Train: 8, Test: 2
# Running Total Test Allocated: 377
# count/test 10	2
# Class mediadive.medium:426, Count: 10, Train: 8, Test: 2
# Running Total Test Allocated: 379
# count/test 13	3
# Class mediadive.medium:428, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 382
# count/test 44	9
# Class mediadive.medium:429, Count: 44, Train: 35, Test: 9
# Running Total Test Allocated: 391
# count/test 5	2
# Class mediadive.medium:429b, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 393
# count/test 4	2
# Class mediadive.medium:429c, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 395
# count/test 5	2
# Class mediadive.medium:434, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 397
# count/test 18	4
# Class mediadive.medium:457, Count: 18, Train: 14, Test: 4
# Running Total Test Allocated: 401
# count/test 6	2
# Class mediadive.medium:462, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 403
# count/test 13	3
# Class mediadive.medium:464, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 406
# count/test 7	2
# Class mediadive.medium:465, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 408
# count/test 4	2
# Class mediadive.medium:496, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 410
# count/test 13	3
# Class mediadive.medium:503, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 413
# count/test 5	2
# Class mediadive.medium:504, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 415
# count/test 5	2
# Class mediadive.medium:507, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 417
# count/test 4	2
# Class mediadive.medium:513, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 419
# count/test 661	132
# Class mediadive.medium:514, Count: 661, Train: 529, Test: 132
# Running Total Test Allocated: 551
# count/test 16	3
# Class mediadive.medium:514a, Count: 16, Train: 13, Test: 3
# Running Total Test Allocated: 554
# count/test 16	3
# Class mediadive.medium:514b, Count: 16, Train: 13, Test: 3
# Running Total Test Allocated: 557
# count/test 28	6
# Class mediadive.medium:514c, Count: 28, Train: 22, Test: 6
# Running Total Test Allocated: 563
# count/test 9	2
# Class mediadive.medium:514d, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 565
# count/test 9	2
# Class mediadive.medium:514f, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 567
# count/test 7	2
# Class mediadive.medium:520, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 569
# count/test 28	6
# Class mediadive.medium:53, Count: 28, Train: 22, Test: 6
# Running Total Test Allocated: 575
# count/test 298	60
# Class mediadive.medium:535, Count: 298, Train: 238, Test: 60
# Running Total Test Allocated: 635
# count/test 22	4
# Class mediadive.medium:535a, Count: 22, Train: 18, Test: 4
# Running Total Test Allocated: 639
# count/test 24	5
# Class mediadive.medium:535b, Count: 24, Train: 19, Test: 5
# Running Total Test Allocated: 644
# count/test 4	2
# Class mediadive.medium:54, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 646
# count/test 58	12
# Class mediadive.medium:545, Count: 58, Train: 46, Test: 12
# Running Total Test Allocated: 658
# count/test 69	14
# Class mediadive.medium:553, Count: 69, Train: 55, Test: 14
# Running Total Test Allocated: 672
# count/test 25	5
# Class mediadive.medium:554, Count: 25, Train: 20, Test: 5
# Running Total Test Allocated: 677
# count/test 13	3
# Class mediadive.medium:58, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 680
# count/test 40	8
# Class mediadive.medium:585, Count: 40, Train: 32, Test: 8
# Running Total Test Allocated: 688
# count/test 5	2
# Class mediadive.medium:593, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 690
# count/test 9	2
# Class mediadive.medium:595, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 692
# count/test 4	2
# Class mediadive.medium:603, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 694
# count/test 4	2
# Class mediadive.medium:616, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 696
# count/test 10	2
# Class mediadive.medium:621, Count: 10, Train: 8, Test: 2
# Running Total Test Allocated: 698
# count/test 36	7
# Class mediadive.medium:63, Count: 36, Train: 29, Test: 7
# Running Total Test Allocated: 705
# count/test 5	2
# Class mediadive.medium:630, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 707
# count/test 7	2
# Class mediadive.medium:640, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 709
# count/test 12	2
# Class mediadive.medium:641, Count: 12, Train: 10, Test: 2
# Running Total Test Allocated: 711
# count/test 50	10
# Class mediadive.medium:645, Count: 50, Train: 40, Test: 10
# Running Total Test Allocated: 721
# count/test 268	54
# Class mediadive.medium:65, Count: 268, Train: 214, Test: 54
# Running Total Test Allocated: 775
# count/test 20	4
# Class mediadive.medium:67, Count: 20, Train: 16, Test: 4
# Running Total Test Allocated: 779
# count/test 6	2
# Class mediadive.medium:671, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 781
# count/test 378	76
# Class mediadive.medium:693, Count: 378, Train: 302, Test: 76
# Running Total Test Allocated: 857
# count/test 5	2
# Class mediadive.medium:7, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 859
# count/test 5	2
# Class mediadive.medium:718, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 861
# count/test 4	2
# Class mediadive.medium:720, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 863
# count/test 5	2
# Class mediadive.medium:736, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 865
# count/test 4	2
# Class mediadive.medium:76, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 867
# count/test 7	2
# Class mediadive.medium:760, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 869
# count/test 37	7
# Class mediadive.medium:78, Count: 37, Train: 30, Test: 7
# Running Total Test Allocated: 876
# count/test 8	2
# Class mediadive.medium:785, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 878
# count/test 11	2
# Class mediadive.medium:804, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 880
# count/test 9	2
# Class mediadive.medium:81, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 882
# count/test 4	2
# Class mediadive.medium:82, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 884
# count/test 6	2
# Class mediadive.medium:826, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 886
# count/test 13	3
# Class mediadive.medium:83, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 889
# count/test 431	86
# Class mediadive.medium:830, Count: 431, Train: 345, Test: 86
# Running Total Test Allocated: 975
# count/test 45	9
# Class mediadive.medium:830c, Count: 45, Train: 36, Test: 9
# Running Total Test Allocated: 984
# count/test 107	21
# Class mediadive.medium:84, Count: 107, Train: 86, Test: 21
# Running Total Test Allocated: 1005
# count/test 5	2
# Class mediadive.medium:86, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1007
# count/test 8	2
# Class mediadive.medium:878, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 1009
# count/test 6	2
# Class mediadive.medium:9, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1011
# count/test 298	60
# Class mediadive.medium:92, Count: 298, Train: 238, Test: 60
# Running Total Test Allocated: 1071
# count/test 5	2
# Class mediadive.medium:921, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1073
# count/test 4	2
# Class mediadive.medium:924a, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1075
# count/test 6	2
# Class mediadive.medium:925, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1077
# count/test 6	2
# Class mediadive.medium:942, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1079
# count/test 11	2
# Class mediadive.medium:948, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 1081
# count/test 4	2
# Class mediadive.medium:960, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1083
# count/test 5	2
# Class mediadive.medium:97, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1085
# count/test 24	5
# Class mediadive.medium:98, Count: 24, Train: 19, Test: 5
# Running Total Test Allocated: 1090
# count/test 20	4
# Class mediadive.medium:987, Count: 20, Train: 16, Test: 4
# Running Total Test Allocated: 1094
# count/test 9	2
# Class mediadive.medium:J101, Count: 9, Train: 7, Test: 2
# Running Total Test Allocated: 1096
# count/test 13	3
# Class mediadive.medium:J104, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 1099
# count/test 4	2
# Class mediadive.medium:J111, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1101
# count/test 13	3
# Class mediadive.medium:J1130, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 1104
# count/test 423	85
# Class mediadive.medium:J118, Count: 423, Train: 338, Test: 85
# Running Total Test Allocated: 1189
# count/test 5	2
# Class mediadive.medium:J119, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1191
# count/test 55	11
# Class mediadive.medium:J12, Count: 55, Train: 44, Test: 11
# Running Total Test Allocated: 1202
# count/test 79	16
# Class mediadive.medium:J13, Count: 79, Train: 63, Test: 16
# Running Total Test Allocated: 1218
# count/test 149	30
# Class mediadive.medium:J14, Count: 149, Train: 119, Test: 30
# Running Total Test Allocated: 1248
# count/test 4	2
# Class mediadive.medium:J144, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1250
# count/test 4	2
# Class mediadive.medium:J151, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1252
# count/test 11	2
# Class mediadive.medium:J156, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 1254
# count/test 17	3
# Class mediadive.medium:J167, Count: 17, Train: 14, Test: 3
# Running Total Test Allocated: 1257
# count/test 52	10
# Class mediadive.medium:J168, Count: 52, Train: 42, Test: 10
# Running Total Test Allocated: 1267
# count/test 4	2
# Class mediadive.medium:J172, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1269
# count/test 11	2
# Class mediadive.medium:J181, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 1271
# count/test 5	2
# Class mediadive.medium:J187, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1273
# count/test 8	2
# Class mediadive.medium:J19, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 1275
# count/test 162	32
# Class mediadive.medium:J22, Count: 162, Train: 130, Test: 32
# Running Total Test Allocated: 1307
# count/test 7	2
# Class mediadive.medium:J232, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 1309
# count/test 5	2
# Class mediadive.medium:J236, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1311
# count/test 21	4
# Class mediadive.medium:J254, Count: 21, Train: 17, Test: 4
# Running Total Test Allocated: 1315
# count/test 20	4
# Class mediadive.medium:J256, Count: 20, Train: 16, Test: 4
# Running Total Test Allocated: 1319
# count/test 177	35
# Class mediadive.medium:J26, Count: 177, Train: 142, Test: 35
# Running Total Test Allocated: 1354
# count/test 47	9
# Class mediadive.medium:J27, Count: 47, Train: 38, Test: 9
# Running Total Test Allocated: 1363
# count/test 6	2
# Class mediadive.medium:J276, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1365
# count/test 81	16
# Class mediadive.medium:J28, Count: 81, Train: 65, Test: 16
# Running Total Test Allocated: 1381
# count/test 6	2
# Class mediadive.medium:J280, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1383
# count/test 10	2
# Class mediadive.medium:J282, Count: 10, Train: 8, Test: 2
# Running Total Test Allocated: 1385
# count/test 7	2
# Class mediadive.medium:J302, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 1387
# count/test 149	30
# Class mediadive.medium:J346, Count: 149, Train: 119, Test: 30
# Running Total Test Allocated: 1417
# count/test 11	2
# Class mediadive.medium:J377, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 1419
# count/test 48	10
# Class mediadive.medium:J386, Count: 48, Train: 38, Test: 10
# Running Total Test Allocated: 1429
# count/test 6	2
# Class mediadive.medium:J402, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1431
# count/test 17	3
# Class mediadive.medium:J41, Count: 17, Train: 14, Test: 3
# Running Total Test Allocated: 1434
# count/test 99	20
# Class mediadive.medium:J42, Count: 99, Train: 79, Test: 20
# Running Total Test Allocated: 1454
# count/test 124	25
# Class mediadive.medium:J43, Count: 124, Train: 99, Test: 25
# Running Total Test Allocated: 1479
# count/test 8	2
# Class mediadive.medium:J436, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 1481
# count/test 4	2
# Class mediadive.medium:J44, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1483
# count/test 42	8
# Class mediadive.medium:J443, Count: 42, Train: 34, Test: 8
# Running Total Test Allocated: 1491
# count/test 13	3
# Class mediadive.medium:J45, Count: 13, Train: 10, Test: 3
# Running Total Test Allocated: 1494
# count/test 4	2
# Class mediadive.medium:J455, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1496
# count/test 7	2
# Class mediadive.medium:J457, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 1498
# count/test 6	2
# Class mediadive.medium:J465, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1500
# count/test 6	2
# Class mediadive.medium:J469, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1502
# count/test 46	9
# Class mediadive.medium:J475, Count: 46, Train: 37, Test: 9
# Running Total Test Allocated: 1511
# count/test 4	2
# Class mediadive.medium:J48, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1513
# count/test 8	2
# Class mediadive.medium:J49, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 1515
# count/test 27	5
# Class mediadive.medium:J50, Count: 27, Train: 22, Test: 5
# Running Total Test Allocated: 1520
# count/test 25	5
# Class mediadive.medium:J51, Count: 25, Train: 20, Test: 5
# Running Total Test Allocated: 1525
# count/test 15	3
# Class mediadive.medium:J52, Count: 15, Train: 12, Test: 3
# Running Total Test Allocated: 1528
# count/test 4	2
# Class mediadive.medium:J528, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1530
# count/test 7	2
# Class mediadive.medium:J569, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 1532
# count/test 24	5
# Class mediadive.medium:J57, Count: 24, Train: 19, Test: 5
# Running Total Test Allocated: 1537
# count/test 12	2
# Class mediadive.medium:J574, Count: 12, Train: 10, Test: 2
# Running Total Test Allocated: 1539
# count/test 27	5
# Class mediadive.medium:J58, Count: 27, Train: 22, Test: 5
# Running Total Test Allocated: 1544
# count/test 6	2
# Class mediadive.medium:J582, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1546
# count/test 5	2
# Class mediadive.medium:J586, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1548
# count/test 19	4
# Class mediadive.medium:J61, Count: 19, Train: 15, Test: 4
# Running Total Test Allocated: 1552
# count/test 5	2
# Class mediadive.medium:J655, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1554
# count/test 36	7
# Class mediadive.medium:J66, Count: 36, Train: 29, Test: 7
# Running Total Test Allocated: 1561
# count/test 4	2
# Class mediadive.medium:J674, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1563
# count/test 4	2
# Class mediadive.medium:J675, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1565
# count/test 8	2
# Class mediadive.medium:J676, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 1567
# count/test 5	2
# Class mediadive.medium:J677, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1569
# count/test 11	2
# Class mediadive.medium:J70, Count: 11, Train: 9, Test: 2
# Running Total Test Allocated: 1571
# count/test 8	2
# Class mediadive.medium:J709, Count: 8, Train: 6, Test: 2
# Running Total Test Allocated: 1573
# count/test 32	6
# Class mediadive.medium:J74, Count: 32, Train: 26, Test: 6
# Running Total Test Allocated: 1579
# count/test 6	2
# Class mediadive.medium:J746, Count: 6, Train: 4, Test: 2
# Running Total Test Allocated: 1581
# count/test 74	15
# Class mediadive.medium:J75, Count: 74, Train: 59, Test: 15
# Running Total Test Allocated: 1596
# count/test 4	2
# Class mediadive.medium:J786, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1598
# count/test 5	2
# Class mediadive.medium:J811, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1600
# count/test 5	2
# Class mediadive.medium:J82, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1602
# count/test 7	2
# Class mediadive.medium:J83, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 1604
# count/test 50	10
# Class mediadive.medium:J84, Count: 50, Train: 40, Test: 10
# Running Total Test Allocated: 1614
# count/test 7	2
# Class mediadive.medium:J853, Count: 7, Train: 5, Test: 2
# Running Total Test Allocated: 1616
# count/test 5	2
# Class mediadive.medium:J946, Count: 5, Train: 3, Test: 2
# Running Total Test Allocated: 1618
# count/test 4	2
# Class mediadive.medium:J97, Count: 4, Train: 2, Test: 2
# Running Total Test Allocated: 1620
# Total instances: 7572
# Expected test instances: 1514
# Allocated test instances: 1620
# (6058, 467)
# (1620, 467)

# %%
# %%time
#only feature data (no embeddings) and below params = Accuracy: 0.3125904486251809
model = CatBoostClassifier(random_seed=RANDOM_SEED,
                           iterations=10000, 
                           loss_function="MultiClass",
                           learning_rate=0.1, 
                           depth=4,#8 = 0.238 
                           l2_leaf_reg=3,
                           bagging_temperature=1,
                           random_strength=5,
                           verbose=100)
model.fit(train_data, 
          eval_set=test_data,
          early_stopping_rounds=50 
         )
# Out:
# 0:	learn: 5.1207088	test: 5.1394263	best: 5.1394263 (0)	total: 665ms	remaining: 1h 50m 45s
# 100:	learn: 1.6901667	test: 2.2985671	best: 2.2985671 (100)	total: 57.3s	remaining: 1h 33m 39s
# 200:	learn: 0.9310505	test: 1.7604281	best: 1.7604281 (200)	total: 1m 54s	remaining: 1h 33m 1s
# 300:	learn: 0.6659859	test: 1.5704357	best: 1.5704357 (300)	total: 2m 51s	remaining: 1h 32m 16s
# 400:	learn: 0.5232356	test: 1.4733881	best: 1.4733881 (400)	total: 3m 48s	remaining: 1h 31m 19s
# 500:	learn: 0.4370011	test: 1.4158592	best: 1.4158592 (500)	total: 4m 45s	remaining: 1h 30m 9s
# 600:	learn: 0.3731755	test: 1.3764009	best: 1.3764009 (600)	total: 5m 41s	remaining: 1h 29m 8s
# 700:	learn: 0.3244335	test: 1.3518828	best: 1.3518828 (700)	total: 6m 38s	remaining: 1h 28m 6s
# 800:	learn: 0.2875769	test: 1.3349573	best: 1.3349573 (800)	total: 7m 34s	remaining: 1h 27m 4s
# 900:	learn: 0.2549022	test: 1.3190097	best: 1.3190097 (900)	total: 8m 31s	remaining: 1h 26m 8s
# 1000:	learn: 0.2308908	test: 1.3067854	best: 1.3067190 (998)	total: 9m 28s	remaining: 1h 25m 12s
# 1100:	learn: 0.2097608	test: 1.2981839	best: 1.2981424 (1099)	total: 10m 25s	remaining: 1h 24m 19s
# 1200:	learn: 0.1901183	test: 1.2894420	best: 1.2894034 (1198)	total: 11m 22s	remaining: 1h 23m 19s
# 1300:	learn: 0.1729672	test: 1.2835348	best: 1.2835348 (1300)	total: 12m 19s	remaining: 1h 22m 24s
# 1400:	learn: 0.1599770	test: 1.2787649	best: 1.2787298 (1399)	total: 13m 16s	remaining: 1h 21m 30s
# 1500:	learn: 0.1467207	test: 1.2732310	best: 1.2731773 (1498)	total: 14m 13s	remaining: 1h 20m 32s
# 1600:	learn: 0.1357080	test: 1.2706685	best: 1.2706685 (1600)	total: 15m 10s	remaining: 1h 19m 33s
# 1700:	learn: 0.1258780	test: 1.2669903	best: 1.2669903 (1700)	total: 16m 6s	remaining: 1h 18m 34s
# 1800:	learn: 0.1177380	test: 1.2640453	best: 1.2640453 (1800)	total: 17m 2s	remaining: 1h 17m 37s
# 1900:	learn: 0.1091969	test: 1.2610660	best: 1.2609461 (1898)	total: 17m 59s	remaining: 1h 16m 39s
# 2000:	learn: 0.1018975	test: 1.2589510	best: 1.2588240 (1997)	total: 18m 56s	remaining: 1h 15m 42s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.25724796
# bestIteration = 2045
#
# Shrink model to first 2046 iterations.
# CPU times: user 2h 34min 8s, sys: 54.6 s, total: 2h 35min 3s
# Wall time: 19min 50s

# %%
# Predict on test data
y_pred_test = model.predict(test_data)
y_pred_proba_test= model.predict_proba(test_data)[:,1]  # Probabilities for the positive class

# Print metrics                                                                                                                        
print("Accuracy:", accuracy_score(y_test, y_pred_test))
print("\nClassification Report:\n", classification_report(y_test, y_pred_test))
# Out:
# Accuracy: 0.5742237345810294
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#     mediadive.medium:1       0.56      0.69      0.62       107
#  mediadive.medium:1009       0.00      0.00      0.00         1
#  mediadive.medium:1025       1.00      1.00      1.00         1
#  mediadive.medium:1027       0.00      0.00      0.00         1
# mediadive.medium:1031a       1.00      0.50      0.67         2
#   mediadive.medium:104       0.38      0.36      0.37        28
#  mediadive.medium:1040       0.00      0.00      0.00         1
#  mediadive.medium:104a       0.00      0.00      0.00         1
#  mediadive.medium:104b       0.73      0.89      0.80         9
#  mediadive.medium:104c       0.67      0.50      0.57         4
#   mediadive.medium:105       0.67      1.00      0.80         2
#  mediadive.medium:1052       0.00      0.00      0.00         1
#  mediadive.medium:1069       1.00      1.00      1.00         2
# mediadive.medium:1076b       1.00      1.00      1.00        14
#  mediadive.medium:1095       0.00      0.00      0.00         1
#    mediadive.medium:11       0.86      0.84      0.85        45
#   mediadive.medium:110       0.43      0.43      0.43        14
#  mediadive.medium:1113       0.75      1.00      0.86         3
#  mediadive.medium:1122       1.00      0.50      0.67         2
#  mediadive.medium:1145       1.00      1.00      1.00         1
#  mediadive.medium:1159       0.00      0.00      0.00         2
#  mediadive.medium:1166       1.00      0.33      0.50         3
#   mediadive.medium:119       0.50      0.50      0.50         4
#  mediadive.medium:1190       0.00      0.00      0.00         1
#  mediadive.medium:1193       1.00      1.00      1.00         2
#   mediadive.medium:11b       0.00      0.00      0.00         2
#  mediadive.medium:1203       0.00      0.00      0.00         4
# mediadive.medium:1203a       0.33      0.25      0.29         4
#  mediadive.medium:120a       0.00      0.00      0.00         1
# mediadive.medium:1210a       0.00      0.00      0.00         1
#   mediadive.medium:122       0.00      0.00      0.00         1
#   mediadive.medium:123       0.00      0.00      0.00         2
#   mediadive.medium:124       0.00      0.00      0.00         1
#  mediadive.medium:1240       0.00      0.00      0.00         2
#   mediadive.medium:133       0.00      0.00      0.00         1
#   mediadive.medium:135       1.00      1.00      1.00         1
#   mediadive.medium:136       0.00      0.00      0.00         1
#   mediadive.medium:141       0.67      0.80      0.73         5
#  mediadive.medium:141c       1.00      0.67      0.80         3
#   mediadive.medium:142       1.00      1.00      1.00         2
#  mediadive.medium:1426       0.00      0.00      0.00         1
#   mediadive.medium:144       0.75      1.00      0.86         3
#  mediadive.medium:1484       0.00      0.00      0.00         1
#  mediadive.medium:1494       1.00      1.00      1.00         1
#  mediadive.medium:1520       1.00      1.00      1.00         1
#  mediadive.medium:1523       0.50      0.60      0.55         5
#  mediadive.medium:1536       1.00      1.00      1.00         2
#  mediadive.medium:1583       1.00      1.00      1.00         1
#  mediadive.medium:1593       0.00      0.00      0.00         2
#   mediadive.medium:172       0.00      0.00      0.00         1
#   mediadive.medium:193       1.00      0.67      0.80         3
#   mediadive.medium:194       0.67      0.50      0.57         4
#   mediadive.medium:195       1.00      1.00      1.00         1
#  mediadive.medium:195a       1.00      0.50      0.67         2
#  mediadive.medium:195c       1.00      0.50      0.67         4
#    mediadive.medium:1a       0.57      0.47      0.52        17
#   mediadive.medium:211       0.00      0.00      0.00         1
#   mediadive.medium:212       0.00      0.00      0.00         1
#   mediadive.medium:213       0.00      0.00      0.00         1
#   mediadive.medium:214       0.00      0.00      0.00         2
#   mediadive.medium:215       0.58      0.39      0.47        18
#   mediadive.medium:217       0.00      0.00      0.00         2
#   mediadive.medium:219       0.00      0.00      0.00         2
#   mediadive.medium:220       0.71      0.68      0.69        74
#  mediadive.medium:220a       1.00      0.33      0.50         3
#   mediadive.medium:231       1.00      1.00      1.00         2
#   mediadive.medium:232       1.00      1.00      1.00         1
#   mediadive.medium:246       1.00      0.50      0.67         2
#   mediadive.medium:248       0.00      0.00      0.00         1
#   mediadive.medium:250       0.00      0.00      0.00         2
#   mediadive.medium:252       0.00      0.00      0.00        11
#   mediadive.medium:253       1.00      1.00      1.00         1
#   mediadive.medium:255       1.00      0.50      0.67         2
#    mediadive.medium:26       0.00      0.00      0.00         1
#    mediadive.medium:27       0.82      1.00      0.90         9
#   mediadive.medium:276       0.00      0.00      0.00         1
#    mediadive.medium:28       1.00      0.80      0.89         5
#    mediadive.medium:29       1.00      1.00      1.00         2
#   mediadive.medium:293       0.50      1.00      0.67         1
#   mediadive.medium:298       0.00      0.00      0.00         1
#     mediadive.medium:3       0.00      0.00      0.00         1
#    mediadive.medium:31       0.50      0.33      0.40         3
#   mediadive.medium:311       1.00      1.00      1.00         1
#  mediadive.medium:311c       1.00      1.00      1.00         2
#   mediadive.medium:330       1.00      1.00      1.00         2
#   mediadive.medium:339       0.67      0.40      0.50         5
#  mediadive.medium:339a       1.00      0.67      0.80         3
#   mediadive.medium:354       1.00      0.20      0.33         5
#   mediadive.medium:357       1.00      1.00      1.00         1
#   mediadive.medium:360       0.00      0.00      0.00         1
#    mediadive.medium:37       0.00      0.00      0.00         1
#   mediadive.medium:372       0.25      0.17      0.20         6
#   mediadive.medium:381       1.00      0.29      0.44         7
#   mediadive.medium:383       0.80      1.00      0.89         4
#    mediadive.medium:40       1.00      0.50      0.67         2
#   mediadive.medium:402       1.00      1.00      1.00         2
#   mediadive.medium:403       1.00      1.00      1.00         3
#   mediadive.medium:411       0.00      0.00      0.00         1
#   mediadive.medium:426       0.00      0.00      0.00         3
#   mediadive.medium:428       0.50      0.25      0.33         4
#   mediadive.medium:429       0.80      0.62      0.70        13
#  mediadive.medium:429b       0.00      0.00      0.00         1
#  mediadive.medium:429c       1.00      1.00      1.00         1
#   mediadive.medium:434       0.00      0.00      0.00         2
#   mediadive.medium:455       0.00      0.00      0.00         1
#   mediadive.medium:457       0.50      0.40      0.44         5
#   mediadive.medium:462       0.00      0.00      0.00         2
#   mediadive.medium:464       1.00      0.25      0.40         4
#   mediadive.medium:465       1.00      0.50      0.67         2
#   mediadive.medium:496       1.00      1.00      1.00         1
#   mediadive.medium:500       0.00      0.00      0.00         1
#   mediadive.medium:503       0.80      1.00      0.89         4
#  mediadive.medium:503b       0.00      0.00      0.00         1
#   mediadive.medium:504       0.00      0.00      0.00         2
#   mediadive.medium:507       1.00      0.50      0.67         2
#   mediadive.medium:508       0.00      0.00      0.00         1
#   mediadive.medium:513       0.00      0.00      0.00         1
#   mediadive.medium:514       0.68      0.83      0.75       198
#  mediadive.medium:514a       1.00      0.40      0.57         5
#  mediadive.medium:514b       0.50      0.20      0.29         5
#  mediadive.medium:514c       1.00      0.75      0.86         8
#  mediadive.medium:514d       0.00      0.00      0.00         3
#  mediadive.medium:514f       1.00      0.33      0.50         3
#   mediadive.medium:520       0.67      1.00      0.80         2
#    mediadive.medium:53       0.20      0.12      0.15         8
#   mediadive.medium:535       0.53      0.56      0.54        89
#  mediadive.medium:535a       0.67      0.29      0.40         7
#  mediadive.medium:535b       0.75      0.43      0.55         7
#    mediadive.medium:54       0.00      0.00      0.00         1
#   mediadive.medium:545       0.67      0.47      0.55        17
#   mediadive.medium:548       0.00      0.00      0.00         1
#   mediadive.medium:54a       0.00      0.00      0.00         1
#   mediadive.medium:553       0.43      0.29      0.34        21
#   mediadive.medium:554       0.00      0.00      0.00         7
#   mediadive.medium:579       0.00      0.00      0.00         1
#    mediadive.medium:58       0.67      0.50      0.57         4
#   mediadive.medium:585       0.92      1.00      0.96        12
#   mediadive.medium:586       0.00      0.00      0.00         1
#   mediadive.medium:593       0.00      0.00      0.00         2
#   mediadive.medium:595       1.00      1.00      1.00         3
#   mediadive.medium:603       1.00      1.00      1.00         1
#   mediadive.medium:607       1.00      1.00      1.00         1
#   mediadive.medium:616       1.00      1.00      1.00         1
#   mediadive.medium:621       1.00      1.00      1.00         3
#  mediadive.medium:621a       0.00      0.00      0.00         1
#   mediadive.medium:628       0.00      0.00      0.00         1
#    mediadive.medium:63       0.55      1.00      0.71        11
#   mediadive.medium:630       1.00      0.50      0.67         2
#  mediadive.medium:634c       0.00      0.00      0.00         1
#   mediadive.medium:636       0.00      0.00      0.00         1
#   mediadive.medium:638       0.00      0.00      0.00         1
#   mediadive.medium:640       0.50      0.50      0.50         2
#   mediadive.medium:641       0.00      0.00      0.00         4
#   mediadive.medium:645       0.29      0.33      0.31        15
#    mediadive.medium:65       0.27      0.45      0.33        80
#    mediadive.medium:67       0.83      0.83      0.83         6
#   mediadive.medium:671       1.00      0.50      0.67         2
#   mediadive.medium:684       0.00      0.00      0.00         1
#   mediadive.medium:693       0.46      0.66      0.54       113
#     mediadive.medium:7       0.00      0.00      0.00         2
#   mediadive.medium:700       1.00      1.00      1.00         1
#   mediadive.medium:718       1.00      0.50      0.67         2
#   mediadive.medium:720       1.00      1.00      1.00         1
#   mediadive.medium:736       0.00      0.00      0.00         2
#    mediadive.medium:76       1.00      1.00      1.00         1
#   mediadive.medium:760       1.00      0.50      0.67         2
#   mediadive.medium:779       1.00      1.00      1.00         1
#    mediadive.medium:78       0.25      0.09      0.13        11
#   mediadive.medium:785       1.00      1.00      1.00         2
#    mediadive.medium:80       0.00      0.00      0.00         1
#   mediadive.medium:804       1.00      1.00      1.00         3
#    mediadive.medium:81       0.00      0.00      0.00         3
#   mediadive.medium:813       1.00      1.00      1.00         1
#    mediadive.medium:82       0.00      0.00      0.00         1
#   mediadive.medium:826       1.00      1.00      1.00         2
#    mediadive.medium:83       0.50      0.25      0.33         4
#   mediadive.medium:830       0.58      0.79      0.67       129
#  mediadive.medium:830c       0.83      0.77      0.80        13
#    mediadive.medium:84       0.37      0.41      0.39        32
#   mediadive.medium:846       1.00      1.00      1.00         1
#    mediadive.medium:86       1.00      1.00      1.00         2
#   mediadive.medium:861       1.00      1.00      1.00         1
#    mediadive.medium:87       1.00      1.00      1.00         1
#   mediadive.medium:878       0.00      0.00      0.00         2
#   mediadive.medium:879       0.00      0.00      0.00         1
#   mediadive.medium:87a       1.00      1.00      1.00         1
#   mediadive.medium:882       0.00      0.00      0.00         1
#   mediadive.medium:895       1.00      1.00      1.00         1
#     mediadive.medium:9       0.00      0.00      0.00         2
#   mediadive.medium:900       1.00      1.00      1.00         1
#    mediadive.medium:92       0.46      0.58      0.51        89
#   mediadive.medium:921       1.00      1.00      1.00         2
#  mediadive.medium:924a       1.00      1.00      1.00         1
#   mediadive.medium:925       1.00      1.00      1.00         2
#   mediadive.medium:942       0.00      0.00      0.00         2
#   mediadive.medium:948       0.00      0.00      0.00         3
#   mediadive.medium:950       1.00      1.00      1.00         1
#   mediadive.medium:960       0.00      0.00      0.00         1
#   mediadive.medium:968       0.00      0.00      0.00         1
#    mediadive.medium:97       0.00      0.00      0.00         2
#    mediadive.medium:98       0.71      0.71      0.71         7
#   mediadive.medium:987       0.50      0.17      0.25         6
#   mediadive.medium:993       0.00      0.00      0.00         1
# mediadive.medium:J1000       1.00      1.00      1.00         1
#  mediadive.medium:J101       1.00      1.00      1.00         3
#  mediadive.medium:J104       1.00      0.25      0.40         4
# mediadive.medium:J1099       1.00      1.00      1.00         1
#  mediadive.medium:J111       1.00      1.00      1.00         1
#  mediadive.medium:J112       0.00      0.00      0.00         1
# mediadive.medium:J1130       0.50      0.25      0.33         4
#  mediadive.medium:J115       0.00      0.00      0.00         1
#  mediadive.medium:J118       0.78      0.80      0.79       127
#  mediadive.medium:J119       0.00      0.00      0.00         1
#   mediadive.medium:J12       0.40      0.50      0.44        16
# mediadive.medium:J1270       0.00      0.00      0.00         1
#   mediadive.medium:J13       0.37      0.54      0.44        24
#  mediadive.medium:J139       0.00      0.00      0.00         1
#   mediadive.medium:J14       0.38      0.53      0.44        45
#  mediadive.medium:J144       1.00      1.00      1.00         1
#  mediadive.medium:J151       1.00      1.00      1.00         1
#  mediadive.medium:J156       0.50      0.33      0.40         3
#  mediadive.medium:J161       1.00      1.00      1.00         1
#  mediadive.medium:J167       0.83      1.00      0.91         5
#  mediadive.medium:J168       0.70      1.00      0.82        16
#  mediadive.medium:J169       0.00      0.00      0.00         1
#  mediadive.medium:J172       0.00      0.00      0.00         1
#  mediadive.medium:J174       1.00      1.00      1.00         1
#  mediadive.medium:J181       0.67      0.67      0.67         3
#  mediadive.medium:J187       1.00      1.00      1.00         1
#   mediadive.medium:J19       0.50      0.50      0.50         2
#  mediadive.medium:J190       1.00      1.00      1.00         1
#  mediadive.medium:J198       1.00      1.00      1.00         1
#  mediadive.medium:J207       0.00      0.00      0.00         1
#  mediadive.medium:J217       0.00      0.00      0.00         1
#   mediadive.medium:J22       0.41      0.51      0.45        49
#  mediadive.medium:J221       0.00      0.00      0.00         1
#  mediadive.medium:J231       1.00      1.00      1.00         1
#  mediadive.medium:J232       1.00      0.50      0.67         2
#  mediadive.medium:J236       1.00      1.00      1.00         1
#  mediadive.medium:J254       0.75      0.50      0.60         6
#  mediadive.medium:J256       0.00      0.00      0.00         6
#   mediadive.medium:J26       0.47      0.58      0.52        53
#   mediadive.medium:J27       0.58      0.50      0.54        14
#  mediadive.medium:J276       1.00      1.00      1.00         2
#   mediadive.medium:J28       0.55      0.50      0.52        24
#  mediadive.medium:J280       0.50      0.50      0.50         2
#  mediadive.medium:J282       1.00      0.67      0.80         3
#  mediadive.medium:J291       0.00      0.00      0.00         1
#  mediadive.medium:J302       0.50      0.50      0.50         2
#  mediadive.medium:J346       0.69      0.56      0.62        45
#  mediadive.medium:J358       0.00      0.00      0.00         1
#  mediadive.medium:J363       0.00      0.00      0.00         1
#  mediadive.medium:J377       1.00      1.00      1.00         3
#  mediadive.medium:J386       0.41      0.50      0.45        14
#  mediadive.medium:J388       0.00      0.00      0.00         1
#  mediadive.medium:J389       0.00      0.00      0.00         1
#  mediadive.medium:J402       0.00      0.00      0.00         2
#  mediadive.medium:J409       0.00      0.00      0.00         1
#   mediadive.medium:J41       0.50      0.20      0.29         5
#  mediadive.medium:J415       0.00      0.00      0.00         1
#   mediadive.medium:J42       0.56      0.50      0.53        30
#   mediadive.medium:J43       0.41      0.41      0.41        37
#  mediadive.medium:J434       1.00      1.00      1.00         1
#  mediadive.medium:J436       0.33      1.00      0.50         2
#   mediadive.medium:J44       0.00      0.00      0.00         1
#  mediadive.medium:J443       0.90      0.69      0.78        13
#   mediadive.medium:J45       1.00      0.25      0.40         4
#  mediadive.medium:J455       1.00      1.00      1.00         1
#  mediadive.medium:J457       1.00      1.00      1.00         2
#  mediadive.medium:J465       0.00      0.00      0.00         2
#  mediadive.medium:J469       1.00      0.50      0.67         2
#  mediadive.medium:J475       0.75      0.21      0.33        14
#  mediadive.medium:J479       1.00      1.00      1.00         1
#   mediadive.medium:J48       0.00      0.00      0.00         1
#  mediadive.medium:J486       0.00      0.00      0.00         1
#  mediadive.medium:J487       1.00      1.00      1.00         1
#   mediadive.medium:J49       0.00      0.00      0.00         2
#   mediadive.medium:J50       0.25      0.12      0.17         8
#  mediadive.medium:J505       0.00      0.00      0.00         1
#   mediadive.medium:J51       0.00      0.00      0.00         7
#   mediadive.medium:J52       0.00      0.00      0.00         4
#  mediadive.medium:J528       0.00      0.00      0.00         1
#  mediadive.medium:J569       0.00      0.00      0.00         2
#   mediadive.medium:J57       0.50      0.29      0.36         7
#  mediadive.medium:J574       1.00      0.75      0.86         4
#   mediadive.medium:J58       0.00      0.00      0.00         8
#  mediadive.medium:J582       1.00      1.00      1.00         2
#  mediadive.medium:J586       1.00      1.00      1.00         2
#  mediadive.medium:J597       0.00      0.00      0.00         1
#   mediadive.medium:J61       0.00      0.00      0.00         6
#  mediadive.medium:J611       0.00      0.00      0.00         1
#  mediadive.medium:J632       0.00      0.00      0.00         1
#  mediadive.medium:J655       0.00      0.00      0.00         2
#   mediadive.medium:J66       0.50      0.27      0.35        11
#  mediadive.medium:J674       0.00      0.00      0.00         1
#  mediadive.medium:J675       1.00      1.00      1.00         1
#  mediadive.medium:J676       0.50      0.50      0.50         2
#  mediadive.medium:J677       0.00      0.00      0.00         2
#  mediadive.medium:J684       0.00      0.00      0.00         1
#   mediadive.medium:J69       0.00      0.00      0.00         1
#   mediadive.medium:J70       0.00      0.00      0.00         3
#  mediadive.medium:J709       0.50      1.00      0.67         2
#  mediadive.medium:J732       0.00      0.00      0.00         1
#  mediadive.medium:J736       0.00      0.00      0.00         1
#   mediadive.medium:J74       0.67      0.40      0.50        10
#  mediadive.medium:J746       1.00      1.00      1.00         2
#   mediadive.medium:J75       0.55      0.50      0.52        22
#  mediadive.medium:J786       1.00      1.00      1.00         1
#   mediadive.medium:J79       0.00      0.00      0.00         1
#  mediadive.medium:J811       1.00      0.50      0.67         2
#   mediadive.medium:J82       0.00      0.00      0.00         1
#   mediadive.medium:J83       0.50      0.50      0.50         2
#   mediadive.medium:J84       0.25      0.13      0.17        15
#  mediadive.medium:J842       0.00      0.00      0.00         1
#  mediadive.medium:J853       1.00      1.00      1.00         2
#  mediadive.medium:J946       1.00      0.50      0.67         2
#   mediadive.medium:J97       0.00      0.00      0.00         1
#
#               accuracy                           0.57      2351
#              macro avg       0.49      0.44      0.45      2351
#           weighted avg       0.55      0.57      0.55      2351
# /Users/marcin/Documents/VIMSS/ontology/KG-Hub/KG-Microbe/kg-microbe/notebooks/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/marcin/Documents/VIMSS/ontology/KG-Hub/KG-Microbe/kg-microbe/notebooks/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/marcin/Documents/VIMSS/ontology/KG-Hub/KG-Microbe/kg-microbe/notebooks/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Predict on train data
y_pred_train = model.predict(train_data)
y_pred_proba_train = model.predict_proba(train_data)[:,1]  # Probabilities for the positive class

# Print metrics                                                                                                                        
print("Accuracy:", accuracy_score(y_train, y_pred_train))
print("\nClassification Report:\n", classification_report(y_train, y_pred_train))
# Out:
# Accuracy: 1.0
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#     mediadive.medium:1       1.00      1.00      1.00       251
#  mediadive.medium:1009       1.00      1.00      1.00         4
#  mediadive.medium:1025       1.00      1.00      1.00         2
#  mediadive.medium:1027       1.00      1.00      1.00         3
# mediadive.medium:1031a       1.00      1.00      1.00         4
#   mediadive.medium:104       1.00      1.00      1.00        67
#  mediadive.medium:1040       1.00      1.00      1.00         3
#  mediadive.medium:104a       1.00      1.00      1.00         2
#  mediadive.medium:104b       1.00      1.00      1.00        21
#  mediadive.medium:104c       1.00      1.00      1.00        10
#   mediadive.medium:105       1.00      1.00      1.00         4
#  mediadive.medium:1052       1.00      1.00      1.00         2
#  mediadive.medium:1069       1.00      1.00      1.00         4
# mediadive.medium:1076b       1.00      1.00      1.00        32
#  mediadive.medium:1095       1.00      1.00      1.00         2
#    mediadive.medium:11       1.00      1.00      1.00       106
#   mediadive.medium:110       1.00      1.00      1.00        34
#  mediadive.medium:1113       1.00      1.00      1.00         6
#  mediadive.medium:1122       1.00      1.00      1.00         3
#  mediadive.medium:1145       1.00      1.00      1.00         2
#  mediadive.medium:1159       1.00      1.00      1.00         6
#  mediadive.medium:1166       1.00      1.00      1.00         6
#   mediadive.medium:119       1.00      1.00      1.00        10
#  mediadive.medium:1190       1.00      1.00      1.00         3
#  mediadive.medium:1193       1.00      1.00      1.00         6
#   mediadive.medium:11b       1.00      1.00      1.00         4
#  mediadive.medium:1203       1.00      1.00      1.00        10
# mediadive.medium:1203a       1.00      1.00      1.00        11
#  mediadive.medium:120a       1.00      1.00      1.00         3
# mediadive.medium:1210a       1.00      1.00      1.00         2
#   mediadive.medium:122       1.00      1.00      1.00         2
#   mediadive.medium:123       1.00      1.00      1.00         6
#   mediadive.medium:124       1.00      1.00      1.00         3
#  mediadive.medium:1240       1.00      1.00      1.00         3
#   mediadive.medium:133       1.00      1.00      1.00         2
#   mediadive.medium:135       1.00      1.00      1.00         2
#   mediadive.medium:136       1.00      1.00      1.00         2
#   mediadive.medium:141       1.00      1.00      1.00        13
#  mediadive.medium:141c       1.00      1.00      1.00         6
#   mediadive.medium:142       1.00      1.00      1.00         3
#  mediadive.medium:1426       1.00      1.00      1.00         3
#   mediadive.medium:144       1.00      1.00      1.00         8
#  mediadive.medium:1484       1.00      1.00      1.00         4
#  mediadive.medium:1494       1.00      1.00      1.00         3
#  mediadive.medium:1520       1.00      1.00      1.00         2
#  mediadive.medium:1523       1.00      1.00      1.00        12
#  mediadive.medium:1536       1.00      1.00      1.00         4
#  mediadive.medium:1583       1.00      1.00      1.00         3
#  mediadive.medium:1593       1.00      1.00      1.00         3
#   mediadive.medium:172       1.00      1.00      1.00         3
#   mediadive.medium:193       1.00      1.00      1.00         7
#   mediadive.medium:194       1.00      1.00      1.00         8
#   mediadive.medium:195       1.00      1.00      1.00         3
#  mediadive.medium:195a       1.00      1.00      1.00         4
#  mediadive.medium:195c       1.00      1.00      1.00         9
#    mediadive.medium:1a       1.00      1.00      1.00        39
#   mediadive.medium:211       1.00      1.00      1.00         2
#   mediadive.medium:212       1.00      1.00      1.00         2
#   mediadive.medium:213       1.00      1.00      1.00         2
#   mediadive.medium:214       1.00      1.00      1.00         5
#   mediadive.medium:215       1.00      1.00      1.00        42
#   mediadive.medium:217       1.00      1.00      1.00         5
#   mediadive.medium:219       1.00      1.00      1.00         5
#   mediadive.medium:220       1.00      1.00      1.00       174
#  mediadive.medium:220a       1.00      1.00      1.00         7
#   mediadive.medium:231       1.00      1.00      1.00         5
#   mediadive.medium:232       1.00      1.00      1.00         3
#   mediadive.medium:246       1.00      1.00      1.00         4
#   mediadive.medium:248       1.00      1.00      1.00         4
#   mediadive.medium:250       1.00      1.00      1.00         4
#   mediadive.medium:252       1.00      1.00      1.00        26
#   mediadive.medium:253       1.00      1.00      1.00         2
#   mediadive.medium:255       1.00      1.00      1.00         4
#    mediadive.medium:26       1.00      1.00      1.00         2
#    mediadive.medium:27       1.00      1.00      1.00        22
#   mediadive.medium:276       1.00      1.00      1.00         2
#    mediadive.medium:28       1.00      1.00      1.00        13
#    mediadive.medium:29       1.00      1.00      1.00         3
#   mediadive.medium:293       1.00      1.00      1.00         3
#   mediadive.medium:298       1.00      1.00      1.00         2
#     mediadive.medium:3       1.00      1.00      1.00         2
#    mediadive.medium:31       1.00      1.00      1.00         7
#   mediadive.medium:311       1.00      1.00      1.00         2
#  mediadive.medium:311c       1.00      1.00      1.00         6
#   mediadive.medium:330       1.00      1.00      1.00         6
#   mediadive.medium:339       1.00      1.00      1.00        12
#  mediadive.medium:339a       1.00      1.00      1.00         8
#   mediadive.medium:354       1.00      1.00      1.00        12
#   mediadive.medium:357       1.00      1.00      1.00         2
#   mediadive.medium:360       1.00      1.00      1.00         2
#    mediadive.medium:37       1.00      1.00      1.00         4
#   mediadive.medium:372       1.00      1.00      1.00        15
#   mediadive.medium:381       1.00      1.00      1.00        17
#   mediadive.medium:383       1.00      1.00      1.00         8
#    mediadive.medium:40       1.00      1.00      1.00         4
#   mediadive.medium:402       1.00      1.00      1.00         6
#   mediadive.medium:403       1.00      1.00      1.00         7
#   mediadive.medium:411       1.00      1.00      1.00         2
#   mediadive.medium:426       1.00      1.00      1.00         7
#   mediadive.medium:428       1.00      1.00      1.00         9
#   mediadive.medium:429       1.00      1.00      1.00        31
#  mediadive.medium:429b       1.00      1.00      1.00         4
#  mediadive.medium:429c       1.00      1.00      1.00         3
#   mediadive.medium:434       1.00      1.00      1.00         3
#   mediadive.medium:455       1.00      1.00      1.00         2
#   mediadive.medium:457       1.00      1.00      1.00        13
#   mediadive.medium:462       1.00      1.00      1.00         4
#   mediadive.medium:464       1.00      1.00      1.00         9
#   mediadive.medium:465       1.00      1.00      1.00         5
#   mediadive.medium:496       1.00      1.00      1.00         3
#   mediadive.medium:500       1.00      1.00      1.00         2
#   mediadive.medium:503       1.00      1.00      1.00         9
#  mediadive.medium:503b       1.00      1.00      1.00         2
#   mediadive.medium:504       1.00      1.00      1.00         3
#   mediadive.medium:507       1.00      1.00      1.00         3
#   mediadive.medium:508       1.00      1.00      1.00         2
#   mediadive.medium:513       1.00      1.00      1.00         3
#   mediadive.medium:514       1.00      1.00      1.00       463
#  mediadive.medium:514a       1.00      1.00      1.00        11
#  mediadive.medium:514b       1.00      1.00      1.00        11
#  mediadive.medium:514c       1.00      1.00      1.00        20
#  mediadive.medium:514d       1.00      1.00      1.00         6
#  mediadive.medium:514f       1.00      1.00      1.00         6
#   mediadive.medium:520       1.00      1.00      1.00         5
#    mediadive.medium:53       1.00      1.00      1.00        20
#   mediadive.medium:535       1.00      1.00      1.00       209
#  mediadive.medium:535a       1.00      1.00      1.00        15
#  mediadive.medium:535b       1.00      1.00      1.00        17
#    mediadive.medium:54       1.00      1.00      1.00         3
#   mediadive.medium:545       1.00      1.00      1.00        41
#   mediadive.medium:548       1.00      1.00      1.00         2
#   mediadive.medium:54a       1.00      1.00      1.00         2
#   mediadive.medium:553       1.00      1.00      1.00        48
#   mediadive.medium:554       1.00      1.00      1.00        18
#   mediadive.medium:579       1.00      1.00      1.00         2
#    mediadive.medium:58       1.00      1.00      1.00         9
#   mediadive.medium:585       1.00      1.00      1.00        28
#   mediadive.medium:586       1.00      1.00      1.00         2
#   mediadive.medium:593       1.00      1.00      1.00         3
#   mediadive.medium:595       1.00      1.00      1.00         6
#   mediadive.medium:603       1.00      1.00      1.00         3
#   mediadive.medium:607       1.00      1.00      1.00         2
#   mediadive.medium:616       1.00      1.00      1.00         3
#   mediadive.medium:621       1.00      1.00      1.00         7
#  mediadive.medium:621a       1.00      1.00      1.00         2
#   mediadive.medium:628       1.00      1.00      1.00         2
#    mediadive.medium:63       1.00      1.00      1.00        25
#   mediadive.medium:630       1.00      1.00      1.00         3
#  mediadive.medium:634c       1.00      1.00      1.00         2
#   mediadive.medium:636       1.00      1.00      1.00         2
#   mediadive.medium:638       1.00      1.00      1.00         2
#   mediadive.medium:640       1.00      1.00      1.00         5
#   mediadive.medium:641       1.00      1.00      1.00         8
#   mediadive.medium:645       1.00      1.00      1.00        35
#    mediadive.medium:65       1.00      1.00      1.00       188
#    mediadive.medium:67       1.00      1.00      1.00        14
#   mediadive.medium:671       1.00      1.00      1.00         4
#   mediadive.medium:684       1.00      1.00      1.00         2
#   mediadive.medium:693       1.00      1.00      1.00       265
#     mediadive.medium:7       1.00      1.00      1.00         3
#   mediadive.medium:700       1.00      1.00      1.00         2
#   mediadive.medium:718       1.00      1.00      1.00         3
#   mediadive.medium:720       1.00      1.00      1.00         3
#   mediadive.medium:736       1.00      1.00      1.00         3
#    mediadive.medium:76       1.00      1.00      1.00         3
#   mediadive.medium:760       1.00      1.00      1.00         5
#   mediadive.medium:779       1.00      1.00      1.00         2
#    mediadive.medium:78       1.00      1.00      1.00        26
#   mediadive.medium:785       1.00      1.00      1.00         6
#    mediadive.medium:80       1.00      1.00      1.00         2
#   mediadive.medium:804       1.00      1.00      1.00         8
#    mediadive.medium:81       1.00      1.00      1.00         6
#   mediadive.medium:813       1.00      1.00      1.00         2
#    mediadive.medium:82       1.00      1.00      1.00         3
#   mediadive.medium:826       1.00      1.00      1.00         4
#    mediadive.medium:83       1.00      1.00      1.00         9
#   mediadive.medium:830       1.00      1.00      1.00       302
#  mediadive.medium:830c       1.00      1.00      1.00        32
#    mediadive.medium:84       1.00      1.00      1.00        75
#   mediadive.medium:846       1.00      1.00      1.00         2
#    mediadive.medium:86       1.00      1.00      1.00         3
#   mediadive.medium:861       1.00      1.00      1.00         2
#    mediadive.medium:87       1.00      1.00      1.00         2
#   mediadive.medium:878       1.00      1.00      1.00         6
#   mediadive.medium:879       1.00      1.00      1.00         2
#   mediadive.medium:87a       1.00      1.00      1.00         2
#   mediadive.medium:882       1.00      1.00      1.00         2
#   mediadive.medium:895       1.00      1.00      1.00         2
#     mediadive.medium:9       1.00      1.00      1.00         4
#   mediadive.medium:900       1.00      1.00      1.00         2
#    mediadive.medium:92       1.00      1.00      1.00       209
#   mediadive.medium:921       1.00      1.00      1.00         3
#  mediadive.medium:924a       1.00      1.00      1.00         3
#   mediadive.medium:925       1.00      1.00      1.00         4
#   mediadive.medium:942       1.00      1.00      1.00         4
#   mediadive.medium:948       1.00      1.00      1.00         8
#   mediadive.medium:950       1.00      1.00      1.00         2
#   mediadive.medium:960       1.00      1.00      1.00         3
#   mediadive.medium:968       1.00      1.00      1.00         2
#    mediadive.medium:97       1.00      1.00      1.00         3
#    mediadive.medium:98       1.00      1.00      1.00        17
#   mediadive.medium:987       1.00      1.00      1.00        14
#   mediadive.medium:993       1.00      1.00      1.00         2
# mediadive.medium:J1000       1.00      1.00      1.00         2
#  mediadive.medium:J101       1.00      1.00      1.00         6
#  mediadive.medium:J104       1.00      1.00      1.00         9
# mediadive.medium:J1099       1.00      1.00      1.00         2
#  mediadive.medium:J111       1.00      1.00      1.00         3
#  mediadive.medium:J112       1.00      1.00      1.00         2
# mediadive.medium:J1130       1.00      1.00      1.00         9
#  mediadive.medium:J115       1.00      1.00      1.00         2
#  mediadive.medium:J118       1.00      1.00      1.00       296
#  mediadive.medium:J119       1.00      1.00      1.00         4
#   mediadive.medium:J12       1.00      1.00      1.00        39
# mediadive.medium:J1270       1.00      1.00      1.00         2
#   mediadive.medium:J13       1.00      1.00      1.00        55
#  mediadive.medium:J139       1.00      1.00      1.00         2
#   mediadive.medium:J14       1.00      1.00      1.00       104
#  mediadive.medium:J144       1.00      1.00      1.00         3
#  mediadive.medium:J151       1.00      1.00      1.00         3
#  mediadive.medium:J156       1.00      1.00      1.00         8
#  mediadive.medium:J161       1.00      1.00      1.00         2
#  mediadive.medium:J167       1.00      1.00      1.00        12
#  mediadive.medium:J168       1.00      1.00      1.00        36
#  mediadive.medium:J169       1.00      1.00      1.00         2
#  mediadive.medium:J172       1.00      1.00      1.00         3
#  mediadive.medium:J174       1.00      1.00      1.00         2
#  mediadive.medium:J181       1.00      1.00      1.00         8
#  mediadive.medium:J187       1.00      1.00      1.00         4
#   mediadive.medium:J19       1.00      1.00      1.00         6
#  mediadive.medium:J190       1.00      1.00      1.00         2
#  mediadive.medium:J198       1.00      1.00      1.00         2
#  mediadive.medium:J207       1.00      1.00      1.00         2
#  mediadive.medium:J217       1.00      1.00      1.00         2
#   mediadive.medium:J22       1.00      1.00      1.00       113
#  mediadive.medium:J221       1.00      1.00      1.00         2
#  mediadive.medium:J231       1.00      1.00      1.00         2
#  mediadive.medium:J232       1.00      1.00      1.00         5
#  mediadive.medium:J236       1.00      1.00      1.00         4
#  mediadive.medium:J254       1.00      1.00      1.00        15
#  mediadive.medium:J256       1.00      1.00      1.00        14
#   mediadive.medium:J26       1.00      1.00      1.00       124
#   mediadive.medium:J27       1.00      1.00      1.00        33
#  mediadive.medium:J276       1.00      1.00      1.00         4
#   mediadive.medium:J28       1.00      1.00      1.00        57
#  mediadive.medium:J280       1.00      1.00      1.00         4
#  mediadive.medium:J282       1.00      1.00      1.00         7
#  mediadive.medium:J291       1.00      1.00      1.00         2
#  mediadive.medium:J302       1.00      1.00      1.00         5
#  mediadive.medium:J346       1.00      1.00      1.00       104
#  mediadive.medium:J358       1.00      1.00      1.00         2
#  mediadive.medium:J363       1.00      1.00      1.00         2
#  mediadive.medium:J377       1.00      1.00      1.00         8
#  mediadive.medium:J386       1.00      1.00      1.00        34
#  mediadive.medium:J388       1.00      1.00      1.00         2
#  mediadive.medium:J389       1.00      1.00      1.00         2
#  mediadive.medium:J402       1.00      1.00      1.00         4
#  mediadive.medium:J409       1.00      1.00      1.00         2
#   mediadive.medium:J41       1.00      1.00      1.00        12
#  mediadive.medium:J415       1.00      1.00      1.00         2
#   mediadive.medium:J42       1.00      1.00      1.00        69
#   mediadive.medium:J43       1.00      1.00      1.00        87
#  mediadive.medium:J434       1.00      1.00      1.00         2
#  mediadive.medium:J436       1.00      1.00      1.00         6
#   mediadive.medium:J44       1.00      1.00      1.00         3
#  mediadive.medium:J443       1.00      1.00      1.00        29
#   mediadive.medium:J45       1.00      1.00      1.00         9
#  mediadive.medium:J455       1.00      1.00      1.00         3
#  mediadive.medium:J457       1.00      1.00      1.00         5
#  mediadive.medium:J465       1.00      1.00      1.00         4
#  mediadive.medium:J469       1.00      1.00      1.00         4
#  mediadive.medium:J475       1.00      1.00      1.00        32
#  mediadive.medium:J479       1.00      1.00      1.00         2
#   mediadive.medium:J48       1.00      1.00      1.00         3
#  mediadive.medium:J486       1.00      1.00      1.00         2
#  mediadive.medium:J487       1.00      1.00      1.00         2
#   mediadive.medium:J49       1.00      1.00      1.00         6
#   mediadive.medium:J50       1.00      1.00      1.00        19
#  mediadive.medium:J505       1.00      1.00      1.00         2
#   mediadive.medium:J51       1.00      1.00      1.00        18
#   mediadive.medium:J52       1.00      1.00      1.00        11
#  mediadive.medium:J528       1.00      1.00      1.00         3
#  mediadive.medium:J569       1.00      1.00      1.00         5
#   mediadive.medium:J57       1.00      1.00      1.00        17
#  mediadive.medium:J574       1.00      1.00      1.00         8
#   mediadive.medium:J58       1.00      1.00      1.00        19
#  mediadive.medium:J582       1.00      1.00      1.00         4
#  mediadive.medium:J586       1.00      1.00      1.00         3
#  mediadive.medium:J597       1.00      1.00      1.00         2
#   mediadive.medium:J61       1.00      1.00      1.00        13
#  mediadive.medium:J611       1.00      1.00      1.00         2
#  mediadive.medium:J632       1.00      1.00      1.00         2
#  mediadive.medium:J655       1.00      1.00      1.00         3
#   mediadive.medium:J66       1.00      1.00      1.00        25
#  mediadive.medium:J674       1.00      1.00      1.00         3
#  mediadive.medium:J675       1.00      1.00      1.00         3
#  mediadive.medium:J676       1.00      1.00      1.00         6
#  mediadive.medium:J677       1.00      1.00      1.00         3
#  mediadive.medium:J684       1.00      1.00      1.00         2
#   mediadive.medium:J69       1.00      1.00      1.00         2
#   mediadive.medium:J70       1.00      1.00      1.00         8
#  mediadive.medium:J709       1.00      1.00      1.00         6
#  mediadive.medium:J732       1.00      1.00      1.00         2
#  mediadive.medium:J736       1.00      1.00      1.00         2
#   mediadive.medium:J74       1.00      1.00      1.00        22
#  mediadive.medium:J746       1.00      1.00      1.00         4
#   mediadive.medium:J75       1.00      1.00      1.00        52
#  mediadive.medium:J786       1.00      1.00      1.00         3
#   mediadive.medium:J79       1.00      1.00      1.00         2
#  mediadive.medium:J811       1.00      1.00      1.00         3
#   mediadive.medium:J82       1.00      1.00      1.00         4
#   mediadive.medium:J83       1.00      1.00      1.00         5
#   mediadive.medium:J84       1.00      1.00      1.00        35
#  mediadive.medium:J842       1.00      1.00      1.00         2
#  mediadive.medium:J853       1.00      1.00      1.00         5
#  mediadive.medium:J946       1.00      1.00      1.00         3
#   mediadive.medium:J97       1.00      1.00      1.00         3
#
#               accuracy                           1.00      5488
#              macro avg       1.00      1.00      1.00      5488
#           weighted avg       1.00      1.00      1.00      5488

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# True labels are assumed to be in y_test
cm = confusion_matrix(y_test, y_pred_test)

plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.savefig('20240108_wembedding_traingreat3_test_confusion_matrix.pdf', format='pdf')
plt.show()

# %%
data_df_nomed = data_df_orig[data_df_orig['medium'].isna()]
data_df_nomed.shape
# Out:
# (20368, 268)

# %%
data_df_nomed_join_embed = data_df_nomed.join(node_embed, how='left')
data_df_nomed_join_embed
# Out:
#                    CHEBI:132943  CHEBI:133748  CHEBI:14321  CHEBI:15361  \
# subject
# NCBITaxon:1000560             0             0            0            0
# NCBITaxon:1000561             0             0            0            0
# NCBITaxon:1000565             0             0            0            0
# NCBITaxon:1000567             0             0            0            0
# NCBITaxon:1000569             0             0            0            0
# ...                         ...           ...          ...          ...
# NCBITaxon:999699              1             0            0            1
# NCBITaxon:999700              1             0            0            1
# NCBITaxon:999702              0             0            0            0
# NCBITaxon:999891              0             0            0            0
# NCBITaxon:999892              0             0            0            0
#
#                    CHEBI:15428  CHEBI:15792  CHEBI:15963  CHEBI:16015  \
# subject
# NCBITaxon:1000560            0            0            0            0
# NCBITaxon:1000561            0            0            0            0
# NCBITaxon:1000565            0            0            0            0
# NCBITaxon:1000567            0            0            0            0
# NCBITaxon:1000569            0            0            0            0
# ...                        ...          ...          ...          ...
# NCBITaxon:999699             0            0            0            0
# NCBITaxon:999700             0            0            0            0
# NCBITaxon:999702             0            0            0            0
# NCBITaxon:999891             0            0            0            0
# NCBITaxon:999892             0            0            0            0
#
#                    CHEBI:16133  CHEBI:16193  ...        90        91  \
# subject                                      ...
# NCBITaxon:1000560            0            0  ...  0.326048 -0.403403
# NCBITaxon:1000561            0            0  ...  0.810777  0.563194
# NCBITaxon:1000565            0            0  ...  1.863723  1.803987
# NCBITaxon:1000567            0            0  ... -0.181053  1.420939
# NCBITaxon:1000569            0            0  ... -0.406371 -1.705035
# ...                        ...          ...  ...       ...       ...
# NCBITaxon:999699             0            0  ...  0.270593  0.441660
# NCBITaxon:999700             0            0  ... -0.213614  0.237640
# NCBITaxon:999702             0            0  ...  1.255571  0.045797
# NCBITaxon:999891             0            0  ...  0.788727 -0.157221
# NCBITaxon:999892             0            0  ... -1.860199 -2.439441
#
#                          92        93        94        95        96        97  \
# subject
# NCBITaxon:1000560  1.397577 -0.262198 -0.771518 -0.663971 -0.657180 -2.693955
# NCBITaxon:1000561  1.720983  1.232392 -0.986182  0.605484  0.028389 -1.388129
# NCBITaxon:1000565 -0.319616  3.754146 -0.418830  0.998324  2.018780 -3.062002
# NCBITaxon:1000567  2.137796  1.840834 -0.281823 -0.186352  0.519962 -2.459532
# NCBITaxon:1000569 -0.344652  0.836237  0.068383  1.694684  1.989822 -2.177317
# ...                     ...       ...       ...       ...       ...       ...
# NCBITaxon:999699   1.466007  0.100871 -0.253739 -1.881985 -0.676012 -0.925026
# NCBITaxon:999700   1.385823  0.026044 -0.376723 -2.344338 -0.860686 -0.997028
# NCBITaxon:999702   2.323681  1.975510 -0.879350 -1.800230 -0.515825 -0.013546
# NCBITaxon:999891   1.797227  0.318751 -0.027281 -1.291286 -0.401950 -2.068124
# NCBITaxon:999892   0.674579 -0.064300  0.160082  0.249032  0.161491 -1.513511
#
#                          98        99
# subject
# NCBITaxon:1000560  0.516579 -1.049345
# NCBITaxon:1000561 -2.122279 -1.476511
# NCBITaxon:1000565 -1.767797  2.847243
# NCBITaxon:1000567 -0.802931  0.737540
# NCBITaxon:1000569  0.046372 -0.093318
# ...                     ...       ...
# NCBITaxon:999699  -1.742803  0.641783
# NCBITaxon:999700  -2.116375  0.720158
# NCBITaxon:999702  -0.828897  1.430358
# NCBITaxon:999891  -1.262965 -0.838779
# NCBITaxon:999892  -0.003463  1.779765
#
# [20368 rows x 368 columns]

# %%
data_df_join_embed2 = data_df_join_embed.join(node_embed2, how='left', lsuffix='_left', rsuffix='_right')
data_df_join_embed2
# Out:
#                    CHEBI:132943  CHEBI:133748  CHEBI:14321  CHEBI:15361  \
# subject
# NCBITaxon:100                 0             0            0            0
# NCBITaxon:1000568             0             0            0            0
# NCBITaxon:1001240             0             1            0            0
# NCBITaxon:1002367             0             0            0            0
# NCBITaxon:1002368             0             0            0            0
# ...                         ...           ...          ...          ...
# NCBITaxon:999550              0             0            0            0
# NCBITaxon:999552              0             0            0            0
# NCBITaxon:999611              0             0            0            0
# NCBITaxon:999894              0             0            0            0
# NCBITaxon:999931              0             0            0            0
#
#                    CHEBI:15428  CHEBI:15792  CHEBI:15963  CHEBI:16015  \
# subject
# NCBITaxon:100                0            0            0            0
# NCBITaxon:1000568            0            0            0            0
# NCBITaxon:1001240            0            1            0            0
# NCBITaxon:1002367            0            0            0            0
# NCBITaxon:1002368            0            0            0            0
# ...                        ...          ...          ...          ...
# NCBITaxon:999550             0            0            0            0
# NCBITaxon:999552             0            0            0            0
# NCBITaxon:999611             0            0            0            0
# NCBITaxon:999894             0            0            0            0
# NCBITaxon:999931             0            0            0            0
#
#                    CHEBI:16133  CHEBI:16193  ...  90_right  91_right  \
# subject                                      ...
# NCBITaxon:100                0            0  ...  3.893311 -1.145257
# NCBITaxon:1000568            0            0  ...  0.162629 -2.273246
# NCBITaxon:1001240            0            0  ...  1.029343  0.536299
# NCBITaxon:1002367            0            0  ...  0.960424 -0.780511
# NCBITaxon:1002368            0            0  ...  1.928981 -2.795320
# ...                        ...          ...  ...       ...       ...
# NCBITaxon:999550             0            0  ... -0.049724 -0.516063
# NCBITaxon:999552             0            0  ...  0.070490  1.371192
# NCBITaxon:999611             0            0  ...  1.084973 -2.020291
# NCBITaxon:999894             0            0  ...  2.085337 -1.646832
# NCBITaxon:999931             0            0  ...  2.522063 -1.444947
#
#                    92_right  93_right  94_right  95_right  96_right  97_right  \
# subject
# NCBITaxon:100     -3.463747 -0.252844  0.133187 -1.350825  0.083498  3.950952
# NCBITaxon:1000568 -0.231700 -1.809598  0.860964 -1.626807  2.129407  2.420233
# NCBITaxon:1001240 -1.034751  0.200735  0.113141 -2.872515  2.464246  1.199523
# NCBITaxon:1002367 -0.646330 -1.586410  0.755049 -0.351068  2.620379  2.629001
# NCBITaxon:1002368 -1.476254 -1.480178 -1.754710 -1.293914  2.666051  2.554238
# ...                     ...       ...       ...       ...       ...       ...
# NCBITaxon:999550  -1.122472 -0.143546 -0.048471 -2.532022 -0.995582  4.884026
# NCBITaxon:999552  -4.092691 -0.763367 -1.182081 -1.621842  1.111404  4.208204
# NCBITaxon:999611  -3.073536 -0.745622  0.092240 -2.240415  0.518260  2.996253
# NCBITaxon:999894  -1.290929  1.334986  2.118105 -1.841994  1.291684  1.864662
# NCBITaxon:999931  -2.763537 -1.992221  0.053032 -3.819162  1.247208  5.129158
#
#                    98_right  99_right
# subject
# NCBITaxon:100      1.296036  2.421812
# NCBITaxon:1000568 -0.656849  1.032531
# NCBITaxon:1001240  0.352270 -1.801784
# NCBITaxon:1002367 -0.215337  3.405646
# NCBITaxon:1002368  0.308699 -0.621719
# ...                     ...       ...
# NCBITaxon:999550   0.669134  0.102672
# NCBITaxon:999552   1.606825  0.705671
# NCBITaxon:999611  -0.029722  0.635136
# NCBITaxon:999894  -0.330740  0.479305
# NCBITaxon:999931   1.141941  2.124608
#
# [7839 rows x 468 columns]

# %%
X2 = data_df_join_embed2.drop('medium', axis=1)
y2 = data_df_join_embed2['medium']

# %%
X2.index
# Out:
# Index(['NCBITaxon:100', 'NCBITaxon:1000568', 'NCBITaxon:1001240',
#        'NCBITaxon:1002367', 'NCBITaxon:1002368', 'NCBITaxon:1002526',
#        'NCBITaxon:1003', 'NCBITaxon:1003091', 'NCBITaxon:1003110',
#        'NCBITaxon:1003195',
#        ...
#        'NCBITaxon:999543', 'NCBITaxon:999545', 'NCBITaxon:999547',
#        'NCBITaxon:999548', 'NCBITaxon:999549', 'NCBITaxon:999550',
#        'NCBITaxon:999552', 'NCBITaxon:999611', 'NCBITaxon:999894',
#        'NCBITaxon:999931'],
#       dtype='object', name='subject', length=7839)

# %%
# Predict on new data
predicted_classes = model.predict(X2)
probabilities = model.predict_proba(X2)
class_probabilities = probabilities[:, 1]
probabilities
# Out:
# array([[9.94399888e-03, 1.57971357e-05, 2.55332604e-05, ...,
#         6.11979819e-06, 4.93572294e-06, 1.86666861e-05],
#        [4.24962652e-06, 5.52412067e-07, 1.56747872e-07, ...,
#         8.08094466e-07, 2.16805801e-07, 7.13848246e-07],
#        [5.42997244e-02, 1.59074001e-04, 1.65176510e-04, ...,
#         3.22400329e-04, 6.92701860e-05, 4.11947415e-04],
#        ...,
#        [7.82310273e-05, 1.73835235e-06, 1.04054093e-06, ...,
#         1.05280854e-06, 4.09959328e-07, 4.63770799e-07],
#        [2.25916627e-04, 3.21384789e-05, 1.71699526e-05, ...,
#         3.05047582e-05, 1.18326142e-05, 8.62318656e-06],
#        [6.29906963e-03, 1.06522897e-04, 4.76752535e-05, ...,
#         1.85981425e-04, 4.12516534e-05, 1.25430410e-04]])

# %%
predicted_classes
# Out:
# array([['mediadive.medium:81'],
#        ['mediadive.medium:110'],
#        ['mediadive.medium:514'],
#        ...,
#        ['mediadive.medium:514'],
#        ['mediadive.medium:1210a'],
#        ['mediadive.medium:J26']], dtype=object)

# %%
X2.index.values
# Out:
# array(['NCBITaxon:100', 'NCBITaxon:1000568', 'NCBITaxon:1001240', ...,
#        'NCBITaxon:999611', 'NCBITaxon:999894', 'NCBITaxon:999931'],
#       dtype=object)

# %%
max_indices = np.argmax(probabilities, axis=1)

# Find the max values in each row
max_values = np.max(probabilities, axis=1)

# Combine row IDs, max values, and column IDs
result = np.column_stack((np.arange(probabilities.shape[0]), max_values, max_indices))

# Print the result
for row in result:
    print(row)
    print(f"Row ID: {X2.index.values[int(row[0])]}, Max Value: {row[1]}, Max Value Column ID: {predicted_classes[int(row[2])]}")
# Out:
# [  0.           0.92968147 171.        ]
# Row ID: NCBITaxon:100, Max Value: 0.9296814666193483, Max Value Column ID: ['mediadive.medium:J26']
# [ 1.          0.93726564 16.        ]
# Row ID: NCBITaxon:1000568, Max Value: 0.9372656426545244, Max Value Column ID: ['mediadive.medium:11']
# [  2.           0.23160626 117.        ]
# Row ID: NCBITaxon:1001240, Max Value: 0.23160625860987313, Max Value Column ID: ['mediadive.medium:J27']
# [  3.           0.76358027 217.        ]
# Row ID: NCBITaxon:1002367, Max Value: 0.7635802676234805, Max Value Column ID: ['mediadive.medium:65']
# [  4.           0.83463033 213.        ]
# Row ID: NCBITaxon:1002368, Max Value: 0.8346303328719149, Max Value Column ID: ['mediadive.medium:645']
# [  5.           0.90645542 234.        ]
# Row ID: NCBITaxon:1002526, Max Value: 0.9064554246965562, Max Value Column ID: ['mediadive.medium:J43']
# [ 6.          0.32772397 88.        ]
# Row ID: NCBITaxon:1003, Max Value: 0.32772396959748307, Max Value Column ID: ['mediadive.medium:585']
# [7.         0.88154782 0.        ]
# Row ID: NCBITaxon:1003091, Max Value: 0.8815478180702483, Max Value Column ID: ['mediadive.medium:81']
# [ 8.          0.88621409 70.        ]
# Row ID: NCBITaxon:1003110, Max Value: 0.8862140865394866, Max Value Column ID: ['mediadive.medium:830']
# [  9.           0.84859471 154.        ]
# Row ID: NCBITaxon:1003195, Max Value: 0.8485947111263668, Max Value Column ID: ['mediadive.medium:J26']
# [10.          0.56913045  0.        ]
# Row ID: NCBITaxon:1004165, Max Value: 0.5691304534954323, Max Value Column ID: ['mediadive.medium:81']
# [11.          0.97662183 55.        ]
# Row ID: NCBITaxon:1004166, Max Value: 0.976621834383228, Max Value Column ID: ['mediadive.medium:514']
# [ 12.           0.96218548 267.        ]
# Row ID: NCBITaxon:1004261, Max Value: 0.9621854806967556, Max Value Column ID: ['mediadive.medium:J118']
# [ 13.           0.98519179 200.        ]
# Row ID: NCBITaxon:1004279, Max Value: 0.9851917865620874, Max Value Column ID: ['mediadive.medium:144']
# [ 14.           0.63852498 176.        ]
# Row ID: NCBITaxon:1004304, Max Value: 0.6385249841745019, Max Value Column ID: ['mediadive.medium:J415']
# [ 15.           0.99432377 117.        ]
# Row ID: NCBITaxon:1004326, Max Value: 0.9943237650114786, Max Value Column ID: ['mediadive.medium:J27']
# [16.          0.88868732 15.        ]
# Row ID: NCBITaxon:100468, Max Value: 0.8886873192720905, Max Value Column ID: ['mediadive.medium:514']
# [17.          0.87873283 26.        ]
# Row ID: NCBITaxon:100469, Max Value: 0.8787328303408158, Max Value Column ID: ['mediadive.medium:J75']
# [ 18.           0.91899151 211.        ]
# Row ID: NCBITaxon:1005925, Max Value: 0.9189915112356877, Max Value Column ID: ['mediadive.medium:830c']
# [ 19.           0.98576948 211.        ]
# Row ID: NCBITaxon:1005926, Max Value: 0.985769483358172, Max Value Column ID: ['mediadive.medium:830c']
# [ 20.          0.7902471 211.       ]
# Row ID: NCBITaxon:1005928, Max Value: 0.7902470993839228, Max Value Column ID: ['mediadive.medium:830c']
# [ 21.           0.89436272 249.        ]
# Row ID: NCBITaxon:1005944, Max Value: 0.8943627206550435, Max Value Column ID: ['mediadive.medium:535']
# [ 22.           0.81647166 249.        ]
# Row ID: NCBITaxon:1005945, Max Value: 0.8164716643478147, Max Value Column ID: ['mediadive.medium:535']
# [23.          0.47667821 60.        ]
# Row ID: NCBITaxon:1005995, Max Value: 0.4766782138177287, Max Value Column ID: ['mediadive.medium:J118']
# [24.          0.90370544  0.        ]
# Row ID: NCBITaxon:1005996, Max Value: 0.9037054405777594, Max Value Column ID: ['mediadive.medium:81']
# [ 25.           0.79068871 213.        ]
# Row ID: NCBITaxon:1005999, Max Value: 0.7906887077390341, Max Value Column ID: ['mediadive.medium:645']
# [ 26.           0.80507391 306.        ]
# Row ID: NCBITaxon:1006000, Max Value: 0.8050739119242512, Max Value Column ID: ['mediadive.medium:311c']
# [ 27.          0.3451578 158.       ]
# Row ID: NCBITaxon:1006003, Max Value: 0.34515779953545045, Max Value Column ID: ['mediadive.medium:92']
# [ 28.           0.81882951 125.        ]
# Row ID: NCBITaxon:1006004, Max Value: 0.8188295143483239, Max Value Column ID: ['mediadive.medium:105']
# [ 29.           0.81789527 158.        ]
# Row ID: NCBITaxon:1006155, Max Value: 0.817895274759124, Max Value Column ID: ['mediadive.medium:92']
# [ 30.           0.49127893 125.        ]
# Row ID: NCBITaxon:1007097, Max Value: 0.4912789326656588, Max Value Column ID: ['mediadive.medium:105']
# [31.          0.92654668 42.        ]
# Row ID: NCBITaxon:1007098, Max Value: 0.9265466787045356, Max Value Column ID: ['mediadive.medium:514']
# [ 32.           0.69027382 249.        ]
# Row ID: NCBITaxon:1007511, Max Value: 0.6902738202966374, Max Value Column ID: ['mediadive.medium:535']
# [ 33.           0.95451788 176.        ]
# Row ID: NCBITaxon:1007516, Max Value: 0.954517878988478, Max Value Column ID: ['mediadive.medium:J415']
# [34.          0.98183116 15.        ]
# Row ID: NCBITaxon:1007676, Max Value: 0.9818311588780841, Max Value Column ID: ['mediadive.medium:514']
# [ 35.           0.97101418 309.        ]
# Row ID: NCBITaxon:1008460, Max Value: 0.9710141780157608, Max Value Column ID: ['mediadive.medium:J14']
# [36.          0.98412734 83.        ]
# Row ID: NCBITaxon:1009370, Max Value: 0.9841273352075675, Max Value Column ID: ['mediadive.medium:J168']
# [ 37.           0.84406753 234.        ]
# Row ID: NCBITaxon:1009852, Max Value: 0.8440675259917386, Max Value Column ID: ['mediadive.medium:J43']
# [38.          0.92306498  0.        ]
# Row ID: NCBITaxon:101059, Max Value: 0.9230649777540233, Max Value Column ID: ['mediadive.medium:81']
# [ 39.           0.74851168 176.        ]
# Row ID: NCBITaxon:1010610, Max Value: 0.7485116844831251, Max Value Column ID: ['mediadive.medium:J415']
# [ 40.           0.97028595 306.        ]
# Row ID: NCBITaxon:101070, Max Value: 0.9702859485316387, Max Value Column ID: ['mediadive.medium:311c']
# [ 41.           0.89403276 244.        ]
# Row ID: NCBITaxon:101489, Max Value: 0.8940327643322343, Max Value Column ID: ['mediadive.medium:J61']
# [ 42.           0.48635322 117.        ]
# Row ID: NCBITaxon:101564, Max Value: 0.4863532231940887, Max Value Column ID: ['mediadive.medium:J27']
# [43.          0.71552404 63.        ]
# Row ID: NCBITaxon:101571, Max Value: 0.7155240394564661, Max Value Column ID: ['mediadive.medium:J118']
# [ 44.           0.86327061 241.        ]
# Row ID: NCBITaxon:101689, Max Value: 0.8632706115834223, Max Value Column ID: ['mediadive.medium:J118']
# [ 45.           0.98035602 305.        ]
# Row ID: NCBITaxon:1017181, Max Value: 0.9803560209451986, Max Value Column ID: ['mediadive.medium:65']
# [ 46.           0.91039582 125.        ]
# Row ID: NCBITaxon:1017184, Max Value: 0.9103958245615513, Max Value Column ID: ['mediadive.medium:105']
# [ 47.           0.97916519 117.        ]
# Row ID: NCBITaxon:1017273, Max Value: 0.9791651927136024, Max Value Column ID: ['mediadive.medium:J27']
# [4.80000000e+01 9.67410428e-02 1.67000000e+02]
# Row ID: NCBITaxon:102134, Max Value: 0.09674104284177577, Max Value Column ID: ['mediadive.medium:1']
# [ 49.          0.9282882 217.       ]
# Row ID: NCBITaxon:102148, Max Value: 0.928288203126531, Max Value Column ID: ['mediadive.medium:65']
# [ 50.           0.83140628 261.        ]
# Row ID: NCBITaxon:102226, Max Value: 0.8314062805366969, Max Value Column ID: ['mediadive.medium:645']
# [ 51.           0.49819907 158.        ]
# Row ID: NCBITaxon:102618, Max Value: 0.49819907423588755, Max Value Column ID: ['mediadive.medium:92']
# [ 52.           0.94854013 158.        ]
# Row ID: NCBITaxon:102619, Max Value: 0.9485401255923763, Max Value Column ID: ['mediadive.medium:92']
# [53.          0.80432414 63.        ]
# Row ID: NCBITaxon:1027360, Max Value: 0.8043241419691283, Max Value Column ID: ['mediadive.medium:J118']
# [ 54.           0.88277245 244.        ]
# Row ID: NCBITaxon:1027633, Max Value: 0.8827724510139401, Max Value Column ID: ['mediadive.medium:J61']
# [ 55.          0.9332879 117.       ]
# Row ID: NCBITaxon:1028, Max Value: 0.9332879033579835, Max Value Column ID: ['mediadive.medium:J27']
# [ 56.           0.35599365 234.        ]
# Row ID: NCBITaxon:1028307, Max Value: 0.35599364886080154, Max Value Column ID: ['mediadive.medium:J43']
# [ 57.        0.81443 158.     ]
# Row ID: NCBITaxon:102862, Max Value: 0.8144300024960477, Max Value Column ID: ['mediadive.medium:92']
# [ 58.           0.96433669 211.        ]
# Row ID: NCBITaxon:1028742, Max Value: 0.9643366949125941, Max Value Column ID: ['mediadive.medium:830c']
# [ 59.           0.93633979 211.        ]
# Row ID: NCBITaxon:1028743, Max Value: 0.9363397938299617, Max Value Column ID: ['mediadive.medium:830c']
# [ 60.           0.83847246 211.        ]
# Row ID: NCBITaxon:1028745, Max Value: 0.8384724609390819, Max Value Column ID: ['mediadive.medium:830c']
# [ 61.           0.88373788 211.        ]
# Row ID: NCBITaxon:1028746, Max Value: 0.8837378792755878, Max Value Column ID: ['mediadive.medium:830c']
# [ 62.           0.99320596 211.        ]
# Row ID: NCBITaxon:1028749, Max Value: 0.9932059596035863, Max Value Column ID: ['mediadive.medium:830c']
# [ 63.           0.97790109 211.        ]
# Row ID: NCBITaxon:1028752, Max Value: 0.9779010889120848, Max Value Column ID: ['mediadive.medium:830c']
# [ 64.         0.835773 249.      ]
# Row ID: NCBITaxon:1031224, Max Value: 0.8357730005421191, Max Value Column ID: ['mediadive.medium:535']
# [ 65.           0.70590539 211.        ]
# Row ID: NCBITaxon:1031537, Max Value: 0.7059053895272779, Max Value Column ID: ['mediadive.medium:830c']
# [ 66.           0.97254291 211.        ]
# Row ID: NCBITaxon:1031538, Max Value: 0.9725429106814969, Max Value Column ID: ['mediadive.medium:830c']
# [ 67.           0.90581951 211.        ]
# Row ID: NCBITaxon:1031541, Max Value: 0.9058195139214953, Max Value Column ID: ['mediadive.medium:830c']
# [ 68.           0.90605102 158.        ]
# Row ID: NCBITaxon:1031542, Max Value: 0.906051017461098, Max Value Column ID: ['mediadive.medium:92']
# [ 69.           0.92525093 100.        ]
# Row ID: NCBITaxon:1031564, Max Value: 0.9252509287264238, Max Value Column ID: ['mediadive.medium:1a']
# [ 70.           0.56712576 176.        ]
# Row ID: NCBITaxon:1031594, Max Value: 0.5671257648415241, Max Value Column ID: ['mediadive.medium:J415']
# [ 71.           0.97321354 158.        ]
# Row ID: NCBITaxon:1032070, Max Value: 0.9732135358619707, Max Value Column ID: ['mediadive.medium:92']
# [ 72.           0.74755645 158.        ]
# Row ID: NCBITaxon:1032238, Max Value: 0.7475564546518432, Max Value Column ID: ['mediadive.medium:92']
# [ 73.           0.93464817 158.        ]
# Row ID: NCBITaxon:1032239, Max Value: 0.9346481720927291, Max Value Column ID: ['mediadive.medium:92']
# [ 74.           0.97607032 158.        ]
# Row ID: NCBITaxon:1032240, Max Value: 0.9760703196194569, Max Value Column ID: ['mediadive.medium:92']
# [ 75.           0.95315133 158.        ]
# Row ID: NCBITaxon:1032241, Max Value: 0.9531513266083155, Max Value Column ID: ['mediadive.medium:92']
# [76.         0.2960047 70.       ]
# Row ID: NCBITaxon:103232, Max Value: 0.29600469723556144, Max Value Column ID: ['mediadive.medium:830']
# [ 77.           0.28238099 154.        ]
# Row ID: NCBITaxon:1032476, Max Value: 0.2823809852698384, Max Value Column ID: ['mediadive.medium:J26']
# [ 78.           0.93538342 158.        ]
# Row ID: NCBITaxon:1032623, Max Value: 0.9353834177027037, Max Value Column ID: ['mediadive.medium:92']
# [79.          0.96870439 63.        ]
# Row ID: NCBITaxon:1033734, Max Value: 0.9687043879481645, Max Value Column ID: ['mediadive.medium:J118']
# [ 80.         0.907991 241.      ]
# Row ID: NCBITaxon:1033736, Max Value: 0.9079910024536965, Max Value Column ID: ['mediadive.medium:J118']
# [ 81.           0.97088803 190.        ]
# Row ID: NCBITaxon:1033739, Max Value: 0.9708880318848171, Max Value Column ID: ['mediadive.medium:28']
# [ 82.           0.98366652 190.        ]
# Row ID: NCBITaxon:1033740, Max Value: 0.9836665221995109, Max Value Column ID: ['mediadive.medium:28']
# [ 83.           0.97525608 223.        ]
# Row ID: NCBITaxon:1033806, Max Value: 0.9752560787375429, Max Value Column ID: ['mediadive.medium:693']
# [ 84.          0.9240296 117.       ]
# Row ID: NCBITaxon:1033846, Max Value: 0.9240296031984632, Max Value Column ID: ['mediadive.medium:J27']
# [85.          0.96071202 16.        ]
# Row ID: NCBITaxon:1034346, Max Value: 0.9607120246005584, Max Value Column ID: ['mediadive.medium:11']
# [ 86.           0.89178772 242.        ]
# Row ID: NCBITaxon:1034471, Max Value: 0.8917877176394495, Max Value Column ID: ['mediadive.medium:65']
# [ 87.           0.97003825 136.        ]
# Row ID: NCBITaxon:1034943, Max Value: 0.9700382461227954, Max Value Column ID: ['mediadive.medium:514']
# [ 88.          0.8742983 136.       ]
# Row ID: NCBITaxon:1034944, Max Value: 0.874298297892127, Max Value Column ID: ['mediadive.medium:514']
# [89.          0.91665116  0.        ]
# Row ID: NCBITaxon:1035, Max Value: 0.9166511588797145, Max Value Column ID: ['mediadive.medium:81']
# [ 90.           0.92868625 170.        ]
# Row ID: NCBITaxon:1035188, Max Value: 0.9286862473831081, Max Value Column ID: ['mediadive.medium:J26']
# [ 91.          0.8436459 158.       ]
# Row ID: NCBITaxon:1035194, Max Value: 0.8436458966744104, Max Value Column ID: ['mediadive.medium:92']
# [92.          0.93676629 27.        ]
# Row ID: NCBITaxon:1035196, Max Value: 0.9367662873094629, Max Value Column ID: ['mediadive.medium:693']
# [ 93.           0.93034507 176.        ]
# Row ID: NCBITaxon:1035707, Max Value: 0.9303450727390834, Max Value Column ID: ['mediadive.medium:J415']
# [ 94.           0.95101563 170.        ]
# Row ID: NCBITaxon:1035839, Max Value: 0.9510156291300641, Max Value Column ID: ['mediadive.medium:J26']
# [ 95.           0.86302394 211.        ]
# Row ID: NCBITaxon:1036133, Max Value: 0.8630239381195438, Max Value Column ID: ['mediadive.medium:830c']
# [ 96.           0.55619964 234.        ]
# Row ID: NCBITaxon:1036171, Max Value: 0.5561996413660292, Max Value Column ID: ['mediadive.medium:J43']
# [ 97.           0.85132492 261.        ]
# Row ID: NCBITaxon:1036181, Max Value: 0.8513249153703139, Max Value Column ID: ['mediadive.medium:645']
# [ 98.           0.89669599 280.        ]
# Row ID: NCBITaxon:1036182, Max Value: 0.8966959875501966, Max Value Column ID: ['mediadive.medium:215']
# [ 99.           0.25073192 176.        ]
# Row ID: NCBITaxon:1036677, Max Value: 0.25073191786164206, Max Value Column ID: ['mediadive.medium:J415']
# [100.           0.86924621  55.        ]
# Row ID: NCBITaxon:1036778, Max Value: 0.8692462089049673, Max Value Column ID: ['mediadive.medium:514']
# [101.           0.96498738   0.        ]
# Row ID: NCBITaxon:1036779, Max Value: 0.9649873825019657, Max Value Column ID: ['mediadive.medium:81']
# [102.           0.98014763   0.        ]
# Row ID: NCBITaxon:1036780, Max Value: 0.9801476309597986, Max Value Column ID: ['mediadive.medium:81']
# [103.           0.96361395  48.        ]
# Row ID: NCBITaxon:103690, Max Value: 0.9636139472796913, Max Value Column ID: ['mediadive.medium:78']
# [104.           0.79328693 178.        ]
# Row ID: NCBITaxon:103725, Max Value: 0.793286929558674, Max Value Column ID: ['mediadive.medium:84']
# [105.           0.83362706 154.        ]
# Row ID: NCBITaxon:103732, Max Value: 0.8336270622433889, Max Value Column ID: ['mediadive.medium:J26']
# [106.          0.9264379 234.       ]
# Row ID: NCBITaxon:1037320, Max Value: 0.9264378969452359, Max Value Column ID: ['mediadive.medium:J43']
# [107.         0.529502 154.      ]
# Row ID: NCBITaxon:103733, Max Value: 0.5295019991494226, Max Value Column ID: ['mediadive.medium:J26']
# [108.           0.64748611 217.        ]
# Row ID: NCBITaxon:1037355, Max Value: 0.6474861083425101, Max Value Column ID: ['mediadive.medium:65']
# [109.          0.7308519 211.       ]
# Row ID: NCBITaxon:1037362, Max Value: 0.7308519023622971, Max Value Column ID: ['mediadive.medium:830c']
# [110.           0.89391653 306.        ]
# Row ID: NCBITaxon:103815, Max Value: 0.8939165250822843, Max Value Column ID: ['mediadive.medium:311c']
# [111.           0.54686943 125.        ]
# Row ID: NCBITaxon:103816, Max Value: 0.5468694312648135, Max Value Column ID: ['mediadive.medium:105']
# [112.           0.71780794 125.        ]
# Row ID: NCBITaxon:103817, Max Value: 0.7178079395812106, Max Value Column ID: ['mediadive.medium:105']
# [113.           0.46877463 154.        ]
# Row ID: NCBITaxon:103836, Max Value: 0.4687746274526767, Max Value Column ID: ['mediadive.medium:J26']
# [114.           0.94532685 175.        ]
# Row ID: NCBITaxon:103837, Max Value: 0.9453268481979455, Max Value Column ID: ['mediadive.medium:11']
# [115.           0.85688143 154.        ]
# Row ID: NCBITaxon:103838, Max Value: 0.8568814250416139, Max Value Column ID: ['mediadive.medium:J26']
# [116.          0.9386412 240.       ]
# Row ID: NCBITaxon:103855, Max Value: 0.93864120382023, Max Value Column ID: ['mediadive.medium:11']
# [117.           0.94999876 242.        ]
# Row ID: NCBITaxon:1038845, Max Value: 0.9499987635098505, Max Value Column ID: ['mediadive.medium:65']
# [118.           0.82545162 234.        ]
# Row ID: NCBITaxon:1038855, Max Value: 0.8254516228534847, Max Value Column ID: ['mediadive.medium:J43']
# [119.           0.61579606 117.        ]
# Row ID: NCBITaxon:1038856, Max Value: 0.6157960582837189, Max Value Column ID: ['mediadive.medium:J27']
# [120.           0.97694592  63.        ]
# Row ID: NCBITaxon:1038869, Max Value: 0.9769459157164898, Max Value Column ID: ['mediadive.medium:J118']
# [121.          0.8297841 217.       ]
# Row ID: NCBITaxon:103891, Max Value: 0.8297841044889828, Max Value Column ID: ['mediadive.medium:65']
# [122.           0.88879759 217.        ]
# Row ID: NCBITaxon:103892, Max Value: 0.888797589528929, Max Value Column ID: ['mediadive.medium:65']
# [123.           0.55385689 154.        ]
# Row ID: NCBITaxon:1038929, Max Value: 0.5538568930348817, Max Value Column ID: ['mediadive.medium:J26']
# [124.           0.95848966 127.        ]
# Row ID: NCBITaxon:104087, Max Value: 0.9584896641795217, Max Value Column ID: ['mediadive.medium:J597']
# [125.           0.49494152  10.        ]
# Row ID: NCBITaxon:104097, Max Value: 0.49494151883857185, Max Value Column ID: ['mediadive.medium:1']
# [126.         0.963433 301.      ]
# Row ID: NCBITaxon:104100, Max Value: 0.9634329952196696, Max Value Column ID: ['mediadive.medium:J43']
# [127.          0.9397958 288.       ]
# Row ID: NCBITaxon:104101, Max Value: 0.9397957984036686, Max Value Column ID: ['mediadive.medium:J346']
# [128.           0.96742189 239.        ]
# Row ID: NCBITaxon:1041147, Max Value: 0.9674218904307145, Max Value Column ID: ['mediadive.medium:514']
# [129.         0.885371 253.      ]
# Row ID: NCBITaxon:1041522, Max Value: 0.8853710039554804, Max Value Column ID: ['mediadive.medium:535']
# [130.           0.95512518  55.        ]
# Row ID: NCBITaxon:1041641, Max Value: 0.9551251764483855, Max Value Column ID: ['mediadive.medium:514']
# [131.           0.80954007 261.        ]
# Row ID: NCBITaxon:104206, Max Value: 0.8095400734915879, Max Value Column ID: ['mediadive.medium:645']
# [132.           0.98897233 211.        ]
# Row ID: NCBITaxon:1042376, Max Value: 0.9889723339227534, Max Value Column ID: ['mediadive.medium:830c']
# [133.          0.5393871 211.       ]
# Row ID: NCBITaxon:104269, Max Value: 0.5393871004101828, Max Value Column ID: ['mediadive.medium:830c']
# [134.          0.6391788 154.       ]
# Row ID: NCBITaxon:1043168, Max Value: 0.6391788033563707, Max Value Column ID: ['mediadive.medium:J26']
# [135.          0.8723236 190.       ]
# Row ID: NCBITaxon:104336, Max Value: 0.8723235994313807, Max Value Column ID: ['mediadive.medium:28']
# [136.           0.72191599 117.        ]
# Row ID: NCBITaxon:1043493, Max Value: 0.7219159888303238, Max Value Column ID: ['mediadive.medium:J27']
# [137.           0.78258553 117.        ]
# Row ID: NCBITaxon:1044, Max Value: 0.7825855277695682, Max Value Column ID: ['mediadive.medium:J27']
# [138.           0.83246362 178.        ]
# Row ID: NCBITaxon:1045501, Max Value: 0.8324636165527043, Max Value Column ID: ['mediadive.medium:84']
# [139.          0.8803808 271.       ]
# Row ID: NCBITaxon:1045773, Max Value: 0.8803807987913981, Max Value Column ID: ['mediadive.medium:925']
# [140.           0.56452884 241.        ]
# Row ID: NCBITaxon:1045774, Max Value: 0.5645288381205754, Max Value Column ID: ['mediadive.medium:J118']
# [141.           0.94636427  63.        ]
# Row ID: NCBITaxon:1045775, Max Value: 0.9463642747246659, Max Value Column ID: ['mediadive.medium:J118']
# [142.           0.84020861 154.        ]
# Row ID: NCBITaxon:1045776, Max Value: 0.8402086071219227, Max Value Column ID: ['mediadive.medium:J26']
# [143.          0.9199393 117.       ]
# Row ID: NCBITaxon:104609, Max Value: 0.9199392951248295, Max Value Column ID: ['mediadive.medium:J27']
# [144.           0.99026834 211.        ]
# Row ID: NCBITaxon:1046117, Max Value: 0.9902683442174725, Max Value Column ID: ['mediadive.medium:830c']
# [145.          0.9573235 241.       ]
# Row ID: NCBITaxon:1046555, Max Value: 0.9573235011004042, Max Value Column ID: ['mediadive.medium:J118']
# [146.           0.74865846 190.        ]
# Row ID: NCBITaxon:1046556, Max Value: 0.7486584558290494, Max Value Column ID: ['mediadive.medium:28']
# [147.           0.88329653 215.        ]
# Row ID: NCBITaxon:1046593, Max Value: 0.8832965281114542, Max Value Column ID: ['mediadive.medium:84']
# [148.           0.98141564  15.        ]
# Row ID: NCBITaxon:1046599, Max Value: 0.9814156443761722, Max Value Column ID: ['mediadive.medium:514']
# [149.           0.67696676  76.        ]
# Row ID: NCBITaxon:1048, Max Value: 0.6769667610223267, Max Value Column ID: ['mediadive.medium:252']
# [150.           0.90235478 154.        ]
# Row ID: NCBITaxon:1048339, Max Value: 0.9023547831056629, Max Value Column ID: ['mediadive.medium:J26']
# [151.          0.2960085   0.       ]
# Row ID: NCBITaxon:1048340, Max Value: 0.2960085039723862, Max Value Column ID: ['mediadive.medium:81']
# [152.           0.25132776 154.        ]
# Row ID: NCBITaxon:1048357, Max Value: 0.25132776189561085, Max Value Column ID: ['mediadive.medium:J26']
# [153.           0.89365544 176.        ]
# Row ID: NCBITaxon:1048394, Max Value: 0.8936554350994245, Max Value Column ID: ['mediadive.medium:J415']
# [154.           0.89424414 241.        ]
# Row ID: NCBITaxon:1048753, Max Value: 0.8942441433828058, Max Value Column ID: ['mediadive.medium:J118']
# [155.           0.98577783  76.        ]
# Row ID: NCBITaxon:1049, Max Value: 0.9857778276689925, Max Value Column ID: ['mediadive.medium:252']
# [156.          0.9423157 117.       ]
# Row ID: NCBITaxon:1049199, Max Value: 0.9423156995160255, Max Value Column ID: ['mediadive.medium:J27']
# [157.           0.84266632 244.        ]
# Row ID: NCBITaxon:1050153, Max Value: 0.8426663193159246, Max Value Column ID: ['mediadive.medium:J61']
# [158.           0.42515352 190.        ]
# Row ID: NCBITaxon:1050174, Max Value: 0.4251535187350252, Max Value Column ID: ['mediadive.medium:28']
# [159.           0.94315541 117.        ]
# Row ID: NCBITaxon:1050198, Max Value: 0.9431554128178212, Max Value Column ID: ['mediadive.medium:J27']
# [160.           0.52549507 234.        ]
# Row ID: NCBITaxon:1051501, Max Value: 0.5254950699525137, Max Value Column ID: ['mediadive.medium:J43']
# [161.           0.95647373 249.        ]
# Row ID: NCBITaxon:1051626, Max Value: 0.9564737253736321, Max Value Column ID: ['mediadive.medium:535']
# [162.           0.98181324 117.        ]
# Row ID: NCBITaxon:1051646, Max Value: 0.9818132352553153, Max Value Column ID: ['mediadive.medium:J27']
# [163.           0.99123896 117.        ]
# Row ID: NCBITaxon:1051649, Max Value: 0.9912389643716657, Max Value Column ID: ['mediadive.medium:J27']
# [164.           0.87367411 190.        ]
# Row ID: NCBITaxon:1051981, Max Value: 0.8736741064650271, Max Value Column ID: ['mediadive.medium:28']
# [165.           0.95423287 100.        ]
# Row ID: NCBITaxon:1051985, Max Value: 0.9542328678410518, Max Value Column ID: ['mediadive.medium:1a']
# [166.           0.97816432  71.        ]
# Row ID: NCBITaxon:1052, Max Value: 0.9781643165706826, Max Value Column ID: ['mediadive.medium:693']
# [167.           0.38123717   0.        ]
# Row ID: NCBITaxon:105219, Max Value: 0.3812371711904654, Max Value Column ID: ['mediadive.medium:81']
# [168.           0.91712001 249.        ]
# Row ID: NCBITaxon:1052257, Max Value: 0.9171200116831274, Max Value Column ID: ['mediadive.medium:535']
# [169.         0.845401 176.      ]
# Row ID: NCBITaxon:1052258, Max Value: 0.8454009967377384, Max Value Column ID: ['mediadive.medium:J415']
# [170.          0.9738278 241.       ]
# Row ID: NCBITaxon:1052259, Max Value: 0.9738278006802379, Max Value Column ID: ['mediadive.medium:J118']
# [171.           0.94862697 241.        ]
# Row ID: NCBITaxon:1052260, Max Value: 0.9486269705670295, Max Value Column ID: ['mediadive.medium:J118']
# [172.           0.41769883 261.        ]
# Row ID: NCBITaxon:1053547, Max Value: 0.4176988312833972, Max Value Column ID: ['mediadive.medium:645']
# [173.           0.93715029 241.        ]
# Row ID: NCBITaxon:1053688, Max Value: 0.9371502865017425, Max Value Column ID: ['mediadive.medium:J118']
# [174.           0.43292507  76.        ]
# Row ID: NCBITaxon:1054, Max Value: 0.4329250674096573, Max Value Column ID: ['mediadive.medium:252']
# [175.           0.98718411  15.        ]
# Row ID: NCBITaxon:1054041, Max Value: 0.9871841121571808, Max Value Column ID: ['mediadive.medium:514']
# [176.          0.9678113 259.       ]
# Row ID: NCBITaxon:105420, Max Value: 0.967811299822484, Max Value Column ID: ['mediadive.medium:J43']
# [177.           0.76136153 260.        ]
# Row ID: NCBITaxon:1054860, Max Value: 0.7613615283286671, Max Value Column ID: ['mediadive.medium:J57']
# [178.           0.30911402 178.        ]
# Row ID: NCBITaxon:1054862, Max Value: 0.3091140172408525, Max Value Column ID: ['mediadive.medium:84']
# [179.           0.95780722  55.        ]
# Row ID: NCBITaxon:1055355, Max Value: 0.9578072213950282, Max Value Column ID: ['mediadive.medium:514']
# [180.           0.68042033 154.        ]
# Row ID: NCBITaxon:1055466, Max Value: 0.6804203345088959, Max Value Column ID: ['mediadive.medium:J26']
# [181.           0.86911772 211.        ]
# Row ID: NCBITaxon:1055723, Max Value: 0.8691177168036149, Max Value Column ID: ['mediadive.medium:830c']
# [182.           0.95566385 215.        ]
# Row ID: NCBITaxon:105612, Max Value: 0.9556638478369228, Max Value Column ID: ['mediadive.medium:84']
# [183.           0.97254502 238.        ]
# Row ID: NCBITaxon:1056495, Max Value: 0.9725450200651725, Max Value Column ID: ['mediadive.medium:J118']
# [184.           0.95960387 117.        ]
# Row ID: NCBITaxon:1056511, Max Value: 0.9596038688547502, Max Value Column ID: ['mediadive.medium:J27']
# [185.           0.99408624 211.        ]
# Row ID: NCBITaxon:1056512, Max Value: 0.9940862394552397, Max Value Column ID: ['mediadive.medium:830c']
# [186.           0.94521061 190.        ]
# Row ID: NCBITaxon:1056807, Max Value: 0.9452106098773347, Max Value Column ID: ['mediadive.medium:28']
# [187.           0.36081129 241.        ]
# Row ID: NCBITaxon:1056982, Max Value: 0.36081129288757474, Max Value Column ID: ['mediadive.medium:J118']
# [188.           0.98274843  76.        ]
# Row ID: NCBITaxon:1057, Max Value: 0.9827484264396125, Max Value Column ID: ['mediadive.medium:252']
# [189.           0.84771035  63.        ]
# Row ID: NCBITaxon:105751, Max Value: 0.8477103488365227, Max Value Column ID: ['mediadive.medium:J118']
# [190.           0.99029638  76.        ]
# Row ID: NCBITaxon:1058, Max Value: 0.9902963782512968, Max Value Column ID: ['mediadive.medium:252']
# [191.           0.95772315 250.        ]
# Row ID: NCBITaxon:1061, Max Value: 0.9577231494928272, Max Value Column ID: ['mediadive.medium:535']
# [192.          0.6629795  74.       ]
# Row ID: NCBITaxon:1063, Max Value: 0.6629795003136976, Max Value Column ID: ['mediadive.medium:693']
# [193.           0.57928981 154.        ]
# Row ID: NCBITaxon:106411, Max Value: 0.5792898134495449, Max Value Column ID: ['mediadive.medium:J26']
# [194.           0.89470482 154.        ]
# Row ID: NCBITaxon:106412, Max Value: 0.8947048225546194, Max Value Column ID: ['mediadive.medium:J26']
# [195.           0.89165747 154.        ]
# Row ID: NCBITaxon:106413, Max Value: 0.8916574744272769, Max Value Column ID: ['mediadive.medium:J26']
# [196.           0.94566733  63.        ]
# Row ID: NCBITaxon:1064516, Max Value: 0.9456673260823956, Max Value Column ID: ['mediadive.medium:J118']
# [197.           0.99001027  63.        ]
# Row ID: NCBITaxon:1064517, Max Value: 0.9900102663939566, Max Value Column ID: ['mediadive.medium:J118']
# [198.           0.98875146  63.        ]
# Row ID: NCBITaxon:1064518, Max Value: 0.9887514577868517, Max Value Column ID: ['mediadive.medium:J118']
# [199.           0.62260006 217.        ]
# Row ID: NCBITaxon:1064535, Max Value: 0.6226000589730439, Max Value Column ID: ['mediadive.medium:65']
# [200.           0.95996808  41.        ]
# Row ID: NCBITaxon:106578, Max Value: 0.9599680762096016, Max Value Column ID: ['mediadive.medium:J28']
# [201.          0.9217362  99.       ]
# Row ID: NCBITaxon:106590, Max Value: 0.9217361953495176, Max Value Column ID: ['mediadive.medium:830']
# [202.          0.9519705 106.       ]
# Row ID: NCBITaxon:106592, Max Value: 0.9519704963425458, Max Value Column ID: ['mediadive.medium:J22']
# [203.           0.98216614  74.        ]
# Row ID: NCBITaxon:1066, Max Value: 0.9821661424499217, Max Value Column ID: ['mediadive.medium:693']
# [204.           0.91459793 306.        ]
# Row ID: NCBITaxon:106648, Max Value: 0.9145979257687287, Max Value Column ID: ['mediadive.medium:311c']
# [205.           0.84227375  74.        ]
# Row ID: NCBITaxon:1067, Max Value: 0.8422737503460259, Max Value Column ID: ['mediadive.medium:693']
# [206.           0.86684651 261.        ]
# Row ID: NCBITaxon:1068978, Max Value: 0.8668465099390743, Max Value Column ID: ['mediadive.medium:645']
# [207.           0.82742891 261.        ]
# Row ID: NCBITaxon:1068979, Max Value: 0.8274289101647573, Max Value Column ID: ['mediadive.medium:645']
# [208.          0.7707552 261.       ]
# Row ID: NCBITaxon:1068980, Max Value: 0.7707551984183354, Max Value Column ID: ['mediadive.medium:645']
# [209.           0.94363995  73.        ]
# Row ID: NCBITaxon:1069, Max Value: 0.943639945728087, Max Value Column ID: ['mediadive.medium:693']
# [210.           0.97058399 110.        ]
# Row ID: NCBITaxon:1069080, Max Value: 0.9705839926888712, Max Value Column ID: ['mediadive.medium:J75']
# [211.           0.98314858 177.        ]
# Row ID: NCBITaxon:1069161, Max Value: 0.9831485803244616, Max Value Column ID: ['mediadive.medium:J42']
# [212.           0.93121307 253.        ]
# Row ID: NCBITaxon:1069220, Max Value: 0.9312130741906689, Max Value Column ID: ['mediadive.medium:535']
# [213.           0.87953768 153.        ]
# Row ID: NCBITaxon:1069221, Max Value: 0.8795376829879401, Max Value Column ID: ['mediadive.medium:830']
# [214.           0.98778486  15.        ]
# Row ID: NCBITaxon:1070421, Max Value: 0.9877848586496457, Max Value Column ID: ['mediadive.medium:514']
# [215.           0.83447572 178.        ]
# Row ID: NCBITaxon:1070424, Max Value: 0.8344757221991241, Max Value Column ID: ['mediadive.medium:84']
# [216.           0.90116301 261.        ]
# Row ID: NCBITaxon:1070866, Max Value: 0.901163006541481, Max Value Column ID: ['mediadive.medium:645']
# [217.           0.87050655 154.        ]
# Row ID: NCBITaxon:1070982, Max Value: 0.8705065473666879, Max Value Column ID: ['mediadive.medium:J26']
# [218.           0.97323859  63.        ]
# Row ID: NCBITaxon:1071052, Max Value: 0.9732385948143943, Max Value Column ID: ['mediadive.medium:J118']
# [219.           0.86827464  63.        ]
# Row ID: NCBITaxon:1071053, Max Value: 0.8682746440149861, Max Value Column ID: ['mediadive.medium:J118']
# [220.           0.89813241  63.        ]
# Row ID: NCBITaxon:1071054, Max Value: 0.8981324070544958, Max Value Column ID: ['mediadive.medium:J118']
# [221.           0.82009919 176.        ]
# Row ID: NCBITaxon:1071679, Max Value: 0.8200991936683318, Max Value Column ID: ['mediadive.medium:J415']
# [222.          0.8855529 158.       ]
# Row ID: NCBITaxon:1071918, Max Value: 0.8855529026783034, Max Value Column ID: ['mediadive.medium:92']
# [223.           0.79316707 158.        ]
# Row ID: NCBITaxon:1071947, Max Value: 0.7931670712432736, Max Value Column ID: ['mediadive.medium:92']
# [224.           0.96192524 212.        ]
# Row ID: NCBITaxon:1071983, Max Value: 0.9619252386011233, Max Value Column ID: ['mediadive.medium:J386']
# [225.           0.91245531 244.        ]
# Row ID: NCBITaxon:1072256, Max Value: 0.9124553119856696, Max Value Column ID: ['mediadive.medium:J61']
# [226.          0.8595983 190.       ]
# Row ID: NCBITaxon:1072463, Max Value: 0.8595983002381262, Max Value Column ID: ['mediadive.medium:28']
# [227.           0.99604245 117.        ]
# Row ID: NCBITaxon:1072583, Max Value: 0.9960424486271812, Max Value Column ID: ['mediadive.medium:J27']
# [228.           0.90203503 158.        ]
# Row ID: NCBITaxon:1072685, Max Value: 0.9020350323735312, Max Value Column ID: ['mediadive.medium:92']
# [229.           0.78174426 154.        ]
# Row ID: NCBITaxon:1073253, Max Value: 0.7817442560334634, Max Value Column ID: ['mediadive.medium:J26']
# [230.           0.95282803 117.        ]
# Row ID: NCBITaxon:107327, Max Value: 0.9528280260663641, Max Value Column ID: ['mediadive.medium:J27']
# [231.           0.75582132 117.        ]
# Row ID: NCBITaxon:1073327, Max Value: 0.7558213159207445, Max Value Column ID: ['mediadive.medium:J27']
# [232.           0.77139992 117.        ]
# Row ID: NCBITaxon:1073328, Max Value: 0.7713999195430169, Max Value Column ID: ['mediadive.medium:J27']
# [233.           0.55391402 117.        ]
# Row ID: NCBITaxon:1073330, Max Value: 0.5539140203397523, Max Value Column ID: ['mediadive.medium:J27']
# [234.           0.95789204 261.        ]
# Row ID: NCBITaxon:1073574, Max Value: 0.9578920391958805, Max Value Column ID: ['mediadive.medium:645']
# [235.           0.98491016   0.        ]
# Row ID: NCBITaxon:1073999, Max Value: 0.984910164217118, Max Value Column ID: ['mediadive.medium:81']
# [236.           0.95354492  73.        ]
# Row ID: NCBITaxon:1074, Max Value: 0.9535449192912219, Max Value Column ID: ['mediadive.medium:693']
# [237.           0.76071134 125.        ]
# Row ID: NCBITaxon:1074000, Max Value: 0.7607113411197887, Max Value Column ID: ['mediadive.medium:105']
# [238.           0.93581842 211.        ]
# Row ID: NCBITaxon:107401, Max Value: 0.9358184174901436, Max Value Column ID: ['mediadive.medium:830c']
# [239.           0.80944088 117.        ]
# Row ID: NCBITaxon:1074311, Max Value: 0.8094408790262512, Max Value Column ID: ['mediadive.medium:J27']
# [240.           0.98662707  15.        ]
# Row ID: NCBITaxon:1074467, Max Value: 0.9866270714867731, Max Value Column ID: ['mediadive.medium:514']
# [241.           0.98025352 211.        ]
# Row ID: NCBITaxon:1074488, Max Value: 0.9802535187480176, Max Value Column ID: ['mediadive.medium:830c']
# [242.           0.73170491 154.        ]
# Row ID: NCBITaxon:1075090, Max Value: 0.7317049131679104, Max Value Column ID: ['mediadive.medium:J26']
# [243.           0.77425083   0.        ]
# Row ID: NCBITaxon:1076124, Max Value: 0.7742508268604881, Max Value Column ID: ['mediadive.medium:81']
# [244.           0.85426457 289.        ]
# Row ID: NCBITaxon:1076125, Max Value: 0.8542645664345931, Max Value Column ID: ['mediadive.medium:J346']
# [245.          0.7403024 132.       ]
# Row ID: NCBITaxon:1076126, Max Value: 0.7403023978415899, Max Value Column ID: ['mediadive.medium:J118']
# [246.           0.70213384  63.        ]
# Row ID: NCBITaxon:1076330, Max Value: 0.7021338356048386, Max Value Column ID: ['mediadive.medium:J118']
# [247.           0.90311946 158.        ]
# Row ID: NCBITaxon:1076331, Max Value: 0.9031194586504537, Max Value Column ID: ['mediadive.medium:92']
# [248.           0.96861916  81.        ]
# Row ID: NCBITaxon:1076414, Max Value: 0.9686191614463875, Max Value Column ID: ['mediadive.medium:92']
# [249.           0.87650002 125.        ]
# Row ID: NCBITaxon:1076549, Max Value: 0.8765000247968264, Max Value Column ID: ['mediadive.medium:105']
# [250.           0.45047019 125.        ]
# Row ID: NCBITaxon:1076550, Max Value: 0.450470193941792, Max Value Column ID: ['mediadive.medium:105']
# [251.           0.86395994 125.        ]
# Row ID: NCBITaxon:1076551, Max Value: 0.8639599439085075, Max Value Column ID: ['mediadive.medium:105']
# [252.          0.9669774 301.       ]
# Row ID: NCBITaxon:1076596, Max Value: 0.9669774033502271, Max Value Column ID: ['mediadive.medium:J43']
# [253.           0.87541878 125.        ]
# Row ID: NCBITaxon:1076620, Max Value: 0.8754187820269795, Max Value Column ID: ['mediadive.medium:105']
# [254.           0.91001046 176.        ]
# Row ID: NCBITaxon:1076937, Max Value: 0.910010462828172, Max Value Column ID: ['mediadive.medium:J415']
# [255.           0.43935468 217.        ]
# Row ID: NCBITaxon:1077285, Max Value: 0.439354684832443, Max Value Column ID: ['mediadive.medium:65']
# [256.           0.32522779 158.        ]
# Row ID: NCBITaxon:1077464, Max Value: 0.3252277902585183, Max Value Column ID: ['mediadive.medium:92']
# [257.           0.83917818 158.        ]
# Row ID: NCBITaxon:1077675, Max Value: 0.8391781801486217, Max Value Column ID: ['mediadive.medium:92']
# [258.           0.93022244 154.        ]
# Row ID: NCBITaxon:1077942, Max Value: 0.930222437789774, Max Value Column ID: ['mediadive.medium:J26']
# [259.           0.88935774 261.        ]
# Row ID: NCBITaxon:1077974, Max Value: 0.8893577414896717, Max Value Column ID: ['mediadive.medium:645']
# [260.           0.92181825 283.        ]
# Row ID: NCBITaxon:1077975, Max Value: 0.9218182531359489, Max Value Column ID: ['mediadive.medium:1a']
# [261.           0.73281583 153.        ]
# Row ID: NCBITaxon:1078020, Max Value: 0.7328158343793567, Max Value Column ID: ['mediadive.medium:830']
# [262.           0.98461553 193.        ]
# Row ID: NCBITaxon:107820, Max Value: 0.9846155280960114, Max Value Column ID: ['mediadive.medium:65']
# [263.           0.91930579 306.        ]
# Row ID: NCBITaxon:1078475, Max Value: 0.9193057881688164, Max Value Column ID: ['mediadive.medium:311c']
# [264.           0.94042663  74.        ]
# Row ID: NCBITaxon:1079, Max Value: 0.9404266262335431, Max Value Column ID: ['mediadive.medium:693']
# [265.           0.92146653 200.        ]
# Row ID: NCBITaxon:1079109, Max Value: 0.92146653082649, Max Value Column ID: ['mediadive.medium:144']
# [266.           0.99253379 211.        ]
# Row ID: NCBITaxon:1079178, Max Value: 0.9925337874159447, Max Value Column ID: ['mediadive.medium:830c']
# [267.           0.98965683 211.        ]
# Row ID: NCBITaxon:1079179, Max Value: 0.9896568307054212, Max Value Column ID: ['mediadive.medium:830c']
# [268.           0.90519839 176.        ]
# Row ID: NCBITaxon:1079859, Max Value: 0.9051983907766923, Max Value Column ID: ['mediadive.medium:J415']
# [269.           0.91414864 126.        ]
# Row ID: NCBITaxon:1079988, Max Value: 0.9141486428328732, Max Value Column ID: ['mediadive.medium:J709']
# [270.           0.99208483  74.        ]
# Row ID: NCBITaxon:1080, Max Value: 0.9920848344672643, Max Value Column ID: ['mediadive.medium:693']
# [271.           0.97802496 193.        ]
# Row ID: NCBITaxon:108003, Max Value: 0.9780249649766842, Max Value Column ID: ['mediadive.medium:65']
# [272.           0.46245359 158.        ]
# Row ID: NCBITaxon:1080071, Max Value: 0.4624535876667503, Max Value Column ID: ['mediadive.medium:92']
# [273.           0.70552767 190.        ]
# Row ID: NCBITaxon:1080072, Max Value: 0.7055276718542194, Max Value Column ID: ['mediadive.medium:28']
# [274.           0.83646529 132.        ]
# Row ID: NCBITaxon:1080073, Max Value: 0.836465285391875, Max Value Column ID: ['mediadive.medium:J118']
# [275.           0.88899034 279.        ]
# Row ID: NCBITaxon:1080074, Max Value: 0.8889903351670096, Max Value Column ID: ['mediadive.medium:671']
# [276.           0.80470822 211.        ]
# Row ID: NCBITaxon:1080221, Max Value: 0.8047082160966583, Max Value Column ID: ['mediadive.medium:830c']
# [277.           0.30198696 190.        ]
# Row ID: NCBITaxon:1081040, Max Value: 0.3019869599853905, Max Value Column ID: ['mediadive.medium:28']
# [278.           0.96032729 125.        ]
# Row ID: NCBITaxon:1081097, Max Value: 0.9603272929781195, Max Value Column ID: ['mediadive.medium:105']
# [279.           0.95158672 156.        ]
# Row ID: NCBITaxon:108150, Max Value: 0.9515867168747807, Max Value Column ID: ['mediadive.medium:514']
# [280.           0.99384926  60.        ]
# Row ID: NCBITaxon:1081736, Max Value: 0.9938492565963886, Max Value Column ID: ['mediadive.medium:J118']
# [281.          0.9666963  74.       ]
# Row ID: NCBITaxon:1082, Max Value: 0.9666962999061648, Max Value Column ID: ['mediadive.medium:693']
# [282.           0.97528288 176.        ]
# Row ID: NCBITaxon:1082345, Max Value: 0.9752828785953171, Max Value Column ID: ['mediadive.medium:J415']
# [283.           0.43749437  55.        ]
# Row ID: NCBITaxon:1082580, Max Value: 0.4374943729975286, Max Value Column ID: ['mediadive.medium:514']
# [284.           0.88165916 234.        ]
# Row ID: NCBITaxon:1082851, Max Value: 0.8816591633184029, Max Value Column ID: ['mediadive.medium:J43']
# [285.          0.9540759 211.       ]
# Row ID: NCBITaxon:1082931, Max Value: 0.9540759016532241, Max Value Column ID: ['mediadive.medium:830c']
# [286.          0.9909821  74.       ]
# Row ID: NCBITaxon:1084, Max Value: 0.9909820966488705, Max Value Column ID: ['mediadive.medium:693']
# [287.           0.43236838 211.        ]
# Row ID: NCBITaxon:1084519, Max Value: 0.4323683782837382, Max Value Column ID: ['mediadive.medium:830c']
# [288.           0.98601985 249.        ]
# Row ID: NCBITaxon:1084522, Max Value: 0.9860198489507073, Max Value Column ID: ['mediadive.medium:535']
# [289.          0.9443536 249.       ]
# Row ID: NCBITaxon:1084523, Max Value: 0.9443535970865767, Max Value Column ID: ['mediadive.medium:535']
# [290.           0.89218467 249.        ]
# Row ID: NCBITaxon:1084524, Max Value: 0.8921846701045247, Max Value Column ID: ['mediadive.medium:535']
# [291.           0.83302521 249.        ]
# Row ID: NCBITaxon:1084525, Max Value: 0.8330252120401356, Max Value Column ID: ['mediadive.medium:535']
# [292.           0.93861306 249.        ]
# Row ID: NCBITaxon:1084526, Max Value: 0.9386130552783143, Max Value Column ID: ['mediadive.medium:535']
# [293.           0.89910413 125.        ]
# Row ID: NCBITaxon:108486, Max Value: 0.8991041315068798, Max Value Column ID: ['mediadive.medium:105']
# [294.           0.98793961  74.        ]
# Row ID: NCBITaxon:1085, Max Value: 0.9879396109507647, Max Value Column ID: ['mediadive.medium:693']
# [295.           0.82469877 190.        ]
# Row ID: NCBITaxon:1087479, Max Value: 0.8246987662674828, Max Value Column ID: ['mediadive.medium:28']
# [296.           0.83579521   0.        ]
# Row ID: NCBITaxon:1087481, Max Value: 0.8357952055669735, Max Value Column ID: ['mediadive.medium:81']
# [297.           0.97562684 305.        ]
# Row ID: NCBITaxon:1088868, Max Value: 0.9756268383569044, Max Value Column ID: ['mediadive.medium:65']
# [298.           0.96807184 305.        ]
# Row ID: NCBITaxon:1088869, Max Value: 0.9680718378811051, Max Value Column ID: ['mediadive.medium:65']
# [299.           0.97965448 102.        ]
# Row ID: NCBITaxon:1088883, Max Value: 0.9796544841524711, Max Value Column ID: ['mediadive.medium:1']
# [300.          0.9392195 211.       ]
# Row ID: NCBITaxon:1089439, Max Value: 0.9392194976993518, Max Value Column ID: ['mediadive.medium:830c']
# [301.           0.70253078 261.        ]
# Row ID: NCBITaxon:1089453, Max Value: 0.7025307837831349, Max Value Column ID: ['mediadive.medium:645']
# [302.           0.94391611 169.        ]
# Row ID: NCBITaxon:1089454, Max Value: 0.9439161054078918, Max Value Column ID: ['mediadive.medium:830']
# [303.           0.45749557 211.        ]
# Row ID: NCBITaxon:1089455, Max Value: 0.45749557325691426, Max Value Column ID: ['mediadive.medium:830c']
# [304.           0.93700441 283.        ]
# Row ID: NCBITaxon:1089544, Max Value: 0.9370044098517047, Max Value Column ID: ['mediadive.medium:1a']
# [305.           0.84679125 154.        ]
# Row ID: NCBITaxon:1089545, Max Value: 0.8467912490972003, Max Value Column ID: ['mediadive.medium:J26']
# [306.           0.97896689  83.        ]
# Row ID: NCBITaxon:1089548, Max Value: 0.9789668916107155, Max Value Column ID: ['mediadive.medium:J168']
# [307.           0.62449352 190.        ]
# Row ID: NCBITaxon:108980, Max Value: 0.6244935186717235, Max Value Column ID: ['mediadive.medium:28']
# [308.           0.85418588 306.        ]
# Row ID: NCBITaxon:1091042, Max Value: 0.8541858770214482, Max Value Column ID: ['mediadive.medium:311c']
# [309.           0.64736444 217.        ]
# Row ID: NCBITaxon:1091045, Max Value: 0.6473644381560233, Max Value Column ID: ['mediadive.medium:65']
# [310.           0.71843738 241.        ]
# Row ID: NCBITaxon:1091046, Max Value: 0.7184373752509933, Max Value Column ID: ['mediadive.medium:J118']
# [311.           0.93090786  77.        ]
# Row ID: NCBITaxon:1092, Max Value: 0.9309078617477508, Max Value Column ID: ['mediadive.medium:65']
# [312.           0.99599143 129.        ]
# Row ID: NCBITaxon:1094466, Max Value: 0.99599142665459, Max Value Column ID: ['mediadive.medium:J386']
# [313.           0.95445309 100.        ]
# Row ID: NCBITaxon:1094553, Max Value: 0.9544530893525468, Max Value Column ID: ['mediadive.medium:1a']
# [314.           0.98367773 100.        ]
# Row ID: NCBITaxon:1094555, Max Value: 0.9836777288780973, Max Value Column ID: ['mediadive.medium:1a']
# [315.           0.93326484 117.        ]
# Row ID: NCBITaxon:1095025, Max Value: 0.9332648366011292, Max Value Column ID: ['mediadive.medium:J27']
# [316.           0.70187663 117.        ]
# Row ID: NCBITaxon:1095026, Max Value: 0.7018766287286556, Max Value Column ID: ['mediadive.medium:J27']
# [317.           0.91171412 190.        ]
# Row ID: NCBITaxon:1095729, Max Value: 0.9117141214378554, Max Value Column ID: ['mediadive.medium:28']
# [318.           0.82357375 242.        ]
# Row ID: NCBITaxon:1095731, Max Value: 0.8235737548065064, Max Value Column ID: ['mediadive.medium:65']
# [319.           0.98868156 170.        ]
# Row ID: NCBITaxon:1095744, Max Value: 0.9886815606927962, Max Value Column ID: ['mediadive.medium:J26']
# [320.           0.92721853 311.        ]
# Row ID: NCBITaxon:1095747, Max Value: 0.9272185338127213, Max Value Column ID: ['mediadive.medium:29']
# [321.           0.58733843 158.        ]
# Row ID: NCBITaxon:1095749, Max Value: 0.5873384283135435, Max Value Column ID: ['mediadive.medium:92']
# [322.           0.71996577 222.        ]
# Row ID: NCBITaxon:1095777, Max Value: 0.7199657674468153, Max Value Column ID: ['mediadive.medium:693']
# [323.           0.59725453 222.        ]
# Row ID: NCBITaxon:1095778, Max Value: 0.5972545349629569, Max Value Column ID: ['mediadive.medium:693']
# [324.           0.97809528 100.        ]
# Row ID: NCBITaxon:1095900, Max Value: 0.9780952836529643, Max Value Column ID: ['mediadive.medium:1a']
# [325.           0.97404434 307.        ]
# Row ID: NCBITaxon:1096341, Max Value: 0.9740443426940206, Max Value Column ID: ['mediadive.medium:92']
# [326.           0.85401318 234.        ]
# Row ID: NCBITaxon:1096779, Max Value: 0.8540131794978949, Max Value Column ID: ['mediadive.medium:J43']
# [327.           0.97164807  77.        ]
# Row ID: NCBITaxon:1097, Max Value: 0.9716480667066522, Max Value Column ID: ['mediadive.medium:65']
# [328.           0.50018345 176.        ]
# Row ID: NCBITaxon:1097667, Max Value: 0.5001834460050133, Max Value Column ID: ['mediadive.medium:J415']
# [329.          0.9673315  94.       ]
# Row ID: NCBITaxon:1098, Max Value: 0.967331496859213, Max Value Column ID: ['mediadive.medium:804']
# [330.           0.97898046 217.        ]
# Row ID: NCBITaxon:1099853, Max Value: 0.9789804611741098, Max Value Column ID: ['mediadive.medium:65']
# [331.           0.98408276   0.        ]
# Row ID: NCBITaxon:110, Max Value: 0.9840827581040941, Max Value Column ID: ['mediadive.medium:81']
# [332.           0.98339483  94.        ]
# Row ID: NCBITaxon:1100, Max Value: 0.9833948252379751, Max Value Column ID: ['mediadive.medium:804']
# [333.           0.85081905 249.        ]
# ...
# [7.7320000e+03 3.6668834e-01 2.3300000e+02]
# Row ID: NCBITaxon:97193, Max Value: 0.36668833971097364, Max Value Column ID: ['mediadive.medium:514']
# [7.73300000e+03 5.47209354e-01 1.78000000e+02]
# Row ID: NCBITaxon:97398, Max Value: 0.5472093540202699, Max Value Column ID: ['mediadive.medium:84']
# [7.73400000e+03 9.06504811e-01 8.50000000e+01]
# Row ID: NCBITaxon:97478, Max Value: 0.9065048109006739, Max Value Column ID: ['mediadive.medium:110']
# [7.73500000e+03 9.32789048e-01 1.76000000e+02]
# Row ID: NCBITaxon:977880, Max Value: 0.9327890481535988, Max Value Column ID: ['mediadive.medium:J415']
# [7.73600000e+03 7.99805836e-01 1.17000000e+02]
# Row ID: NCBITaxon:979, Max Value: 0.7998058360126514, Max Value Column ID: ['mediadive.medium:J27']
# [7.7370000e+03 8.3162399e-01 1.7600000e+02]
# Row ID: NCBITaxon:979226, Max Value: 0.8316239902972377, Max Value Column ID: ['mediadive.medium:J415']
# [7.73800000e+03 9.76001225e-01 9.00000000e+00]
# Row ID: NCBITaxon:979627, Max Value: 0.976001224607711, Max Value Column ID: ['mediadive.medium:65']
# [7.73900000e+03 9.36796793e-01 1.90000000e+02]
# Row ID: NCBITaxon:979746, Max Value: 0.93679679337682, Max Value Column ID: ['mediadive.medium:28']
# [7.74000000e+03 4.77143289e-01 1.41000000e+02]
# Row ID: NCBITaxon:980254, Max Value: 0.4771432886533053, Max Value Column ID: ['mediadive.medium:220']
# [7.74100000e+03 9.48082367e-01 1.16000000e+02]
# Row ID: NCBITaxon:980427, Max Value: 0.9480823669951075, Max Value Column ID: ['mediadive.medium:J256']
# [7.74200000e+03 8.00265541e-01 0.00000000e+00]
# Row ID: NCBITaxon:980518, Max Value: 0.8002655411030868, Max Value Column ID: ['mediadive.medium:81']
# [7.74300000e+03 9.54960315e-01 5.50000000e+01]
# Row ID: NCBITaxon:980631, Max Value: 0.9549603152768023, Max Value Column ID: ['mediadive.medium:514']
# [7.74400000e+03 9.55102945e-01 2.11000000e+02]
# Row ID: NCBITaxon:981, Max Value: 0.9551029452256443, Max Value Column ID: ['mediadive.medium:830c']
# [7.74500000e+03 9.97445806e-01 6.30000000e+01]
# Row ID: NCBITaxon:981324, Max Value: 0.9974458058269914, Max Value Column ID: ['mediadive.medium:J118']
# [7.74600000e+03 3.74889024e-01 0.00000000e+00]
# Row ID: NCBITaxon:981327, Max Value: 0.3748890238987857, Max Value Column ID: ['mediadive.medium:81']
# [7.74700000e+03 8.68990471e-01 2.13000000e+02]
# Row ID: NCBITaxon:981331, Max Value: 0.868990470681956, Max Value Column ID: ['mediadive.medium:645']
# [7.74800000e+03 9.74376346e-01 6.30000000e+01]
# Row ID: NCBITaxon:981333, Max Value: 0.9743763456421459, Max Value Column ID: ['mediadive.medium:J118']
# [7.7490000e+03 9.1697715e-01 2.3400000e+02]
# Row ID: NCBITaxon:981334, Max Value: 0.9169771503496685, Max Value Column ID: ['mediadive.medium:J43']
# [7.75000000e+03 4.04579536e-01 0.00000000e+00]
# Row ID: NCBITaxon:981336, Max Value: 0.4045795355527481, Max Value Column ID: ['mediadive.medium:81']
# [7.75100000e+03 8.65416756e-01 1.78000000e+02]
# Row ID: NCBITaxon:981369, Max Value: 0.8654167562802675, Max Value Column ID: ['mediadive.medium:84']
# [7.75200000e+03 7.77926859e-01 2.11000000e+02]
# Row ID: NCBITaxon:981381, Max Value: 0.777926858920331, Max Value Column ID: ['mediadive.medium:830c']
# [7.75300000e+03 8.69197397e-01 2.11000000e+02]
# Row ID: NCBITaxon:981384, Max Value: 0.8691973969552064, Max Value Column ID: ['mediadive.medium:830c']
# [7.7540000e+03 6.8048997e-01 1.5800000e+02]
# Row ID: NCBITaxon:981386, Max Value: 0.6804899696542882, Max Value Column ID: ['mediadive.medium:92']
# [7.75500000e+03 9.09400246e-01 2.34000000e+02]
# Row ID: NCBITaxon:983, Max Value: 0.9094002458099432, Max Value Column ID: ['mediadive.medium:J43']
# [7.75600000e+03 9.52719516e-01 1.58000000e+02]
# Row ID: NCBITaxon:983328, Max Value: 0.9527195156353747, Max Value Column ID: ['mediadive.medium:92']
# [7.75700000e+03 8.22075845e-01 1.58000000e+02]
# Row ID: NCBITaxon:983594, Max Value: 0.8220758454413439, Max Value Column ID: ['mediadive.medium:92']
# [7.75800000e+03 8.35896351e-01 2.41000000e+02]
# Row ID: NCBITaxon:983873, Max Value: 0.8358963510746696, Max Value Column ID: ['mediadive.medium:J118']
# [7.7590000e+03 5.6084014e-01 5.5000000e+01]
# Row ID: NCBITaxon:983920, Max Value: 0.5608401396812251, Max Value Column ID: ['mediadive.medium:514']
# [7.7600000e+03 9.5040834e-01 2.0000000e+02]
# Row ID: NCBITaxon:984260, Max Value: 0.9504083402015218, Max Value Column ID: ['mediadive.medium:144']
# [7.76100000e+03 6.78876232e-01 1.90000000e+02]
# Row ID: NCBITaxon:985002, Max Value: 0.6788762315298074, Max Value Column ID: ['mediadive.medium:28']
# [7.76200000e+03 3.07198539e-01 1.25000000e+02]
# Row ID: NCBITaxon:985012, Max Value: 0.3071985392430847, Max Value Column ID: ['mediadive.medium:105']
# [7.76300000e+03 9.80244422e-01 2.11000000e+02]
# Row ID: NCBITaxon:985043, Max Value: 0.9802444215537267, Max Value Column ID: ['mediadive.medium:830c']
# [7.76400000e+03 7.38391117e-01 1.17000000e+02]
# Row ID: NCBITaxon:985054, Max Value: 0.738391117140395, Max Value Column ID: ['mediadive.medium:J27']
# [7.76500000e+03 8.67290561e-01 1.17000000e+02]
# Row ID: NCBITaxon:985055, Max Value: 0.8672905614207846, Max Value Column ID: ['mediadive.medium:J27']
# [7.76600000e+03 7.96376226e-01 0.00000000e+00]
# Row ID: NCBITaxon:985079, Max Value: 0.7963762260034054, Max Value Column ID: ['mediadive.medium:81']
# [7.76700000e+03 9.12822994e-01 1.90000000e+02]
# Row ID: NCBITaxon:985762, Max Value: 0.9128229936756268, Max Value Column ID: ['mediadive.medium:28']
# [7.76800000e+03 5.49535746e-01 2.34000000e+02]
# Row ID: NCBITaxon:986, Max Value: 0.5495357461892824, Max Value Column ID: ['mediadive.medium:J43']
# [7.76900000e+03 9.62408229e-01 2.44000000e+02]
# Row ID: NCBITaxon:98671, Max Value: 0.962408228821383, Max Value Column ID: ['mediadive.medium:J61']
# [7.77000000e+03 8.84252252e-01 1.58000000e+02]
# Row ID: NCBITaxon:986710, Max Value: 0.8842522523603634, Max Value Column ID: ['mediadive.medium:92']
# [7.77100000e+03 7.46759182e-01 1.32000000e+02]
# Row ID: NCBITaxon:986711, Max Value: 0.7467591821026377, Max Value Column ID: ['mediadive.medium:J118']
# [7.77200000e+03 8.20197569e-01 1.17000000e+02]
# Row ID: NCBITaxon:986746, Max Value: 0.8201975688831085, Max Value Column ID: ['mediadive.medium:J27']
# [7.77300000e+03 8.13769967e-01 1.32000000e+02]
# Row ID: NCBITaxon:987045, Max Value: 0.8137699670328412, Max Value Column ID: ['mediadive.medium:J118']
# [7.77400000e+03 7.95123672e-01 1.76000000e+02]
# Row ID: NCBITaxon:987056, Max Value: 0.795123671686461, Max Value Column ID: ['mediadive.medium:J415']
# [7.77500000e+03 9.42181295e-01 2.44000000e+02]
# Row ID: NCBITaxon:988821, Max Value: 0.9421812947969994, Max Value Column ID: ['mediadive.medium:J61']
# [7.77600000e+03 9.46160389e-01 2.11000000e+02]
# Row ID: NCBITaxon:989, Max Value: 0.9461603890863226, Max Value Column ID: ['mediadive.medium:830c']
# [7.77700000e+03 8.73346494e-01 1.17000000e+02]
# Row ID: NCBITaxon:989403, Max Value: 0.873346494033596, Max Value Column ID: ['mediadive.medium:J27']
# [7.77800000e+03 9.86169302e-01 1.11000000e+02]
# Row ID: NCBITaxon:990, Max Value: 0.986169301747183, Max Value Column ID: ['mediadive.medium:535']
# [7.77900000e+03 8.63403708e-01 2.11000000e+02]
# Row ID: NCBITaxon:990268, Max Value: 0.8634037084983598, Max Value Column ID: ['mediadive.medium:830c']
# [7.78000000e+03 6.31741982e-01 2.11000000e+02]
# Row ID: NCBITaxon:990271, Max Value: 0.6317419818937253, Max Value Column ID: ['mediadive.medium:830c']
# [7.781000e+03 9.834531e-01 2.000000e+02]
# Row ID: NCBITaxon:990284, Max Value: 0.983453100220908, Max Value Column ID: ['mediadive.medium:144']
# [7.78200000e+03 9.93125133e-01 0.00000000e+00]
# Row ID: NCBITaxon:990287, Max Value: 0.9931251332670417, Max Value Column ID: ['mediadive.medium:81']
# [7.78300000e+03 9.49705885e-01 1.76000000e+02]
# Row ID: NCBITaxon:990371, Max Value: 0.949705884947792, Max Value Column ID: ['mediadive.medium:J415']
# [7.78400000e+03 7.64003012e-01 1.76000000e+02]
# Row ID: NCBITaxon:990373, Max Value: 0.7640030124712157, Max Value Column ID: ['mediadive.medium:J415']
# [7.78500000e+03 6.98106618e-01 1.17000000e+02]
# Row ID: NCBITaxon:990712, Max Value: 0.6981066181537535, Max Value Column ID: ['mediadive.medium:J27']
# [7.78600000e+03 9.09331338e-01 1.17000000e+02]
# Row ID: NCBITaxon:990998, Max Value: 0.9093313380965143, Max Value Column ID: ['mediadive.medium:J27']
# [7.7870000e+03 9.7313461e-01 1.5500000e+02]
# Row ID: NCBITaxon:991, Max Value: 0.9731346096926444, Max Value Column ID: ['mediadive.medium:28']
# [7.78800000e+03 8.33990741e-01 2.41000000e+02]
# Row ID: NCBITaxon:991009, Max Value: 0.8339907410494041, Max Value Column ID: ['mediadive.medium:J118']
# [7.78900000e+03 5.62147801e-01 1.90000000e+02]
# Row ID: NCBITaxon:99117, Max Value: 0.562147801167709, Max Value Column ID: ['mediadive.medium:28']
# [7.79000000e+03 8.53171667e-01 2.17000000e+02]
# Row ID: NCBITaxon:991789, Max Value: 0.8531716670422846, Max Value Column ID: ['mediadive.medium:65']
# [7.79100000e+03 8.12586336e-01 2.17000000e+02]
# Row ID: NCBITaxon:991791, Max Value: 0.8125863361015323, Max Value Column ID: ['mediadive.medium:65']
# [7.79200000e+03 7.42299117e-01 1.17000000e+02]
# Row ID: NCBITaxon:992267, Max Value: 0.7422991172762522, Max Value Column ID: ['mediadive.medium:J27']
# [7.793000e+03 4.797142e-01 1.200000e+01]
# Row ID: NCBITaxon:992286, Max Value: 0.4797142003318322, Max Value Column ID: ['mediadive.medium:J455']
# [7.79400000e+03 9.71105126e-01 2.11000000e+02]
# Row ID: NCBITaxon:992289, Max Value: 0.9711051256709287, Max Value Column ID: ['mediadive.medium:830c']
# [7.79500000e+03 9.00396887e-01 2.41000000e+02]
# Row ID: NCBITaxon:993084, Max Value: 0.9003968874814554, Max Value Column ID: ['mediadive.medium:J118']
# [7.79600000e+03 9.77671132e-01 2.41000000e+02]
# Row ID: NCBITaxon:993086, Max Value: 0.9776711318234139, Max Value Column ID: ['mediadive.medium:J118']
# [7.79700000e+03 9.65629175e-01 2.41000000e+02]
# Row ID: NCBITaxon:993087, Max Value: 0.9656291747689318, Max Value Column ID: ['mediadive.medium:J118']
# [7.79800000e+03 8.69731874e-01 2.61000000e+02]
# Row ID: NCBITaxon:993414, Max Value: 0.8697318744356343, Max Value Column ID: ['mediadive.medium:645']
# [7.79900000e+03 9.26428694e-01 1.90000000e+02]
# Row ID: NCBITaxon:993416, Max Value: 0.9264286939152536, Max Value Column ID: ['mediadive.medium:28']
# [7.80000000e+03 9.45164101e-01 1.50000000e+01]
# Row ID: NCBITaxon:993692, Max Value: 0.9451641005131943, Max Value Column ID: ['mediadive.medium:514']
# [7.80100000e+03 9.66112793e-01 2.11000000e+02]
# Row ID: NCBITaxon:994319, Max Value: 0.9661127928893475, Max Value Column ID: ['mediadive.medium:830c']
# [7.80200000e+03 9.24352659e-01 2.11000000e+02]
# Row ID: NCBITaxon:994320, Max Value: 0.924352658805977, Max Value Column ID: ['mediadive.medium:830c']
# [7.80300000e+03 8.59888648e-01 1.54000000e+02]
# Row ID: NCBITaxon:994479, Max Value: 0.859888648374828, Max Value Column ID: ['mediadive.medium:J26']
# [7.80400000e+03 3.17440945e-01 2.41000000e+02]
# Row ID: NCBITaxon:995038, Max Value: 0.3174409454425507, Max Value Column ID: ['mediadive.medium:J118']
# [7.80500000e+03 9.59034667e-01 1.46000000e+02]
# Row ID: NCBITaxon:995050, Max Value: 0.9590346671659488, Max Value Column ID: ['mediadive.medium:92']
# [7.80600000e+03 9.61210932e-01 1.27000000e+02]
# Row ID: NCBITaxon:995054, Max Value: 0.9612109318133519, Max Value Column ID: ['mediadive.medium:J597']
# [7.8070000e+03 9.4986476e-01 2.0000000e+01]
# Row ID: NCBITaxon:995066, Max Value: 0.9498647597827391, Max Value Column ID: ['mediadive.medium:J118']
# [7.80800000e+03 8.21777052e-01 2.49000000e+02]
# Row ID: NCBITaxon:996, Max Value: 0.8217770524823141, Max Value Column ID: ['mediadive.medium:535']
# [7.80900000e+03 9.64064607e-01 1.17000000e+02]
# Row ID: NCBITaxon:996115, Max Value: 0.9640646069458191, Max Value Column ID: ['mediadive.medium:J27']
# [7.81000000e+03 8.26394483e-01 1.17000000e+02]
# Row ID: NCBITaxon:996342, Max Value: 0.826394482586964, Max Value Column ID: ['mediadive.medium:J27']
# [7.81100000e+03 7.31090063e-01 1.54000000e+02]
# Row ID: NCBITaxon:996641, Max Value: 0.7310900625159409, Max Value Column ID: ['mediadive.medium:J26']
# [7.8120000e+03 8.7982112e-01 2.1700000e+02]
# Row ID: NCBITaxon:99675, Max Value: 0.8798211200549106, Max Value Column ID: ['mediadive.medium:65']
# [7.81300000e+03 9.69353557e-01 4.10000000e+01]
# Row ID: NCBITaxon:996765, Max Value: 0.9693535569053712, Max Value Column ID: ['mediadive.medium:J28']
# [7.81400000e+03 7.28274821e-01 1.58000000e+02]
# Row ID: NCBITaxon:997347, Max Value: 0.728274821472203, Max Value Column ID: ['mediadive.medium:92']
# [7.815000e+03 9.956106e-01 1.000000e+02]
# Row ID: NCBITaxon:997348, Max Value: 0.9956106004243996, Max Value Column ID: ['mediadive.medium:1a']
# [7.81600000e+03 9.22395244e-01 5.00000000e+00]
# Row ID: NCBITaxon:997349, Max Value: 0.9223952441049604, Max Value Column ID: ['mediadive.medium:J22']
# [7.81700000e+03 8.68017156e-01 5.00000000e+00]
# Row ID: NCBITaxon:997350, Max Value: 0.8680171555665755, Max Value Column ID: ['mediadive.medium:J22']
# [7.81800000e+03 8.55652565e-01 5.00000000e+00]
# Row ID: NCBITaxon:997352, Max Value: 0.8556525653959992, Max Value Column ID: ['mediadive.medium:J22']
# [7.81900000e+03 8.65331019e-01 5.00000000e+00]
# Row ID: NCBITaxon:997353, Max Value: 0.8653310187954165, Max Value Column ID: ['mediadive.medium:J22']
# [7.82000000e+03 9.34871133e-01 5.00000000e+00]
# Row ID: NCBITaxon:997355, Max Value: 0.9348711329630515, Max Value Column ID: ['mediadive.medium:J22']
# [7.82100000e+03 8.98038153e-01 2.41000000e+02]
# Row ID: NCBITaxon:99807, Max Value: 0.898038153470445, Max Value Column ID: ['mediadive.medium:J118']
# [7.82200000e+03 9.20296792e-01 1.17000000e+02]
# Row ID: NCBITaxon:998674, Max Value: 0.9202967916538635, Max Value Column ID: ['mediadive.medium:J27']
# [7.82300000e+03 6.20019835e-01 1.58000000e+02]
# Row ID: NCBITaxon:999183, Max Value: 0.6200198353551389, Max Value Column ID: ['mediadive.medium:92']
# [7.82400000e+03 8.62614667e-01 3.12000000e+02]
# Row ID: NCBITaxon:999415, Max Value: 0.8626146673843144, Max Value Column ID: ['mediadive.medium:545']
# [7.82500000e+03 9.85640833e-01 2.18000000e+02]
# Row ID: NCBITaxon:999428, Max Value: 0.9856408325018458, Max Value Column ID: ['mediadive.medium:220']
# [7.82600000e+03 9.83674426e-01 2.18000000e+02]
# Row ID: NCBITaxon:999429, Max Value: 0.983674426077583, Max Value Column ID: ['mediadive.medium:220']
# [7.82700000e+03 9.71261394e-01 2.18000000e+02]
# Row ID: NCBITaxon:999430, Max Value: 0.9712613941986374, Max Value Column ID: ['mediadive.medium:220']
# [7.82800000e+03 9.73323794e-01 1.17000000e+02]
# Row ID: NCBITaxon:999542, Max Value: 0.9733237941390394, Max Value Column ID: ['mediadive.medium:J27']
# [7.82900000e+03 9.84440376e-01 1.17000000e+02]
# Row ID: NCBITaxon:999543, Max Value: 0.9844403756087059, Max Value Column ID: ['mediadive.medium:J27']
# [7.83000000e+03 9.61033553e-01 1.17000000e+02]
# Row ID: NCBITaxon:999545, Max Value: 0.9610335525617751, Max Value Column ID: ['mediadive.medium:J27']
# [7.83100000e+03 9.42591266e-01 2.11000000e+02]
# Row ID: NCBITaxon:999547, Max Value: 0.9425912662926867, Max Value Column ID: ['mediadive.medium:830c']
# [7.83200000e+03 9.58678512e-01 1.17000000e+02]
# Row ID: NCBITaxon:999548, Max Value: 0.9586785122459964, Max Value Column ID: ['mediadive.medium:J27']
# [7.83300000e+03 9.86156952e-01 1.17000000e+02]
# Row ID: NCBITaxon:999549, Max Value: 0.9861569520209301, Max Value Column ID: ['mediadive.medium:J27']
# [7.83400000e+03 6.58428164e-01 2.11000000e+02]
# Row ID: NCBITaxon:999550, Max Value: 0.6584281638843709, Max Value Column ID: ['mediadive.medium:830c']
# [7.83500000e+03 9.64708159e-01 1.17000000e+02]
# Row ID: NCBITaxon:999552, Max Value: 0.9647081586143964, Max Value Column ID: ['mediadive.medium:J27']
# [7.83600000e+03 9.91279006e-01 1.17000000e+02]
# Row ID: NCBITaxon:999611, Max Value: 0.9912790056823069, Max Value Column ID: ['mediadive.medium:J27']
# [7.83700000e+03 9.54758494e-01 2.90000000e+01]
# Row ID: NCBITaxon:999894, Max Value: 0.9547584936553708, Max Value Column ID: ['mediadive.medium:693']
# [7.83800000e+03 2.22205726e-01 2.41000000e+02]
# Row ID: NCBITaxon:999931, Max Value: 0.22220572599247324, Max Value Column ID: ['mediadive.medium:J118']

# %%
predictions = pd.DataFrame(result, columns=['row_id', 'prob_max', 'media_id'])

predictions['row_id'] = predictions['row_id'].apply(lambda x: X2.index.values[int(x)])
predictions['media_id'] = predictions['media_id'].apply(lambda x: predicted_classes[int(x)][0])

predictions = predictions.sort_values(by='prob_max', ascending=False)

print(predictions)
# Out:
#                  row_id  prob_max               media_id
# 1795  NCBITaxon:1276246  0.999485    mediadive.medium:98
# 1793  NCBITaxon:1276227  0.999483    mediadive.medium:98
# 1236   NCBITaxon:118246  0.999474  mediadive.medium:J118
# 1768  NCBITaxon:1266998  0.999374  mediadive.medium:830c
# 798   NCBITaxon:1122249  0.999339    mediadive.medium:98
# ...                 ...       ...                    ...
# 48     NCBITaxon:102134  0.096741     mediadive.medium:1
# 848   NCBITaxon:1122954  0.086014  mediadive.medium:J346
# 3779    NCBITaxon:29376  0.081234    mediadive.medium:92
# 437   NCBITaxon:1120975  0.077697   mediadive.medium:J26
# 5108    NCBITaxon:44823  0.074112   mediadive.medium:105
#
# [7839 rows x 3 columns]

# %%
predictions[predictions['prob_max'] > 0.99]
# Out:
#                  row_id  prob_max               media_id
# 1795  NCBITaxon:1276246  0.999485    mediadive.medium:98
# 1793  NCBITaxon:1276227  0.999483    mediadive.medium:98
# 1236   NCBITaxon:118246  0.999474  mediadive.medium:J118
# 1768  NCBITaxon:1266998  0.999374  mediadive.medium:830c
# 798   NCBITaxon:1122249  0.999339    mediadive.medium:98
# ...                 ...       ...                    ...
# 1619  NCBITaxon:1227489  0.990093   mediadive.medium:693
# 1906  NCBITaxon:1304886  0.990039   mediadive.medium:830
# 758   NCBITaxon:1122187  0.990027  mediadive.medium:J415
# 364   NCBITaxon:1111734  0.990017   mediadive.medium:J22
# 197   NCBITaxon:1064517  0.990010  mediadive.medium:J118
#
# [335 rows x 3 columns]

# %%
type(result)
# Out:
# numpy.ndarray

# %%
Spiroplasma culicicola AES-1 - salt marsh mosquito 
    cellular organisms; Bacteria; Terrabacteria group; Mycoplasmatota; Mollicutes; Entomoplasmatales; Spiroplasmataceae; Spiroplasma; Spiroplasma culicicola

Spiroplasma chrysopicola DF-1 - deer fly
    cellular organisms; Bacteria; Terrabacteria group; Mycoplasmatota; Mollicutes; Entomoplasmatales; Spiroplasmataceae; Spiroplasma; Spiroplasma chrysopicola

Mycoplasmopsis sturni DSM 22021 - Conjunctiva of European starling Sturnus vulgaris
    cellular organisms; Bacteria; Terrabacteria group; Mycoplasmatota; Mycoplasmoidales; Metamycoplasmataceae; Mycoplasmopsis; Mycoplasmopsis sturni

98 . RHIZOBIUM MEDIUM
# Out:
#   Cell In[99], line 1
#     Spiroplasma culicicola AES-1
#                 ^
# SyntaxError: invalid syntax

# %%
Ureibacillus terrenus - uncultivated soil in Italy
    cellular organisms; Bacteria; Terrabacteria group; Bacillota; Bacilli; Bacillales; Planococcaceae; Ureibacillus

118 . MARINE AGAR 2216
