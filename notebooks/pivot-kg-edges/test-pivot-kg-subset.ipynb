# %% [markdown]
# # Test Pivoting Merged KG Edges
# ### This notebooks tests various approaches for pivoting data in `data/merged-kg_edges.tsv.gz`

# %%
import pandas as pds

# %% [markdown]
# ## load dataframe using file merged-kg_edges.tsv.gz

# %%
df = pds.read_csv('data/merged-kg_edges.tsv.gz', sep='\t')
len(df)
# Out:
# 424612

# %%
df.head() # peek at data
# Out:
#                                               id      subject  \
# 0  urn:uuid:875773d1-301d-46e4-bc42-1156d7cfaafa  CHEBI:51503
# 1  urn:uuid:6c7238d0-5836-4cfe-be27-63837059086b  CHEBI:26547
# 2  urn:uuid:f64ba0ef-1152-40b5-b245-bed32d57443f  CHEBI:51504
# 3  urn:uuid:eebedf42-5961-4208-aaae-44796c6574e6  CHEBI:26548
# 4  urn:uuid:a2ef1a16-b470-4b35-a6c9-0a2681b3fe2f  CHEBI:51505
#
#              predicate       object         relation provided_by
# 0  biolink:subclass_of  CHEBI:51494  rdfs:subClassOf       chebi
# 1  biolink:subclass_of  CHEBI:35315  rdfs:subClassOf       chebi
# 2  biolink:subclass_of  CHEBI:51493  rdfs:subClassOf       chebi
# 3  biolink:subclass_of  CHEBI:24400  rdfs:subClassOf       chebi
# 4  biolink:subclass_of  CHEBI:51504  rdfs:subClassOf       chebi

# %% [markdown]
# ## approach 1: create a reduced dataframe using subset of objects values
# - To make visual inspection easier, get 5 unique object values.
# - Filter `df` to include only rows with these objects, results in `reducedDf`.

# %%
objects = list(df['object'].unique())
len(objects)
# Out:
# 47792

# %%
test_objects = objects[:5]
test_objects
# Out:
# ['CHEBI:51494', 'CHEBI:35315', 'CHEBI:51493', 'CHEBI:24400', 'CHEBI:51504']

# %% [markdown]
# ### build test dataframe by filtering rows by test_objects

# %%
reducedDf = df[df['object'].isin(test_objects)]
len(reducedDf)
# Out:
# 644

# %%
reducedDf.head() # peek at data
# Out:
#                                               id      subject  \
# 0  urn:uuid:875773d1-301d-46e4-bc42-1156d7cfaafa  CHEBI:51503
# 1  urn:uuid:6c7238d0-5836-4cfe-be27-63837059086b  CHEBI:26547
# 2  urn:uuid:f64ba0ef-1152-40b5-b245-bed32d57443f  CHEBI:51504
# 3  urn:uuid:eebedf42-5961-4208-aaae-44796c6574e6  CHEBI:26548
# 4  urn:uuid:a2ef1a16-b470-4b35-a6c9-0a2681b3fe2f  CHEBI:51505
#
#              predicate       object         relation provided_by
# 0  biolink:subclass_of  CHEBI:51494  rdfs:subClassOf       chebi
# 1  biolink:subclass_of  CHEBI:35315  rdfs:subClassOf       chebi
# 2  biolink:subclass_of  CHEBI:51493  rdfs:subClassOf       chebi
# 3  biolink:subclass_of  CHEBI:24400  rdfs:subClassOf       chebi
# 4  biolink:subclass_of  CHEBI:51504  rdfs:subClassOf       chebi

# %% [markdown]
# ### pivot `reducedDf` using the `id` column as the index

# %%
reducedDf.head().pivot(index='id', columns='object', values='subject')
# Out:
# object                                         CHEBI:24400  CHEBI:35315  \
# id
# urn:uuid:6c7238d0-5836-4cfe-be27-63837059086b          NaN  CHEBI:26547
# urn:uuid:875773d1-301d-46e4-bc42-1156d7cfaafa          NaN          NaN
# urn:uuid:a2ef1a16-b470-4b35-a6c9-0a2681b3fe2f          NaN          NaN
# urn:uuid:eebedf42-5961-4208-aaae-44796c6574e6  CHEBI:26548          NaN
# urn:uuid:f64ba0ef-1152-40b5-b245-bed32d57443f          NaN          NaN
#
# object                                         CHEBI:51493  CHEBI:51494  \
# id
# urn:uuid:6c7238d0-5836-4cfe-be27-63837059086b          NaN          NaN
# urn:uuid:875773d1-301d-46e4-bc42-1156d7cfaafa          NaN  CHEBI:51503
# urn:uuid:a2ef1a16-b470-4b35-a6c9-0a2681b3fe2f          NaN          NaN
# urn:uuid:eebedf42-5961-4208-aaae-44796c6574e6          NaN          NaN
# urn:uuid:f64ba0ef-1152-40b5-b245-bed32d57443f  CHEBI:51504          NaN
#
# object                                         CHEBI:51504
# id
# urn:uuid:6c7238d0-5836-4cfe-be27-63837059086b          NaN
# urn:uuid:875773d1-301d-46e4-bc42-1156d7cfaafa          NaN
# urn:uuid:a2ef1a16-b470-4b35-a6c9-0a2681b3fe2f  CHEBI:51505
# urn:uuid:eebedf42-5961-4208-aaae-44796c6574e6          NaN
# urn:uuid:f64ba0ef-1152-40b5-b245-bed32d57443f          NaN

# %% [markdown]
# ## approach 2: create a test dataframe using subject values that occur more than 20 times

# %%
testDf = df.groupby('subject').filter(lambda x: len(x) > 20)
len(testDf)
# Out:
# 120

# %%
testDf.subject.value_counts()
# Out:
# CHEBI:3962       30
# NCBITaxon:287    25
# CHEBI:16118      23
# CHEBI:4775       21
# NCBITaxon:562    21
# Name: subject, dtype: int64

# %%
testDf.head() # peek at data
# Out:
#                                                    id     subject  \
# 145309  urn:uuid:ef61c57d-1fc2-44c2-bb5d-c5d9afe8d0ee  CHEBI:3962
# 145310  urn:uuid:fe86c705-cbe7-4ccd-8225-443493c55864  CHEBI:3962
# 145311  urn:uuid:030b4615-f2ed-432d-889a-3b021eff2c1b  CHEBI:3962
# 145312  urn:uuid:fa519ca3-a590-4773-99ca-452c59eccf56  CHEBI:3962
# 145313  urn:uuid:73e4d0e2-8eb8-48ff-84bc-77f7861f04f4  CHEBI:3962
#
#                     predicate       object    relation provided_by
# 145309  biolink:has_attribute  CHEBI:53746  RO:0000087       chebi
# 145310  biolink:has_attribute  CHEBI:64670  RO:0000087       chebi
# 145311  biolink:has_attribute  CHEBI:26130  RO:0000087       chebi
# 145312  biolink:has_attribute  CHEBI:37958  RO:0000087       chebi
# 145313  biolink:has_attribute  CHEBI:48550  RO:0000087       chebi

# %% [markdown]
# ### pivot `testdf` so that that the subject values are values in each object column

# %%
pivotTestDf = testDf.pivot(index='subject', columns='object', values='subject')
pivotTestDf
# Out:
# object        CHEBI:131699 CHEBI:17620  CHEBI:22586  CHEBI:22754  \
# subject
# CHEBI:16118            NaN         NaN  CHEBI:16118  CHEBI:16118
# CHEBI:3962             NaN  CHEBI:3962          NaN          NaN
# CHEBI:4775      CHEBI:4775         NaN   CHEBI:4775          NaN
# NCBITaxon:287          NaN         NaN          NaN          NaN
# NCBITaxon:562          NaN         NaN          NaN          NaN
#
# object           CHEBI:24632 CHEBI:25000  CHEBI:25212 CHEBI:26130 CHEBI:26195  \
# subject
# CHEBI:16118              NaN         NaN  CHEBI:16118         NaN         NaN
# CHEBI:3962               NaN         NaN   CHEBI:3962  CHEBI:3962  CHEBI:3962
# CHEBI:4775               NaN  CHEBI:4775          NaN         NaN  CHEBI:4775
# NCBITaxon:287  NCBITaxon:287         NaN          NaN         NaN         NaN
# NCBITaxon:562            NaN         NaN          NaN         NaN         NaN
#
# object        CHEBI:30778  ...    NCBITaxon:1 NCBITaxon:136841  NCBITaxon:561  \
# subject                    ...
# CHEBI:16118           NaN  ...            NaN              NaN            NaN
# CHEBI:3962            NaN  ...            NaN              NaN            NaN
# CHEBI:4775     CHEBI:4775  ...            NaN              NaN            NaN
# NCBITaxon:287         NaN  ...  NCBITaxon:287    NCBITaxon:287            NaN
# NCBITaxon:562         NaN  ...            NaN              NaN  NCBITaxon:562
#
# object          PATO:0001472 Shape:bacillus Shape:coccobacillus  \
# subject
# CHEBI:16118              NaN            NaN                 NaN
# CHEBI:3962               NaN            NaN                 NaN
# CHEBI:4775               NaN            NaN                 NaN
# NCBITaxon:287  NCBITaxon:287  NCBITaxon:287                 NaN
# NCBITaxon:562            NaN  NCBITaxon:562       NCBITaxon:562
#
# object        UBERON:0000065 UBERON:0000178 UBERON:0000468 UBERON:0000996
# subject
# CHEBI:16118              NaN            NaN            NaN            NaN
# CHEBI:3962               NaN            NaN            NaN            NaN
# CHEBI:4775               NaN            NaN            NaN            NaN
# NCBITaxon:287  NCBITaxon:287  NCBITaxon:287  NCBITaxon:287            NaN
# NCBITaxon:562  NCBITaxon:562  NCBITaxon:562  NCBITaxon:562  NCBITaxon:562
#
# [5 rows x 99 columns]

# %% [markdown]
# ### validate output from test dataframe
# Steps
# - get the subject and object from `testDf` where the index is `NCBITaxon:562`; store this result in `testResult`
# - get the subject and object from the pivot dataframe; store this result in `pivotResult`
# - perform a left outer join on `pivotResult` and `testResult`; the result is valid if:
#   * every result from the `pivotResult['NCBITaxon:562']` dataframe has the same value in the `testResult['subject']` column
#   * every NaN from `pivotResult['NCBITaxon:562']` is also NaN in `testResult['subject']`

# %%
testResult = testDf[testDf.subject == 'NCBITaxon:562'][['subject', 'object']]
# testResult
print('(rows, cols):', testResult.shape)
testResult
# Out:
# (rows, cols): (21, 2)
#               subject               object
# 288097  NCBITaxon:562     ECOCORE:00000180
# 288098  NCBITaxon:562     ECOCORE:00000177
# 288099  NCBITaxon:562       Shape:bacillus
# 288100  NCBITaxon:562       UBERON:0000468
# 288101  NCBITaxon:562         ENVO:2100002
# 288102  NCBITaxon:562       UBERON:0000996
# 288103  NCBITaxon:562         ENVO:2100003
# 288104  NCBITaxon:562       UBERON:0000065
# 288105  NCBITaxon:562        ENVO:00002149
# 288106  NCBITaxon:562        ENVO:00002123
# 288107  NCBITaxon:562        ENVO:00002006
# 288108  NCBITaxon:562      Env:intratissue
# 288109  NCBITaxon:562        Env:endotherm
# 288110  NCBITaxon:562       UBERON:0000178
# 288111  NCBITaxon:562          CHEBI:33290
# 288112  NCBITaxon:562        ENVO:01001001
# 288113  NCBITaxon:562        ENVO:00002001
# 288114  NCBITaxon:562     ECOCORE:00000173
# 288115  NCBITaxon:562        ENVO:08000002
# 288116  NCBITaxon:562  Shape:coccobacillus
# 288117  NCBITaxon:562        NCBITaxon:561

# %%
# pds.set_option('display.max_rows', 500) # uncomment to see all of result
pivotResult = pivotTestDf.loc['NCBITaxon:562'].reset_index()
print('(rows, cols):', pivotResult.shape)
pivotResult
# Out:
# (rows, cols): (99, 2)
#                  object  NCBITaxon:562
# 0          CHEBI:131699            NaN
# 1           CHEBI:17620            NaN
# 2           CHEBI:22586            NaN
# 3           CHEBI:22754            NaN
# 4           CHEBI:24632            NaN
# ..                  ...            ...
# 94  Shape:coccobacillus  NCBITaxon:562
# 95       UBERON:0000065  NCBITaxon:562
# 96       UBERON:0000178  NCBITaxon:562
# 97       UBERON:0000468  NCBITaxon:562
# 98       UBERON:0000996  NCBITaxon:562
#
# [99 rows x 2 columns]

# %% [markdown]
# visually inspecting the output, we see that the values and NaNs line up as expected.

# %%
pds.set_option('display.max_rows', 500)
pds.merge(pivotResult, testResult, how='left', on='object')
# Out:
#                  object  NCBITaxon:562        subject
# 0          CHEBI:131699            NaN            NaN
# 1           CHEBI:17620            NaN            NaN
# 2           CHEBI:22586            NaN            NaN
# 3           CHEBI:22754            NaN            NaN
# 4           CHEBI:24632            NaN            NaN
# 5           CHEBI:25000            NaN            NaN
# 6           CHEBI:25212            NaN            NaN
# 7           CHEBI:26130            NaN            NaN
# 8           CHEBI:26195            NaN            NaN
# 9           CHEBI:30778            NaN            NaN
# 10          CHEBI:33290  NCBITaxon:562  NCBITaxon:562
# 11          CHEBI:33566            NaN            NaN
# 12          CHEBI:35526            NaN            NaN
# 13          CHEBI:35608            NaN            NaN
# 14          CHEBI:35610            NaN            NaN
# 15          CHEBI:35617            NaN            NaN
# 16          CHEBI:35618            NaN            NaN
# 17          CHEBI:35679            NaN            NaN
# 18          CHEBI:35718            NaN            NaN
# 19          CHEBI:35856            NaN            NaN
# 20          CHEBI:37733            NaN            NaN
# 21          CHEBI:37958            NaN            NaN
# 22          CHEBI:38157            NaN            NaN
# 23          CHEBI:38163            NaN            NaN
# 24          CHEBI:38164            NaN            NaN
# 25          CHEBI:38462            NaN            NaN
# 26           CHEBI:3992            NaN            NaN
# 27          CHEBI:48550            NaN            NaN
# 28          CHEBI:48578            NaN            NaN
# 29          CHEBI:49323            NaN            NaN
# 30          CHEBI:50276            NaN            NaN
# 31          CHEBI:50390            NaN            NaN
# 32          CHEBI:50469            NaN            NaN
# 33          CHEBI:50509            NaN            NaN
# 34          CHEBI:50733            NaN            NaN
# 35          CHEBI:50750            NaN            NaN
# 36          CHEBI:50846            NaN            NaN
# 37          CHEBI:51689            NaN            NaN
# 38          CHEBI:52214            NaN            NaN
# 39          CHEBI:53746            NaN            NaN
# 40          CHEBI:59997            NaN            NaN
# 41          CHEBI:61115            NaN            NaN
# 42          CHEBI:62868            NaN            NaN
# 43          CHEBI:63726            NaN            NaN
# 44          CHEBI:64047            NaN            NaN
# 45          CHEBI:64670            NaN            NaN
# 46          CHEBI:67079            NaN            NaN
# 47          CHEBI:67265            NaN            NaN
# 48          CHEBI:68612            NaN            NaN
# 49          CHEBI:72854            NaN            NaN
# 50          CHEBI:76617            NaN            NaN
# 51          CHEBI:76779            NaN            NaN
# 52          CHEBI:76797            NaN            NaN
# 53          CHEBI:76924            NaN            NaN
# 54          CHEBI:76946            NaN            NaN
# 55          CHEBI:77108            NaN            NaN
# 56          CHEBI:77110            NaN            NaN
# 57          CHEBI:77111            NaN            NaN
# 58          CHEBI:77113            NaN            NaN
# 59          CHEBI:77115            NaN            NaN
# 60          CHEBI:77182            NaN            NaN
# 61          CHEBI:77484            NaN            NaN
# 62          CHEBI:78802            NaN            NaN
# 63          CHEBI:84799            NaN            NaN
# 64          CHEBI:84800            NaN            NaN
# 65          CHEBI:84801            NaN            NaN
# 66          CHEBI:84802            NaN            NaN
# 67          CHEBI:84804            NaN            NaN
# 68          CHEBI:85046            NaN            NaN
# 69          CHEBI:86322            NaN            NaN
# 70          CHEBI:86494            NaN            NaN
# 71     ECOCORE:00000173  NCBITaxon:562  NCBITaxon:562
# 72     ECOCORE:00000177  NCBITaxon:562  NCBITaxon:562
# 73     ECOCORE:00000180  NCBITaxon:562  NCBITaxon:562
# 74        ENVO:00000073            NaN            NaN
# 75        ENVO:00001998            NaN            NaN
# 76        ENVO:00002001  NCBITaxon:562  NCBITaxon:562
# 77        ENVO:00002006  NCBITaxon:562  NCBITaxon:562
# 78        ENVO:00002011            NaN            NaN
# 79        ENVO:00002123  NCBITaxon:562  NCBITaxon:562
# 80        ENVO:00002149  NCBITaxon:562  NCBITaxon:562
# 81        ENVO:00002170            NaN            NaN
# 82        ENVO:01001001  NCBITaxon:562  NCBITaxon:562
# 83        ENVO:02500038            NaN            NaN
# 84        ENVO:08000002  NCBITaxon:562  NCBITaxon:562
# 85         ENVO:2100002  NCBITaxon:562  NCBITaxon:562
# 86         ENVO:2100003  NCBITaxon:562  NCBITaxon:562
# 87        Env:endotherm  NCBITaxon:562  NCBITaxon:562
# 88      Env:intratissue  NCBITaxon:562  NCBITaxon:562
# 89          NCBITaxon:1            NaN            NaN
# 90     NCBITaxon:136841            NaN            NaN
# 91        NCBITaxon:561  NCBITaxon:562  NCBITaxon:562
# 92         PATO:0001472            NaN            NaN
# 93       Shape:bacillus  NCBITaxon:562  NCBITaxon:562
# 94  Shape:coccobacillus  NCBITaxon:562  NCBITaxon:562
# 95       UBERON:0000065  NCBITaxon:562  NCBITaxon:562
# 96       UBERON:0000178  NCBITaxon:562  NCBITaxon:562
# 97       UBERON:0000468  NCBITaxon:562  NCBITaxon:562
# 98       UBERON:0000996  NCBITaxon:562  NCBITaxon:562
